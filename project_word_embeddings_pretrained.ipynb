# %% [markdown]
# # Detect claims to fact check in political debates
#
# In this project you will implement various classifiers using both neural and feature based technqiues to detect which sentences in political debates should be fact checked.
# Dataset from ClaimBuster: https://zenodo.org/record/3609356
# Evaluate your classifiers using the same metrics as http://ranger.uta.edu/~cli/pubs/2017/claimbuster-kdd17-hassan.pdf (Table 2)
#
# Classification report from sklearn provides everything

# %%
# TODO:  Create advanced model(s) (suggestions are given below)
#           -- Generate more features that a model can use. For example the context around the sentence, sentiment, named entities etc.
#           -- Rule based classifier. For example, if sentence contains certain words, tags, statistics etc.
#           -- Deep learning (word embeddings, transformer models etc.)
#           -- Sub-sentence classifier. Long sentences may include several claims, so the goal is to mark the span of claim(s) within a sentence

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import collections
import string

from sklearn.cluster import KMeans
from sklearn.metrics import *
from sklearn.linear_model import Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier

import json
import glob
import re
import time

# %% [markdown]
# # Loading and merging the data

# %%
file1 = pd.read_csv("data/crowdsourced.csv", encoding='utf-8')
file2 = pd.read_csv("data/groundtruth.csv", encoding='utf-8')
df = pd.concat([file1, file2])


df["date"] = df["File_id"].str.strip(to_strip=".txt")

df["date"] = pd.to_datetime(df["date"])
df.sort_values("date", inplace= True)
df["mos_before_election"] = 11 - df["date"].dt.month

df['index'] = pd.RangeIndex(len(df))
df.set_index('index', inplace=True)
df
# Out:
#        Sentence_id                                               Text  \
# index
# 0             8211                   Now, this is not standing still.
# 1             8515  So these are three programs which are quite mo...
# 2             8514  The proposal advanced by you and by Mr. Javits...
# 3             8513         It does not put a deficit on the Treasury.
# 4             8512  The third is medical care for the aged which i...
# ...            ...                                                ...
# 23528        34028  First of all, the media is so dishonest and so...
# 23529        34027        What I've seen -- what I've seen is so bad.
# 23530        34026                       I'll look at it at the time.
# 23531        34039                 So I talk about the corrupt media.
# 23532        33341  They work hard, they do everything they can to...
#
#                 Speaker       Speaker_title Speaker_party         File_id  \
# index
# 0      Richard M. Nixon      Vice President    REPUBLICAN  1960-09-26.txt
# 1       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 2       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 3       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 4       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# ...                 ...                 ...           ...             ...
# 23528      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23529      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23530      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23531      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23532   Hillary Clinton  Secretary of State      DEMOCRAT  2016-10-19.txt
#
#        Length  Line_number  Sentiment  Verdict       date  mos_before_election
# index
# 0           6          114  -0.417840       -1 1960-09-26                    2
# 1           9          418   0.249581       -1 1960-09-26                    2
# 2          42          417  -0.626563        1 1960-09-26                    2
# 3           9          416  -0.629486        1 1960-09-26                    2
# 4          22          415   0.000000       -1 1960-09-26                    2
# ...       ...          ...        ...      ...        ...                  ...
# 23528      17          907   0.032300       -1 2016-10-19                    1
# 23529       9          906  -0.669600       -1 2016-10-19                    1
# 23530       7          905   0.000000       -1 2016-10-19                    1
# 23531       7          918   0.000000       -1 2016-10-19                    1
# 23532      14          220   0.361200       -1 2016-10-19                    1
#
# [23533 rows x 12 columns]

# %% [markdown]
# # Data preprocessing

# %%
def remove_punctuation(text):
    tokens = re.sub('[^a-zA-Z]', ' ', text).lower()
    return tokens

# %%
def remove_stop_words(text):
    stop_words = stopwords.words('english')
    word_list = [word for word in text.split() if word not in stop_words]
    return word_list

# %%
def get_word_stemm(word_list):
    """Stemmers remove morphological affixes from words, leaving only the word stem."""
    stemmer = SnowballStemmer('english')
    singles = [stemmer.stem(word) for word in word_list] 
    return singles

# %%
def preprocess_data(docs, stemming=False):

    text_list = [] 
    for doc in docs:  
        # 1. Remove punctuation and set as lower case
        text = remove_punctuation(doc)

        # 2. Remove stop words and extra spaces
        word_list = remove_stop_words(text)

        if stemming:
            # 3. Stemming
            word_list = get_word_stemm(word_list)

        joined_text = " ".join(word_list)
        text_list.append(joined_text)
        
    return text_list

# %%
data = preprocess_data(df.Text.values, stemming=True)

# %%
# add clean text to dataframe
df["Clean_text"] = pd.Series(data)

# %%
df.head()
# Out:
#        Sentence_id                                               Text  \
# index
# 0             8211                   Now, this is not standing still.
# 1             8515  So these are three programs which are quite mo...
# 2             8514  The proposal advanced by you and by Mr. Javits...
# 3             8513         It does not put a deficit on the Treasury.
# 4             8512  The third is medical care for the aged which i...
#
#                 Speaker   Speaker_title Speaker_party         File_id  Length  \
# index
# 0      Richard M. Nixon  Vice President    REPUBLICAN  1960-09-26.txt       6
# 1       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt       9
# 2       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt      42
# 3       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt       9
# 4       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt      22
#
#        Line_number  Sentiment  Verdict       date  mos_before_election  \
# index
# 0              114  -0.417840       -1 1960-09-26                    2
# 1              418   0.249581       -1 1960-09-26                    2
# 2              417  -0.626563        1 1960-09-26                    2
# 3              416  -0.629486        1 1960-09-26                    2
# 4              415   0.000000       -1 1960-09-26                    2
#
#                                               Clean_text
# index
# 0                                            stand still
# 1                               three program quit moder
# 2      propos advanc mr javit would cost six hundr mi...
# 3                                   put deficit treasuri
# 4      third medic care age tie social secur financ s...

# %%
mask = df["date"].dt.year < 2012

X_train = df.loc[mask, "Clean_text"].values
y_train = df.loc[mask, "Verdict"].values

X_test = df.loc[~mask, "Clean_text"].values
y_test = df.loc[~mask, "Verdict"].values

# %% [markdown]
# # Word Embedding using keras - NOT WORKING YET :D

# %% [markdown]
# ## Extract Word Embeddings from Glove

# %%
# embeddings_index = dict()
# f = open('glove.6B/glove.6B.100d.txt')
# for line in f:
#     values = line.split()
#     word = values[0]
#     coefs = np.asarray(values[1:], dtype='float32')
#     embeddings_index[word] = coefs
# f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38936/3745991154.py in <module>
#       1 embeddings_index = dict()
# ----> 2 f = open('glove.6B/glove.6B.100d.txt')
#       3 for line in f:
#       4     values = line.split()
#       5     word = values[0]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'glove.6B/glove.6B.100d.txt'

# %%
from keras.preprocessing.text import Tokenizer

embedding_matrix = np.zeros((vocabulary_size, 100))
for word, index in tokenizer.word_index.items():
    if index > vocabulary_size - 1:
        break
    else:
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector

# %%
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
# defining vocabulary
vocabulary = {}
sentences_len = []
for sentence in df["Clean_text"]:
    for term in sentence.split():
        vocabulary.setdefault(term, len(vocabulary))

# %%
# Defining vocabulary size
vocabulary_size = list(vocabulary.values())[-1] + 1

print(f"vocabulary is composed of {vocabulary_size} unique words")
# Out:
# vocabulary is composed of 6916 unique words

# %% [markdown]
# ## One hot encoding representation

# %%
encoded_vocab = [one_hot(words, vocabulary_size) for words in df["Clean_text"].values]

# %%
encoded_vocab
# Out:
# [[2644, 5474],
#  [6759, 1742, 2383, 1009],
#  [4222,
#   5408,
#   5070,
#   1975,
#   3016,
#   4077,
#   5716,
#   682,
#   4028,
#   3933,
#   5070,
#   4205,
#   1164,
#   5862,
#   557,
#   583,
#   5419,
#   2347,
#   583,
#   3134,
#   4474,
#   6645],
#  [1287, 6507, 4435],
#  [776, 6178, 170, 2730, 6215, 4474, 6645, 2347, 4474, 6645, 3627],
#  [6074, 376, 2132, 329],
#  [6074, 376],
#  [6074, 2722, 3774, 5611, 1742],
#  [4655,
#   1352,
#   6806,
#   925,
#   5572,
#   2219,
#   2132,
#   973,
#   6722,
#   5911,
#   3267,
#   3419,
#   2722,
#   993,
#   2276,
#   3362,
#   2297,
#   2219,
#   2132,
#   973,
#   2722,
#   329],
#  [948, 2253, 1352, 4115, 6121, 5070, 3562, 1513, 4222],
#  [6822, 3910, 6323, 5982, 1352, 6822, 6763, 2326, 818],
#  [6518, 2746, 1934, 4559, 1352],
#  [5911, 4655, 6806, 3243, 6553, 776, 6759, 768, 2132, 2297, 1518, 993, 4222],
#  [2219,
#   1352,
#   3933,
#   1905,
#   4662,
#   4898,
#   4450,
#   87,
#   5056,
#   6174,
#   4711,
#   4028,
#   3933,
#   3091,
#   5253],
#  [6912, 1868, 1033, 1352, 4293, 2795, 3199, 4655],
#  [5073,
#   2795,
#   6636,
#   4106,
#   5928,
#   5073,
#   935,
#   2276,
#   1352,
#   5911,
#   4106,
#   3182,
#   935,
#   376,
#   1866,
#   1695,
#   923,
#   2795],
#  [4334, 2385, 5055, 2795, 3385, 3313, 4837, 3182, 923],
#  [148,
#   6074,
#   3381,
#   554,
#   3158,
#   4222,
#   2504,
#   4130,
#   533,
#   2219,
#   6822,
#   6565,
#   4106,
#   3385,
#   1742],
#  [5911, 3673, 6474, 6553, 459],
#  [2264,
#   2297,
#   554,
#   3374,
#   3031,
#   2722,
#   2132,
#   1695,
#   993,
#   2414,
#   2795,
#   4222,
#   456,
#   6168,
#   2869,
#   2795,
#   2132,
#   3016,
#   2129,
#   3016,
#   2316,
#   5572,
#   1742,
#   935],
#  [2219, 459, 2916, 5779, 1742],
#  [6912, 5911, 6735],
#  [6255,
#   2264,
#   6090,
#   5779,
#   2264,
#   2746,
#   2202,
#   6571,
#   3436,
#   2202,
#   6571,
#   4094,
#   2202,
#   6571,
#   4015,
#   1068,
#   6017,
#   6200,
#   5779],
#  [4194, 3168, 2264, 5779, 6168, 5911, 2746, 2202],
#  [2253, 948, 4130, 1885, 5934, 4270, 2703],
#  [4130, 2219, 4000, 4000, 2219, 2761],
#  [3065,
#   3016,
#   6074,
#   554,
#   3158,
#   6074,
#   587,
#   5757,
#   6168,
#   6822,
#   3016,
#   5419,
#   2683,
#   6168,
#   4222,
#   2746,
#   1934,
#   4559,
#   4222,
#   5423,
#   170,
#   2683,
#   6089],
#  [3065,
#   5911,
#   6822,
#   4334,
#   1033,
#   1214,
#   6141,
#   948,
#   4850,
#   1838,
#   2778,
#   1889,
#   5965,
#   569,
#   6822,
#   3865,
#   569,
#   3865,
#   2933,
#   1786,
#   996,
#   148,
#   4850,
#   1838,
#   2778,
#   5779,
#   416,
#   1686,
#   3284,
#   3013,
#   569,
#   5598,
#   5243],
#  [4221, 3923, 2261, 3016, 4337, 6427],
#  [148, 2223, 1635, 3447, 3447, 3447, 4221, 2594, 569, 3016, 4322],
#  [5055,
#   6633,
#   903,
#   5070,
#   975,
#   4990,
#   1394,
#   4990,
#   4990,
#   4025,
#   4990,
#   4784,
#   3774,
#   3436],
#  [2219, 5806, 6168, 3091, 4307],
#  [4130, 1838, 300, 3774, 3436, 2219, 4078, 6906, 3943],
#  [5419, 554, 3158, 3168, 4349, 236],
#  [376, 5269, 3158, 5806],
#  [5911, 3774, 3436, 4420, 4652, 3013, 3774, 3436, 5911, 1289, 396, 5269],
#  [5928, 6822, 1270, 2147, 5441, 2370, 5747, 5806, 1635],
#  [5611,
#   6822,
#   1889,
#   3774,
#   3436,
#   6557,
#   5185,
#   4229,
#   6906,
#   6822,
#   3016,
#   4322,
#   6906,
#   300],
#  [5911, 2253, 5806, 6822, 1258, 6822, 3867, 170, 973],
#  [459, 1258, 4747, 1709],
#  [1331, 1315, 6220, 3167, 3074, 4662, 682, 3641, 3933],
#  [5225, 376, 3182, 1742, 2297, 554, 2592],
#  [3016,
#   6074,
#   2795,
#   2316,
#   683,
#   2795,
#   2316,
#   5572,
#   1742,
#   5766,
#   5611,
#   1695,
#   5611,
#   3182],
#  [4648, 404],
#  [404, 2440, 6168, 440, 3057, 1866, 163, 3057],
#  [5911, 3286, 2440, 5669, 1866, 163],
#  [554, 3158, 3199, 6168, 1866, 163],
#  [236, 2683, 2703, 3199],
#  [6587, 1033, 416, 1742, 2451, 4794, 5862],
#  [4794, 533, 3168, 1742, 4774, 1645, 2110],
#  [3016, 3199, 1156, 1855, 6381, 5345, 6382, 1742, 5862, 2761, 3057],
#  [1742,
#   4852,
#   4559,
#   3639,
#   1258,
#   6587,
#   5510,
#   698,
#   4559,
#   6694,
#   1035,
#   1674,
#   2095,
#   3182],
#  [1742, 1107, 1528, 6178, 170, 2730, 166, 166, 1242, 5545, 2069, 912],
#  [5031, 5345, 554, 3158, 5880, 4759],
#  [2041, 2913, 645, 3182],
#  [2041, 1528, 1521, 6178, 170],
#  [4130, 2761],
#  [925,
#   1258,
#   1242,
#   1331,
#   4868,
#   2264,
#   5095,
#   2297,
#   5423,
#   6178,
#   170,
#   1197,
#   1877,
#   5147,
#   500,
#   5679,
#   1742,
#   6168,
#   5779,
#   6090,
#   5779,
#   353,
#   404,
#   1729,
#   2440,
#   456,
#   3943,
#   5686,
#   5249,
#   3091],
#  [1033, 1742, 6381, 3199, 496, 4194, 1363, 6074, 6255, 1742, 166, 126],
#  [3635, 6382, 1337, 554, 3158, 3016, 4119, 2746, 2202, 126, 3016, 126],
#  [2440, 4337, 4648, 2644],
#  [5986, 5572, 2326, 5572, 1742, 2297, 554, 4506, 4130, 3908, 1755, 3071, 6694],
#  [2766, 2440, 5031, 4653, 5305],
#  [2451, 1292],
#  [3932, 1156, 2019, 554],
#  [6822, 3016, 1019, 2019, 2297, 5572, 376, 2297, 6822, 1638],
#  [3016, 6074, 1156, 1498, 860, 3508, 2297, 554],
#  [4954,
#   5712,
#   4222,
#   2132,
#   5095,
#   5423,
#   5095,
#   4559,
#   5095,
#   2894,
#   4655,
#   1025,
#   1987,
#   6822,
#   5633,
#   3867,
#   4077,
#   3933,
#   2594,
#   925,
#   5572,
#   3374,
#   935],
#  [4655],
#  [5073, 1114, 1352, 416, 5095, 285, 6557, 2795, 3182],
#  [376,
#   6038,
#   935,
#   4465,
#   1114,
#   4222,
#   2766,
#   1247,
#   376,
#   2722,
#   6557,
#   2276,
#   2795,
#   5572,
#   4106,
#   1247],
#  [2795, 4347, 4106, 5679, 3182, 6642, 923, 776, 935],
#  [3016,
#   6074,
#   2241,
#   2795,
#   4106,
#   5679,
#   3278,
#   554,
#   1394,
#   5572,
#   5125,
#   4947,
#   3031,
#   6822,
#   681,
#   3964],
#  [3016, 4794, 3050, 2241, 3267, 2132, 3419, 2722, 5572, 4648, 1114, 4969],
#  [3016,
#   6074,
#   554,
#   3158,
#   1337,
#   5125,
#   2297,
#   6340,
#   4969,
#   3419,
#   2722,
#   4969,
#   3267,
#   2132],
#  [3286,
#   1528,
#   4063,
#   2219,
#   776,
#   894,
#   2132,
#   2297,
#   554,
#   3385,
#   6553,
#   776,
#   6553,
#   776,
#   1521,
#   353],
#  [6912, 4499, 5920, 4745, 6474],
#  [2276,
#   2132,
#   2795,
#   2722,
#   376,
#   5269,
#   4106,
#   5186,
#   935,
#   3699,
#   5806,
#   5467,
#   5512,
#   3031,
#   6714,
#   459,
#   3412],
#  [3699, 2861, 2722, 2795, 5611, 2722, 376, 2297, 554, 1480, 5611, 1742],
#  [6652, 912, 3731, 993, 6657, 2795, 3774, 3436, 3016, 4106],
#  [710, 3267, 2722, 993, 2219, 2132, 993],
#  [2041, 6215, 4474, 6645],
#  [4077, 4077, 2722, 2329],
#  [3700, 682, 3641, 682, 3457, 3641, 3551, 2202, 1250],
#  [116, 1033, 116, 1645, 5611, 4075, 362],
#  [363, 311, 6587, 5658, 5044, 3112, 4784],
#  [363, 2682, 1242, 6822, 2125, 2211, 2690],
#  [3867, 1695, 5911, 925, 4015, 1695, 5679, 1695, 5911, 925, 5679, 1695],
#  [2761,
#   4705,
#   2486,
#   1468,
#   5351,
#   1235,
#   6140,
#   4898,
#   6636,
#   3091,
#   6553,
#   6140,
#   4898,
#   4774,
#   3091],
#  [3867, 2428, 2515, 4901],
#  [5911, 2916, 5779],
#  [4130, 6587, 3182, 3574, 2041, 2041, 1695, 2041, 1214],
#  [2041, 6074, 3091, 1649, 3731, 3091, 3774, 3436, 4881, 5779],
#  [2041, 1846, 6894, 3091, 6074, 3091, 1649, 4071, 3774, 3436],
#  [275,
#   275,
#   5779,
#   6168,
#   275,
#   5147,
#   3484,
#   5471,
#   5928,
#   4474,
#   2312,
#   1695,
#   5911,
#   6822,
#   1649,
#   925,
#   3253,
#   2691,
#   6906],
#  [1289, 5540, 5911, 2594, 1230],
#  [583,
#   3253,
#   4130,
#   6906,
#   5330,
#   2132,
#   2722,
#   2594,
#   3374,
#   4284,
#   1230,
#   569,
#   3306,
#   2515],
#  [27,
#   5779,
#   1218,
#   2079,
#   2795,
#   5480,
#   3182,
#   2511,
#   5253,
#   3013,
#   5329,
#   293,
#   6102,
#   4291,
#   3182,
#   4334,
#   3013,
#   1289,
#   818,
#   1695,
#   4229,
#   6645,
#   2913,
#   1481,
#   2594],
#  [5911, 993, 5070, 3562],
#  [27,
#   340,
#   2626,
#   5667,
#   4663,
#   5679,
#   6551,
#   2312,
#   3774,
#   3436,
#   6324,
#   4663,
#   569,
#   5747,
#   6370,
#   6645,
#   5111,
#   340,
#   6220,
#   5111,
#   5111,
#   1242,
#   4326,
#   610,
#   4015,
#   2312,
#   5419],
#  [2761, 4130],
#  [776, 5911, 4130, 6587, 3182, 1033, 1695, 1033, 4025, 5235, 4000, 6587],
#  [1416, 5243, 4284],
#  [5512, 67, 5572, 912, 6178, 170, 1675, 5611, 2219, 2132, 554, 1226],
#  [3774, 3436, 2644, 5474],
#  [5911, 2761, 1514, 5736, 4000, 1242, 2761, 1514],
#  [88, 1352, 2545, 4420, 4474, 6645],
#  [148, 2223, 5698, 3933, 665, 925, 1242, 665, 3182],
#  [2644, 1742, 2761, 116, 3057],
#  [5911, 6218, 4881, 6218, 2428, 6218, 2079, 2746, 2202],
#  [5073,
#   6636,
#   1645,
#   5779,
#   5073,
#   3627,
#   1331,
#   4094,
#   404,
#   1197,
#   1395,
#   4647,
#   2703,
#   3057,
#   1645,
#   4347,
#   6017,
#   6200,
#   3551,
#   1438,
#   1091,
#   3518,
#   1642,
#   4066,
#   1791,
#   374,
#   3419,
#   3091,
#   1382],
#  [6255, 2264, 6090, 5779],
#  [5806, 1635],
#  [311, 2132, 6340, 4969, 993, 2276, 1352, 2928, 6038, 2297, 1518],
#  [6381,
#   6074,
#   6553,
#   776,
#   2132,
#   2297,
#   993,
#   3933,
#   1905,
#   4662,
#   4898,
#   1977,
#   4990,
#   376,
#   2722,
#   5928,
#   3243,
#   6553,
#   776,
#   993,
#   3933,
#   1905,
#   4662],
#  [5939, 4077, 3933],
#  [554, 3158, 406, 6478],
#  [3381,
#   1934,
#   1197,
#   3028,
#   2504,
#   2114,
#   554,
#   3158,
#   6522,
#   3091,
#   583,
#   2114,
#   5602,
#   1934,
#   6323,
#   5982],
#  [6822, 6074, 6658, 3182, 2928, 554, 3158, 3182, 2928],
#  [1156, 1050, 554, 3158, 6763, 3199, 2626, 6822, 6531, 1742],
#  [3699, 4075, 5056, 5766, 793, 4440, 2920],
#  [6912, 4293, 2795, 3731, 935, 5997, 1806, 5156, 4969],
#  [4130, 166, 2746, 2202, 126, 4130, 2202],
#  [5576, 1742],
#  [3267, 682, 3641, 3074, 3551, 6017],
#  [5070, 2602, 4071, 5533],
#  [5911, 3754, 2483],
#  [5572, 6822, 6822, 4066],
#  [5767, 3006],
#  [5073, 47],
#  [3381, 4767, 6647, 2504, 2869, 3774, 3436, 1855, 6168, 1905, 3091, 1107],
#  [1830, 1905, 3091, 1107],
#  [4330,
#   5779,
#   1172,
#   116,
#   2869,
#   1331,
#   3615,
#   2558,
#   1315,
#   6220,
#   3167,
#   710,
#   3267,
#   6140,
#   4898,
#   2558,
#   1315,
#   6220,
#   3167],
#  [4881, 166, 583, 4477],
#  [5073, 4499],
#  [2041, 4913, 5779, 1172],
#  [3286, 5911, 6912, 1287, 610, 3512, 2644, 6556, 2041, 4913, 6051, 2253, 116],
#  [2041, 2877, 6576, 3091, 3774, 3436, 6168, 4559, 5423, 404, 2778, 5928, 2312],
#  [5305,
#   2877,
#   6381,
#   2626,
#   3419,
#   3091,
#   1107,
#   6894,
#   3091,
#   1107,
#   1235,
#   3091,
#   1107,
#   1905,
#   3091,
#   1107],
#  [2041, 4913, 2703, 3867, 6370],
#  [5911,
#   5400,
#   2795,
#   5130,
#   5480,
#   1695,
#   4410,
#   4334,
#   3374,
#   2602,
#   3306,
#   4420,
#   6645,
#   4559,
#   5928,
#   116,
#   5147,
#   6791,
#   5591],
#  [5911, 5679, 1695],
#  [6518, 5911, 2589, 6822, 1695],
#  [6912,
#   4334,
#   6074,
#   5073,
#   1197,
#   3028,
#   4094,
#   1197,
#   963,
#   1853,
#   6324,
#   6440,
#   5686,
#   913,
#   2651,
#   2455,
#   2326,
#   3319,
#   5934,
#   2492,
#   6583,
#   5185,
#   5928,
#   1197],
#  [5419, 554, 3158, 5394, 6725],
#  [4474, 6645, 752, 2745, 4098, 3267, 4098, 4662, 2132, 993],
#  [1050, 2761, 3016, 3912, 5572, 4066],
#  [6168,
#   1316,
#   2722,
#   2329,
#   1316,
#   4222,
#   2044,
#   5472,
#   2877,
#   4222,
#   456,
#   4222,
#   2703,
#   3016,
#   3551,
#   4015,
#   116,
#   1695,
#   3016,
#   2129,
#   6427,
#   1742,
#   1514],
#  [1742, 1292, 88, 1352],
#  [6518, 4293, 2795, 285, 6178, 170, 2730],
#  [2041,
#   1528,
#   3316,
#   1218,
#   1242,
#   3723,
#   3723,
#   4662,
#   4996,
#   4098,
#   1242,
#   3252,
#   5679,
#   925,
#   1885,
#   6278,
#   5185,
#   1481,
#   933],
#  [2041, 2703, 1055, 1828, 4624],
#  [4334, 6074, 710, 3267, 1242, 2041, 1695, 1481, 6906, 2766, 5965, 4565, 5472],
#  [5934, 456, 5070, 3562, 2041, 3167, 710, 3267, 1242],
#  [2223, 1238, 2795, 1695, 1298, 2644, 311, 1742, 2761, 116],
#  [2393,
#   3182,
#   925,
#   6722,
#   3850,
#   3182,
#   6771,
#   1468,
#   6822,
#   3182,
#   1504,
#   1468,
#   2393,
#   6624,
#   1289,
#   1352,
#   1987,
#   2546],
#  [5934,
#   3016,
#   2703,
#   2457,
#   166,
#   6694,
#   4077,
#   5911,
#   3809,
#   3182,
#   3149,
#   1242,
#   1033,
#   5467,
#   4774,
#   1645,
#   2202,
#   126,
#   6017,
#   2393,
#   1736,
#   1619,
#   4883,
#   3770],
#  [2219, 3692, 5911, 1742, 1242, 5842],
#  [3016, 2434, 35, 4028, 3182, 2434, 4474, 6645],
#  [1742,
#   4474,
#   6645,
#   3016,
#   6390,
#   4909,
#   4474,
#   6645,
#   406,
#   2202,
#   5423,
#   5682,
#   2264,
#   2041],
#  [1041, 2654, 5682, 2041],
#  [2545, 5926, 5733, 2202, 5682, 3518, 5682],
#  [5423,
#   1742,
#   2219,
#   554,
#   1975,
#   2132,
#   554,
#   6912,
#   5611,
#   2219,
#   2545,
#   3182,
#   1218,
#   4662,
#   2041,
#   5423,
#   5682,
#   3639,
#   2041],
#  [2219, 5095, 5423, 4265, 285],
#  [3809, 5934, 456, 3016, 3339, 4833, 5243],
#  [236,
#   876,
#   554,
#   3158,
#   4194,
#   3016,
#   1482,
#   166,
#   2746,
#   2202,
#   3016,
#   1998,
#   6168,
#   362,
#   116],
#  [2761, 1247],
#  [2691,
#   1977,
#   4428,
#   6553,
#   2144,
#   3641,
#   3933,
#   3091,
#   2069,
#   126,
#   3612,
#   4809,
#   3641,
#   3933,
#   3091,
#   2069,
#   126],
#  [4077,
#   1977,
#   3267,
#   3641,
#   3933,
#   3091,
#   3612,
#   3267,
#   6397,
#   2144,
#   3641,
#   3933,
#   3091,
#   2069,
#   126],
#  [6518, 5611, 2746, 1934, 4559, 2746, 1934, 6323, 5982],
#  [5911, 2766, 3632],
#  [5911, 3306],
#  [5911,
#   718,
#   481,
#   6440,
#   5686,
#   3556,
#   4631,
#   3809,
#   2093,
#   2545,
#   2703,
#   2670,
#   5682,
#   2326,
#   3809,
#   5782,
#   1521,
#   4559,
#   3809,
#   6323,
#   1521,
#   4654],
#  [4015, 6583, 4066, 3013, 4559, 5536, 6518, 3446],
#  [4130,
#   5147,
#   6791,
#   5591,
#   3016,
#   3575,
#   3306,
#   6832,
#   3016,
#   2920,
#   5679,
#   1910,
#   3016,
#   1885,
#   5190,
#   3484,
#   6679,
#   2347,
#   975,
#   163,
#   134,
#   2471],
#  [6168, 2920, 2702],
#  [5600, 3016, 1646, 2702, 3016, 5353, 6220, 1729, 6735, 5915],
#  [1839,
#   96,
#   2222,
#   5928,
#   116,
#   5070,
#   3562,
#   5070,
#   4205,
#   1289,
#   583,
#   4662,
#   6140,
#   4898,
#   5928,
#   116,
#   3016,
#   1885,
#   6894,
#   3641,
#   3933,
#   2511,
#   5686,
#   1910],
#  [4868, 1982, 5911, 2347, 2223, 1742, 300, 2920, 2702, 5253, 5647, 5185],
#  [5911,
#   5070,
#   695,
#   1337,
#   2219,
#   554,
#   3158,
#   6257,
#   2722,
#   2329,
#   285,
#   521,
#   6220,
#   4114],
#  [5911,
#   5934,
#   1156,
#   4063,
#   1114,
#   4222,
#   554,
#   3158,
#   1514,
#   5733,
#   521,
#   6220,
#   4114,
#   844,
#   5686],
#  [2253, 948, 1035, 2234, 5686],
#  [554,
#   3158,
#   5934,
#   3381,
#   2219,
#   4222,
#   2504,
#   2219,
#   6178,
#   170,
#   2730,
#   3016,
#   2347,
#   4474,
#   6645],
#  [5400, 2234, 5686, 3575, 4474, 6645],
#  [5934, 3016, 2703, 3575, 3306, 1476, 6791, 5591, 5147],
#  [6791,
#   5591,
#   5147,
#   148,
#   5611,
#   2199,
#   5400,
#   5225,
#   6822,
#   6822,
#   6822,
#   1284,
#   6679,
#   2219,
#   975,
#   3575,
#   1284,
#   6679,
#   1877,
#   249,
#   3575,
#   2761,
#   2202,
#   1287,
#   6679,
#   3091],
#  [1742,
#   1514,
#   275,
#   4662,
#   993,
#   3774,
#   3436,
#   554,
#   3016,
#   1287,
#   6178,
#   170,
#   2730,
#   4474,
#   6645,
#   3016,
#   4961,
#   4474,
#   6645,
#   5536,
#   4474,
#   6645,
#   5686],
#  [3016,
#   6074,
#   4222,
#   554,
#   3158,
#   456,
#   3551,
#   2219,
#   6553,
#   6694,
#   5733,
#   2234,
#   5686,
#   1646,
#   2702],
#  [1742,
#   1975,
#   3562,
#   3562,
#   1975,
#   1742,
#   3016,
#   4077,
#   2225,
#   3912,
#   6822,
#   5716,
#   682,
#   4028,
#   3933,
#   2202,
#   6140,
#   3091,
#   5716,
#   682,
#   4028,
#   3933,
#   3436],
#  [6178, 170, 2730, 3016, 1287, 4474, 6645],
#  [3908, 4335],
#  [3016, 6074, 3182, 3639, 496, 4292, 5911, 3306, 2445, 4868, 3182, 3574],
#  [6912,
#   6074,
#   4130,
#   6658,
#   4130,
#   148,
#   6822,
#   3699,
#   1214,
#   4000,
#   3774,
#   3436,
#   1419,
#   2264,
#   4000],
#  [1107,
#   2226,
#   3731,
#   2795,
#   5602,
#   4745,
#   1694,
#   6822,
#   3031,
#   2297,
#   1518,
#   3910,
#   554,
#   2682,
#   3419,
#   6035,
#   2795],
#  [1298, 5743, 2795],
#  [1419, 6822, 406, 6822, 2219, 5743, 4218, 2515, 2795],
#  [935, 3019, 3091],
#  [993, 1055, 6822, 3419, 3091, 6822, 4293, 2795, 6822, 2795, 554, 1289, 5540],
#  [6763,
#   6763,
#   6822,
#   4533,
#   3419,
#   682,
#   912,
#   2253,
#   661,
#   4340,
#   6645,
#   3774,
#   3436,
#   6038,
#   554,
#   847,
#   4663,
#   4969],
#  [4130, 3512, 2414, 459, 1289, 6168, 3774, 3436, 3306, 5330, 1218],
#  [1514,
#   844,
#   2746,
#   4114,
#   6168,
#   3306,
#   2316,
#   844,
#   2746,
#   4114,
#   166,
#   2095,
#   1218,
#   2219,
#   6553,
#   6759],
#  [5911, 2714, 1416, 661, 6645, 3306, 1289],
#  [2439,
#   4337,
#   3199,
#   6822,
#   2316,
#   6771,
#   4114,
#   1542,
#   1855,
#   2095,
#   1218,
#   2219,
#   6553],
#  [844, 312],
#  [844, 312, 2222],
#  [3699,
#   22,
#   6679,
#   5278,
#   6679,
#   4075,
#   6007,
#   4075,
#   1645,
#   3184,
#   1900,
#   4066,
#   2913,
#   1885,
#   5915,
#   2682,
#   3267,
#   456,
#   5915,
#   2682,
#   3419,
#   5602,
#   5584,
#   1900,
#   6688,
#   5928,
#   1250],
#  [3918, 5400, 5576, 1742, 3918, 3699, 6822, 6007, 6766],
#  [4293, 2795, 1050],
#  [4292, 1727, 4335],
#  [1646, 2702, 2761, 3770, 1156, 3207, 1562, 3182, 3606, 3182, 3918],
#  [2464, 4270, 2123, 3921, 4130, 1866, 3921, 1055, 4130, 2316, 5394, 6009],
#  [993,
#   2114,
#   4222,
#   5611,
#   4652,
#   5911,
#   2545,
#   4420,
#   6323,
#   5982,
#   5633,
#   698,
#   2746,
#   2019,
#   993,
#   4280,
#   5070,
#   3562,
#   1050,
#   6215,
#   993,
#   6822,
#   3910,
#   3534,
#   6215,
#   3910,
#   4222],
#  [2041, 2746, 2202, 3575, 6323, 5982, 1176],
#  [6679,
#   3306,
#   3436,
#   3436,
#   5767,
#   2264,
#   6236,
#   3306,
#   1197,
#   3028,
#   6323,
#   5982,
#   2326,
#   4229,
#   4094,
#   138,
#   1197,
#   6607,
#   1197,
#   4969],
#  [2439, 5911, 6766, 4222, 5611, 3397, 6557],
#  [6518,
#   4763,
#   456,
#   6822,
#   2722,
#   2329,
#   3016,
#   4077,
#   2766,
#   5965,
#   6679,
#   2114,
#   2126,
#   2702],
#  [1510,
#   1513,
#   1510,
#   6109,
#   948,
#   1055,
#   3419,
#   3091,
#   2722,
#   935,
#   844,
#   1284,
#   1736,
#   1284,
#   6894,
#   3641,
#   3933],
#  [5920, 5911, 3134, 3436, 3754, 2440],
#  [5920, 1742, 170, 5558, 300, 2920, 2702, 4066, 5779, 6168],
#  [6912, 406, 1352],
#  [5031,
#   406,
#   1352,
#   6557,
#   554,
#   1352,
#   6822,
#   2545,
#   3933,
#   1905,
#   4662,
#   4898,
#   1977,
#   4990],
#  [275, 2297, 6557, 2297, 275, 6822, 993],
#  [563,
#   4106,
#   6557,
#   3933,
#   3457,
#   4655,
#   3050,
#   3867,
#   5679,
#   2795,
#   6557,
#   1352,
#   2795,
#   329],
#  [2795, 818, 5928, 4106, 1352, 2219, 776, 6571, 2219, 5733, 2297, 554],
#  [6518, 6557, 2746, 1934, 4559, 1352, 554],
#  [275, 3731, 3362, 2297, 1518],
#  [6061, 6340, 4969],
#  [948,
#   5512,
#   3031,
#   3267,
#   6038,
#   6340,
#   4969,
#   2132,
#   973,
#   6553,
#   2722,
#   993,
#   2276,
#   1934,
#   4559,
#   1352,
#   3362,
#   2297],
#  [4130, 4293, 2795, 1050],
#  [2114,
#   6168,
#   4403,
#   163,
#   1934,
#   1197,
#   5633,
#   2691,
#   5936,
#   4868,
#   2746,
#   2202,
#   2234,
#   6323,
#   2453],
#  [3436, 925, 5767, 2264, 6679, 3016, 665, 1197, 3028, 6323, 5982],
#  [6822,
#   4293,
#   2795,
#   2913,
#   6522,
#   1218,
#   6168,
#   2746,
#   2202,
#   3575,
#   1176,
#   6323,
#   5982,
#   1247,
#   554,
#   4035],
#  [6822,
#   5911,
#   5073,
#   993,
#   2746,
#   2202,
#   6822,
#   3575,
#   6323,
#   5982,
#   4742,
#   5073,
#   2504,
#   554,
#   3158,
#   6522,
#   3091,
#   5977,
#   5093,
#   4632,
#   583,
#   2114,
#   1934,
#   1197,
#   3028,
#   912,
#   27,
#   1934,
#   6323,
#   5982,
#   6722,
#   163,
#   4652,
#   4598],
#  [4130, 2746, 2202, 1934, 6323, 5982],
#  [406],
#  [6017, 406, 5073, 2041, 146, 6323, 5982],
#  [818, 146, 6323, 5982],
#  [148, 2041, 4559, 243, 2746, 2019],
#  [2746,
#   2202,
#   5572,
#   5679,
#   3575,
#   6323,
#   4745,
#   2326,
#   1943,
#   5679,
#   5480,
#   3923,
#   2234,
#   6323,
#   2453],
#  [5911, 3016, 333, 1695, 5911, 3016, 333, 2453, 1804],
#  [4218, 5934, 456],
#  [2114, 146, 5982, 6323],
#  [554,
#   3158,
#   583,
#   6522,
#   3091,
#   5093,
#   4632,
#   163,
#   5572,
#   146,
#   5982,
#   6323,
#   5611,
#   1197,
#   3028,
#   2761,
#   4094,
#   1197,
#   963,
#   416,
#   3436,
#   6679,
#   5884,
#   2234,
#   3923,
#   6323,
#   5982],
#  [148,
#   5934,
#   1287,
#   5540,
#   2746,
#   2202,
#   3575,
#   49,
#   6323,
#   5982,
#   4094,
#   2093,
#   3436,
#   3306,
#   1289,
#   5540,
#   166],
#  [6168, 1862, 5307, 4094, 2093, 3436, 456, 5540],
#  [6323,
#   5982,
#   3072,
#   5777,
#   2682,
#   1242,
#   1055,
#   3419,
#   3091,
#   6102,
#   3267,
#   1242,
#   435,
#   5982],
#  [5305],
#  [6168, 163, 5572, 5982, 6323, 2746, 2202, 5572, 4814, 1742],
#  [5939,
#   2531,
#   4077,
#   2019,
#   249,
#   2594,
#   6587,
#   3182,
#   1258,
#   2746,
#   2202,
#   5679,
#   4559,
#   1438,
#   5679,
#   2202],
#  [1247, 554, 6679, 3016, 6203, 3436],
#  [2132, 2329, 4077],
#  [6658, 6474, 4292],
#  [3381, 6658, 5227, 2264, 6658, 5227, 6074],
#  [1331,
#   3286,
#   579,
#   1033,
#   1033,
#   4652,
#   6121,
#   6324,
#   1990,
#   1742,
#   1114,
#   4663,
#   1990,
#   4786,
#   2499,
#   5156,
#   5095,
#   6652,
#   5095],
#  [579,
#   1420,
#   6090,
#   456,
#   6121,
#   6621,
#   2182,
#   6587,
#   5788,
#   2186,
#   5480,
#   1420,
#   6587,
#   6220,
#   3016,
#   3339,
#   166,
#   1242,
#   5788,
#   5761,
#   5788,
#   2186,
#   2535,
#   1695,
#   4025],
#  [6822,
#   456,
#   6121,
#   579,
#   1331,
#   579,
#   1033,
#   1047,
#   456,
#   6121,
#   6556,
#   2498,
#   2558,
#   5571,
#   6657,
#   2795,
#   1620,
#   1889,
#   935],
#  [300,
#   1645,
#   1592,
#   2795,
#   4969,
#   5134,
#   721,
#   5928,
#   116,
#   3639,
#   2703,
#   6121,
#   6657,
#   300,
#   1645,
#   5911,
#   5073,
#   5766],
#  [1866, 554, 3158, 3199, 6257, 6363, 6757, 4969, 1114, 5766],
#  [3016,
#   3199,
#   406,
#   5947,
#   3016,
#   4320,
#   1238,
#   4969,
#   956,
#   5134,
#   4676,
#   6089,
#   6912,
#   300,
#   3774,
#   3436],
#  [6912,
#   3016,
#   6074,
#   4972,
#   2393,
#   6822,
#   6688,
#   1734,
#   2455,
#   6822,
#   5070,
#   3562,
#   3912,
#   4635,
#   6257,
#   3918,
#   4774,
#   1645],
#  [5070,
#   4774,
#   3731,
#   6913,
#   2095,
#   6822,
#   710,
#   3267,
#   1987,
#   903,
#   6822,
#   3500,
#   5330,
#   3774,
#   3436,
#   1382,
#   4684,
#   5134,
#   2019,
#   860,
#   5602,
#   3050,
#   3912,
#   5214,
#   2455,
#   406,
#   5686,
#   5249,
#   3091,
#   2877,
#   1055,
#   3419,
#   3091],
#  [4467,
#   406,
#   5214,
#   1830,
#   2440,
#   1055,
#   1905,
#   3091,
#   2722,
#   3419,
#   3091,
#   2132,
#   3673,
#   5214,
#   1382,
#   116],
#  [6556,
#   6822,
#   5134,
#   721,
#   6822,
#   3064,
#   4969,
#   2860,
#   6121,
#   1791,
#   1298,
#   935,
#   5934,
#   5920,
#   3908,
#   6556,
#   2019,
#   5134],
#  [6556,
#   1990,
#   4151,
#   5156,
#   4913,
#   1592,
#   2188,
#   3053,
#   5911,
#   2219,
#   4343,
#   1674,
#   4075,
#   4091,
#   1695,
#   5470,
#   3496,
#   1990],
#  [5911, 3467, 4822, 6090, 148],
#  [4307,
#   353,
#   1742,
#   4151,
#   5760,
#   6759,
#   682,
#   2746,
#   2202,
#   3053,
#   4635,
#   3091,
#   5911,
#   6822,
#   5779,
#   6722,
#   6553,
#   6382,
#   3484,
#   2861],
#  [6912,
#   5911,
#   2746,
#   2202,
#   5779,
#   1742,
#   3049,
#   5611,
#   6822,
#   5911,
#   3016,
#   5394,
#   6822,
#   5928,
#   5824],
#  [3374, 5893, 372, 6219, 1468],
#  [682, 6504],
#  [3512, 2316, 2019, 5306, 6912],
#  [3286, 847, 579, 456, 6121, 6657],
#  [1885, 6107, 2902, 3809, 912],
#  [3016, 3199, 4222, 925, 285],
#  [4130, 6906, 5934, 5920, 459, 2041, 683, 3774, 3436],
#  [2761, 1742, 1242],
#  [4130, 1645, 4784, 6694],
#  [2129, 6168, 1742, 362, 2081, 6870, 682, 4996, 4028, 243, 6587],
#  [6168,
#   1742,
#   554,
#   3158,
#   1514,
#   1363,
#   4233,
#   2081,
#   6870,
#   6168,
#   1862,
#   1742,
#   3016,
#   683,
#   2133,
#   5974,
#   5679,
#   818,
#   1695,
#   5572,
#   3057],
#  [3180,
#   5934,
#   3016,
#   3339,
#   2703,
#   554,
#   3158,
#   3199,
#   6257,
#   2505,
#   1256,
#   2480,
#   645,
#   1535,
#   4343],
#  [1868, 6906, 3149, 5939, 622, 5974, 4292, 2683],
#  [1866, 2761, 2480],
#  [1866, 2761, 1528, 3182, 5738],
#  [1866, 554, 3158, 27, 1954, 6168, 5880, 4000, 6090, 2761, 5736, 4000],
#  [3019, 3091, 1382, 912, 6658, 6822, 2202, 2877],
#  [6518, 5911, 4130, 6822, 1742, 1514, 459, 2440, 683],
#  [4307,
#   2722,
#   459,
#   4886,
#   2860,
#   5090,
#   4454,
#   5329,
#   293,
#   601,
#   4774,
#   5611,
#   5928,
#   1742,
#   2044,
#   5472],
#  [5070, 3562, 4307, 2132, 459],
#  [6279],
#  [948,
#   1055,
#   1905,
#   4662,
#   3091,
#   2132,
#   5130,
#   329,
#   2746,
#   1934,
#   4559,
#   6178,
#   170,
#   2730,
#   5147,
#   134,
#   2471,
#   5147,
#   6791,
#   5591],
#  [5911, 5070, 3562, 5766, 2499, 459],
#  [1019, 3016, 3418],
#  [3016, 5602, 3050, 2434, 3419, 6553, 5249, 5470],
#  [5934, 3731, 935, 3091],
#  [692,
#   5528,
#   188,
#   6529,
#   1054,
#   4711,
#   3809,
#   2129,
#   2439,
#   3374,
#   6478,
#   2636,
#   5766,
#   5306,
#   3692],
#  [490, 4066, 1837, 4066, 4552, 3774, 3436, 3939, 5542, 1837],
#  [3374, 2860, 4531, 2202, 2966, 3908, 903],
#  [4531, 5540, 6542, 3374, 1382, 5572, 13, 3374, 6822, 4531],
#  [5572, 4531, 3374, 5190, 5400, 1742, 6240, 1528, 6531, 1468, 1887],
#  [3016,
#   4222,
#   1887,
#   1468,
#   2054,
#   1742,
#   554,
#   3158,
#   3199,
#   3016,
#   2234,
#   5134,
#   2219,
#   3016,
#   6542,
#   3374,
#   3575,
#   3374,
#   5576,
#   6822,
#   3167,
#   4531],
#  [6912, 3016, 3199, 5070, 88, 6822, 1866, 2795, 4742, 5671, 4598],
#  [6822,
#   3016,
#   148,
#   3199,
#   6763,
#   4763,
#   2504,
#   5911,
#   3016,
#   297,
#   2795,
#   3774,
#   3436,
#   2752,
#   6822,
#   5580,
#   6038,
#   408,
#   2486,
#   456,
#   6121,
#   456,
#   3091,
#   1031,
#   1164],
#  [2795,
#   2385,
#   4420,
#   4384,
#   3249,
#   5572,
#   403,
#   2041,
#   2496,
#   1571,
#   5633,
#   2752,
#   4720,
#   2900,
#   2253,
#   948,
#   935],
#  [6074],
#  [3091, 3583, 6220, 6645, 5039],
#  [2496],
#  [6763, 3908, 2499],
#  [6763, 2795, 456, 3867, 4533, 6556, 6699, 1453, 1660, 2253],
#  [2795, 2966, 403],
#  [5986, 403, 1139],
#  [6074, 456, 4533],
#  [3016, 6074, 2795, 1791, 5698, 4720, 6048, 2703, 376, 4533, 2795, 2703, 4533],
#  [1571, 1258, 672, 2966],
#  [4366, 5073, 1868, 3374, 3306, 2069, 912],
#  [5911, 6658, 1905, 5918, 243, 5306, 925, 490],
#  [4841, 2202, 5540, 5572, 3374, 4565, 2069, 2202, 3921],
#  [5911, 5056, 3943, 5911, 5056, 1214],
#  [3374, 3496, 2219, 5306, 6746, 1525, 3774, 3436],
#  [6746, 1525, 3496, 2219, 5306, 6822],
#  [3374, 4066, 5806, 2570, 6458, 4028, 3091, 5911, 3016, 5915, 4552, 1695],
#  [5911, 2129, 2202, 5942, 2766, 2219],
#  [6518, 5939, 2069, 6531, 4075, 5766, 2019, 1885, 793, 4440, 1242, 2920],
#  [1912,
#   5611,
#   5134,
#   5185,
#   1461,
#   3167,
#   5056,
#   5178,
#   6822,
#   4531,
#   6397,
#   3641,
#   3933,
#   4265],
#  [6822, 146, 5686, 468, 4435, 3374, 1055, 3091, 2055, 6531, 1468, 3809, 3091],
#  [5911, 6531, 4075, 275],
#  [2626, 4614, 5125],
#  [2439,
#   3199,
#   3708,
#   1770,
#   5611,
#   2746,
#   2202,
#   3425,
#   3374,
#   1770,
#   3073,
#   1885,
#   793,
#   4440,
#   2920,
#   3073,
#   5766,
#   3167,
#   2019,
#   4662,
#   5716,
#   6140,
#   4898,
#   4531,
#   3534,
#   5134,
#   1235,
#   1905,
#   6140,
#   4898],
#  [5911, 5070, 652, 1742, 275],
#  [4334,
#   6074,
#   4652,
#   4293,
#   2795,
#   6257,
#   3374,
#   4652,
#   4292,
#   6168,
#   166,
#   6474,
#   5070,
#   652],
#  [5911, 2545, 5766, 4614, 2019],
#  [5911, 5611, 5134, 6215, 4705, 5306, 5134, 1055, 6759, 3091, 5070, 652, 2228],
#  [2439, 6168, 6345, 5305, 6819, 3943, 1258, 6906, 1019, 2515, 1214],
#  [456,
#   3199,
#   818,
#   5779,
#   1176,
#   2202,
#   2019,
#   3199,
#   3016,
#   148,
#   2761,
#   2234,
#   5134,
#   6822,
#   3620,
#   3575,
#   3167,
#   2627,
#   6751,
#   5243,
#   3374,
#   6822,
#   2019,
#   2464,
#   1855,
#   3381,
#   3615],
#  [5911, 1513, 1176],
#  [1742, 1514, 2219, 1270, 2069, 1742, 236],
#  [3267, 2722, 993],
#  [776, 6178, 170, 2730, 4850, 3306, 1905, 4662, 3091, 4474, 6645],
#  [363, 2041, 4913, 6588, 6257, 3809, 570, 1100],
#  [6694, 5911, 1695, 2703, 3013, 4652, 2761, 2644, 5474],
#  [6527,
#   719,
#   3179,
#   3467,
#   148,
#   3383,
#   5579,
#   3267,
#   4618,
#   2219,
#   5249,
#   166,
#   698,
#   5572,
#   2651,
#   1197,
#   2267,
#   719],
#  [2219, 776, 166, 698, 5572, 1604, 2267, 4151],
#  [776, 166, 698, 1277, 1238, 5249, 166, 698, 2297],
#  [6822, 3267, 912, 166, 698, 5056, 4326, 2267, 719],
#  [5911, 1242],
#  [2041, 2261, 6587, 3306, 8],
#  [1866, 2041, 6588, 340, 2202],
#  [3774,
#   3436,
#   5147,
#   134,
#   2471,
#   6645,
#   4956,
#   5824,
#   5664,
#   6177,
#   3774,
#   3436,
#   2069,
#   2222,
#   4177,
#   3167,
#   6535,
#   1525,
#   3013,
#   2041,
#   4913,
#   2860,
#   5679],
#  [2041, 3436, 1289, 5540],
#  [6009, 3912, 311, 401, 4474, 3908, 1055, 1905, 4662, 3091],
#  [3182, 3774, 3436, 6017, 925, 5147, 134, 2471, 2695, 925],
#  [4384,
#   3374,
#   4892,
#   3103,
#   3374,
#   3470,
#   3374,
#   560,
#   4702,
#   3932,
#   4229,
#   3252,
#   793,
#   4440,
#   5306,
#   3692,
#   5056,
#   5997,
#   5766,
#   4614,
#   1742],
#  [2363,
#   4028,
#   6587,
#   3918,
#   1218,
#   4662,
#   4705,
#   4474,
#   6645,
#   3771,
#   3723,
#   3419,
#   3933,
#   2546,
#   2316,
#   5928,
#   6017,
#   5928,
#   4474,
#   6645,
#   5536],
#  [6168, 6218, 2202, 6168, 5766, 4614, 5125],
#  [5911, 163, 3774, 3436, 3306, 4420, 2594],
#  [163, 3306, 5779, 6168],
#  [5911, 1242, 5842],
#  [5911, 148, 6220, 5540],
#  [363, 275, 5147, 6791, 5591, 3774, 3436, 6698],
#  [363, 1528, 3006, 3339, 3288, 1693, 5024, 3503, 4913, 3774, 3436, 5474, 243],
#  [5911, 4559, 5536, 6518, 3446],
#  [1638, 1107, 2226, 583, 4130, 2264, 6220, 925, 3284, 5249, 6761, 5249, 243],
#  [1638,
#   4025,
#   5235,
#   6906,
#   4130,
#   2264,
#   4025,
#   3284,
#   5249,
#   6761,
#   5249,
#   243,
#   2264,
#   5779,
#   1176,
#   2594,
#   1176,
#   5743,
#   406,
#   2264,
#   5779,
#   1176,
#   4621],
#  [5911, 4450, 3867, 4570, 5243, 3774, 3436, 5576, 3013, 404, 5576, 2312, 4420],
#  [2044,
#   5472,
#   4340,
#   1247,
#   3016,
#   2041,
#   3544,
#   6203,
#   2439,
#   1176,
#   4079,
#   5070,
#   975,
#   1238],
#  [5070, 975, 5862, 557, 4420, 569, 3268, 5939, 4025, 3167, 5679, 2041, 4913],
#  [5217, 569, 2385, 1054, 2860],
#  [2281, 6304, 3942, 376, 5441, 300, 1695],
#  [5576, 1695, 5576, 3013, 5576, 2312, 404, 3774, 3436, 369, 2594],
#  [6912, 1289, 1416, 5779, 6168, 5911, 2594, 6645, 5235, 4025],
#  [275, 2594, 275],
#  [2439, 5911, 4130, 6587, 3182, 166],
#  [4652],
#  [4652,
#   4334,
#   3306,
#   4420,
#   3189,
#   3306,
#   4420,
#   1887,
#   6587,
#   6003,
#   1033,
#   6906,
#   4420,
#   1033,
#   6906,
#   1238],
#  [2703, 3754, 5911, 5305, 363, 6587, 3057, 2703],
#  [363, 3774, 3436, 1055, 3091, 2055, 2222, 5928, 116, 376, 1525, 3013, 4025],
#  [5928,
#   116,
#   2761,
#   2312,
#   5467,
#   2761,
#   2316,
#   5928,
#   369,
#   2761,
#   2316,
#   1289,
#   2302,
#   1033],
#  [363,
#   6397,
#   3641,
#   3933,
#   4265,
#   2989,
#   5128,
#   1855,
#   4555,
#   6278,
#   4025,
#   1855,
#   4555,
#   3267,
#   4028,
#   6587,
#   5599,
#   311,
#   2546,
#   2989,
#   6448,
#   2202,
#   4705,
#   4662,
#   4898,
#   3316,
#   6140,
#   6017],
#  [1481,
#   2129,
#   3708,
#   534,
#   3774,
#   3436,
#   5782,
#   6017,
#   2778,
#   204,
#   1197,
#   6863,
#   5185,
#   5598,
#   2486,
#   5911,
#   1289,
#   1416,
#   4091,
#   6587],
#  [363, 3809, 6323, 1760, 4961, 5782, 3306, 1197, 204, 912, 878],
#  [5911, 3306, 1242, 5842, 3306, 1289, 5540, 912, 5181, 3692, 5243, 6906],
#  [3932, 6588, 5842, 87, 6048],
#  [2041, 6017, 1289, 5540],
#  [5911, 4450, 3867, 4570, 1695],
#  [1033,
#   6168,
#   3774,
#   3436,
#   5779,
#   6168,
#   3774,
#   3436,
#   5779,
#   5911,
#   6912,
#   406,
#   403,
#   5643,
#   622,
#   1868,
#   1033,
#   2440],
#  [3467, 1645, 554, 3158, 5024, 1645, 28, 3910, 2133],
#  [3467, 3381, 1695, 2504, 5095, 500, 5679, 5095, 285, 5779, 6168],
#  [6912, 107, 2703],
#  [2440, 4774, 1645, 5686, 5249, 3091, 5686, 5249, 3091, 6636, 1645],
#  [2877, 6553, 2440, 6382, 554, 3158, 2044, 5472, 5911, 2869, 6090, 5779, 6168],
#  [6645,
#   1197,
#   1055,
#   5686,
#   5249,
#   3091,
#   6645,
#   4635,
#   5686,
#   5249,
#   2253,
#   4635,
#   1905,
#   3091],
#  [5147, 412, 5679, 5686, 5249, 3091, 5147, 4635, 1645, 5468],
#  [3774, 3436, 275, 6051, 1481, 2594, 275],
#  [3467, 4647],
#  [1868, 1287, 4345, 6906, 3149],
#  [4194,
#   4105,
#   1315,
#   6220,
#   3167,
#   2044,
#   236,
#   5031,
#   6074,
#   2877,
#   116,
#   1645,
#   4635,
#   1645,
#   2558,
#   116,
#   6822,
#   1242,
#   5686,
#   3091,
#   1645,
#   2558,
#   116,
#   2095,
#   6140,
#   4898,
#   5686,
#   3091],
#  [3673, 116, 1645, 2199],
#  [1868, 1287, 1868, 1287, 4345, 4705, 2486],
#  [5467],
#  [2869, 4990, 5777, 4662, 912, 166, 6636, 1645, 4774, 1645],
#  [5134, 3575],
#  [2869, 5134, 3575, 5351, 4662, 912, 166, 4774, 1645, 6636, 1645],
#  [4695, 3551],
#  [3091,
#   3091,
#   1268,
#   2869,
#   5716,
#   6397,
#   2144,
#   6140,
#   4898,
#   2219,
#   5178,
#   4025,
#   3615],
#  [1033, 116, 6616, 5332, 3371],
#  [2869, 6645, 1645, 4635, 1645],
#  [1055, 3091, 1156],
#  [5467, 5915, 3091],
#  [5073, 5329, 293, 2766, 4517, 4822, 6090, 2766, 4517, 3774, 3436],
#  [4465, 6587, 3013, 5779],
#  [2041, 6906, 127, 2667],
#  [2041,
#   3182,
#   4822,
#   6090,
#   3053,
#   329,
#   4881,
#   1033,
#   6090,
#   1528,
#   6694,
#   1729,
#   3864,
#   3774,
#   3436,
#   1033,
#   975,
#   1033,
#   5217,
#   569],
#  [5329, 293, 583, 6766, 4284, 6587, 3148, 2550],
#  [4130, 2594, 4420, 35, 1224, 4103, 1791, 1694],
#  [5911],
#  [5911, 3180, 2006, 4450, 5243],
#  [5911, 912, 6090, 4881, 5779],
#  [5911, 4284, 6587, 3148],
#  [4130, 3932, 2044, 396, 5313, 3774, 3436, 5633, 4841, 913, 6278, 396, 6478],
#  [4130, 6220, 3932, 2644, 5474, 3963, 5520, 5520, 3006, 3219, 3006, 5685],
#  [6168, 5520, 554, 3158, 5911, 2144],
#  [4009, 163, 1828, 6168, 5779, 6168],
#  [1829, 5394, 5063, 554, 3158, 1624, 5472, 5063, 3774, 3436, 5779, 6168],
#  [1050],
#  [5911,
#   1050,
#   3544,
#   4598,
#   5472,
#   4763,
#   456,
#   3809,
#   1226,
#   622,
#   5766,
#   3774,
#   3436,
#   2644,
#   5474],
#  [6694, 554, 3158, 583, 3809, 6906, 5419],
#  [614,
#   5472,
#   1331,
#   4763,
#   456,
#   116,
#   6220,
#   3167,
#   1055,
#   3091,
#   2055,
#   1525,
#   6220,
#   4025],
#  [6518, 1513, 4743, 2703],
#  [2041, 2703, 6478, 4767, 3754, 6556, 5572, 1025, 6652],
#  [3932, 3850, 1025, 6647],
#  [2438, 6759, 6504, 6587, 3918],
#  [5055, 6087, 3584],
#  [3774, 3436, 4652, 1695],
#  [3065,
#   554,
#   3158,
#   5788,
#   2795,
#   3154,
#   1624,
#   3397,
#   5698,
#   1679,
#   406,
#   3692,
#   5925,
#   4632,
#   2360,
#   5925,
#   4632,
#   1763],
#  [5225, 3313, 1513, 1624, 3397],
#  [3569, 1679, 3306, 1986, 5073, 6548, 4632],
#  [5877, 1528, 3774, 3436, 1791, 6478, 2863, 2041, 4913, 6687, 1025, 5441],
#  [4794, 5788, 1513, 204],
#  [5877,
#   1791,
#   1624,
#   3397,
#   5070,
#   975,
#   4720,
#   6048,
#   4648,
#   5611,
#   935,
#   4784,
#   2531,
#   4229,
#   6645,
#   3774,
#   3436],
#  [2692],
#  [3016,
#   1258,
#   6239,
#   138,
#   4969,
#   2202,
#   3919,
#   5766,
#   163,
#   5572,
#   5674,
#   3057,
#   456,
#   6382,
#   1238,
#   2219,
#   311,
#   3267,
#   5842,
#   6089,
#   5968,
#   3182,
#   2202,
#   3919],
#  [1298,
#   5911,
#   6906,
#   5419,
#   4720,
#   2202,
#   3919,
#   1298,
#   6679,
#   665,
#   3919,
#   3134,
#   5118,
#   5510,
#   5633,
#   6556,
#   4009,
#   669,
#   1478,
#   6017,
#   1635],
#  [1156, 1164, 2202, 3919, 5173, 4947, 3031, 935, 5070, 3158, 2383, 1250],
#  [3381, 6382, 2504, 5911, 1033, 6565, 5130],
#  [422, 6565, 5130, 1337, 1331, 5572, 6032, 4008],
#  [3918, 6527, 3640],
#  [614,
#   2688,
#   67,
#   2688,
#   2234,
#   5782,
#   3306,
#   6174,
#   5528,
#   4373,
#   5433,
#   3306,
#   6174,
#   6032,
#   570,
#   5572,
#   2049,
#   2080],
#  [1513, 4648],
#  [6912,
#   3925,
#   4349,
#   3774,
#   3436,
#   1176,
#   2795,
#   157,
#   4725,
#   3111,
#   6174,
#   5572,
#   406,
#   5125],
#  [3286,
#   1513,
#   5911,
#   4280,
#   4061,
#   1855,
#   3199,
#   5070,
#   975,
#   6381,
#   5806,
#   4632,
#   1624,
#   3397],
#  [3692, 1727, 683, 1868, 2774, 6074, 3918, 311, 912, 1420, 5013, 4784],
#  [803, 5095, 5013, 4784, 1618, 2132, 2329],
#  [5911, 4421, 554, 3158, 1513, 6759, 5227],
#  [2439,
#   6557,
#   138,
#   1934,
#   1352,
#   3286,
#   912,
#   3512,
#   1238,
#   2182,
#   6587,
#   1823,
#   2393,
#   3091,
#   1107,
#   5147,
#   3512,
#   1033,
#   818,
#   4822,
#   6090,
#   924,
#   3182],
#  [6168, 6324, 2312, 4025],
#  [6671, 3182, 1420, 4406, 6168, 2867, 6168, 2771, 6168, 6168, 6906],
#  [148, 4130, 243, 3182, 926, 3182, 2041, 243, 3306, 5611, 4591, 2594],
#  [926, 2438, 5911, 5576, 4216, 3918, 554, 3158, 2913, 5571, 2219, 590],
#  [6257, 1055, 5795, 5345, 2556, 926, 2219, 3316, 3016, 243],
#  [5788,
#   1645,
#   4075,
#   5788,
#   5070,
#   3562,
#   5093,
#   4632,
#   6827,
#   2502,
#   2023,
#   721,
#   3565,
#   2878,
#   3791,
#   5123,
#   5123,
#   6061,
#   1905,
#   6504,
#   4900,
#   5686,
#   3091],
#  [6518, 5788, 157, 243, 1638],
#  [5788, 283, 1645, 3912, 3867, 6618, 391, 4900, 2202, 1887, 243, 1638, 1114],
#  [776,
#   2402,
#   1102,
#   2132,
#   823,
#   1952,
#   5427,
#   2132,
#   823,
#   2515,
#   5345,
#   3943,
#   5716,
#   6134,
#   4900,
#   5350,
#   2955,
#   6241,
#   3703,
#   2955,
#   569,
#   3921,
#   5766,
#   3551],
#  [2364,
#   1934,
#   5806,
#   3791,
#   464,
#   4337,
#   6857,
#   2594,
#   4337,
#   3912,
#   6618,
#   925,
#   3912,
#   5766,
#   3615,
#   926,
#   2438,
#   2594],
#  [1019,
#   3316,
#   435,
#   5911,
#   435,
#   5806,
#   4075,
#   4091,
#   926,
#   4028,
#   3091,
#   948,
#   4091,
#   4822,
#   6090,
#   3319,
#   1242,
#   818,
#   4822,
#   6090,
#   1170,
#   1956,
#   1731,
#   6090,
#   1742,
#   3481,
#   4822,
#   6090,
#   1055,
#   3419,
#   3091,
#   11,
#   6759,
#   2546,
#   2498,
#   6822,
#   777],
#  [5070,
#   4873,
#   3199,
#   3774,
#   3436,
#   4465,
#   925,
#   1736,
#   5925,
#   4632,
#   3016,
#   4384,
#   6906,
#   1624,
#   3397],
#  [2177,
#   1862,
#   2312,
#   3699,
#   5925,
#   3912,
#   3016,
#   1982,
#   6906,
#   6849,
#   3373,
#   5602,
#   4419,
#   3319,
#   5788,
#   5540,
#   3182,
#   5847,
#   3016,
#   3381,
#   1242,
#   6906,
#   6427,
#   1833,
#   6178,
#   1620,
#   1624,
#   3397,
#   67,
#   5779],
#  [3699, 4763, 5241, 6822, 5070, 3562, 1535, 1682, 5235, 1695, 2044],
#  [1047, 1679, 4384, 5934, 5920, 4229, 6645],
#  [2776, 396, 1889],
#  [583,
#   4465,
#   5602,
#   2234,
#   4419,
#   3319,
#   5602,
#   5345,
#   1679,
#   3016,
#   5806,
#   948,
#   6168,
#   5070,
#   3562,
#   583,
#   5031,
#   4619,
#   1679,
#   3016,
#   5806,
#   1855,
#   4555,
#   5070,
#   2383,
#   5811,
#   554,
#   847,
#   4663,
#   4969,
#   3052,
#   5031,
#   2603,
#   3016,
#   3381,
#   1242,
#   1624,
#   3397,
#   3016,
#   1736,
#   5925,
#   5925,
#   3912,
#   6168],
#  [5934,
#   2385,
#   6505,
#   948,
#   1624,
#   3397,
#   2955,
#   178,
#   1624,
#   3397,
#   6636,
#   1645,
#   1624,
#   3397,
#   1679,
#   4406,
#   4370],
#  [1624, 3397, 1679, 4215, 1009, 1645],
#  [2041, 4913, 1624, 3397, 6906, 3912, 4134, 3846],
#  [5217, 569, 1624, 3397, 6906, 2371, 3846],
#  [1031,
#   1620,
#   6220,
#   3699,
#   6427,
#   403,
#   6357,
#   293,
#   4652,
#   4420,
#   4652,
#   6478,
#   148,
#   422,
#   2191],
#  [6168,
#   2129,
#   396,
#   757,
#   157,
#   1624,
#   3397,
#   3016,
#   4377,
#   5925,
#   3306,
#   3699,
#   4384,
#   5125],
#  [6168, 1768],
#  [6168, 1768, 5471, 3252],
#  [5070, 4052, 1289, 5093, 2546, 1107, 583, 1791, 2129, 1889, 6857, 1047, 3846],
#  [5540, 5130, 1998, 6168, 5997],
#  [5070, 975, 3731, 4632, 5767, 3534],
#  [5934,
#   456,
#   3754,
#   3381,
#   5522,
#   903,
#   2504,
#   4465,
#   4533,
#   3306,
#   903,
#   2482,
#   4784,
#   1035],
#  [3016,
#   1289,
#   5070,
#   975,
#   4837,
#   1440,
#   2582,
#   2018,
#   847,
#   4253,
#   823,
#   3016,
#   5345,
#   1289,
#   3016,
#   1019,
#   2515,
#   3912,
#   1990,
#   2851],
#  [3306,
#   5779,
#   1218,
#   2219,
#   6553,
#   204,
#   4420,
#   2312,
#   3484,
#   2861,
#   1055,
#   3091,
#   6168,
#   1289,
#   4404,
#   3374,
#   2795,
#   3774,
#   3436,
#   2276,
#   2198,
#   935,
#   2966,
#   2020,
#   5471,
#   2312,
#   4307,
#   372,
#   1982,
#   178,
#   3306,
#   5330,
#   5330,
#   6735,
#   5951,
#   4404,
#   1238,
#   4281,
#   2682],
#  [3306, 6255, 2312],
#  [3306, 6255, 4847],
#  [3374,
#   2795,
#   3774,
#   3436,
#   3286,
#   3091,
#   3306,
#   319,
#   6735,
#   4130,
#   369,
#   5951,
#   2302,
#   5951],
#  [2863,
#   6478,
#   5679,
#   2920,
#   2587,
#   5779,
#   3155,
#   6906,
#   4655,
#   3050,
#   5736,
#   2515,
#   4533,
#   5951,
#   6912,
#   4130],
#  [3306,
#   5925,
#   1791,
#   1289,
#   5911,
#   2281,
#   3774,
#   3436,
#   404,
#   2312,
#   404,
#   5471,
#   2312,
#   6912,
#   5928,
#   2312],
#  [1868, 6074, 2219, 6822, 5934, 3016, 300],
#  [5920],
#  [5880, 4293, 2795, 6478],
#  [2692,
#   2439,
#   4652,
#   3373,
#   4652,
#   1887,
#   3639,
#   3373,
#   1887,
#   6478,
#   5925,
#   4632,
#   3016,
#   5777,
#   170,
#   4936,
#   5070,
#   975,
#   1640,
#   2261,
#   2957,
#   1640,
#   2261,
#   3774,
#   6220,
#   5190,
#   3234,
#   3512,
#   2041,
#   6032,
#   3918,
#   1025,
#   4648,
#   2703,
#   746],
#  [6912,
#   5911,
#   178,
#   1218,
#   2219,
#   2069,
#   5928,
#   5600,
#   6822,
#   6822,
#   5686,
#   6822,
#   6324,
#   3016,
#   5927],
#  [1839,
#   2869,
#   1749,
#   3436,
#   1289,
#   2703,
#   3057,
#   2869,
#   1481,
#   3373,
#   5886,
#   5602,
#   2913],
#  [3306, 3534, 3016, 3569, 3306, 5572, 163, 5951, 2770, 2253, 2504, 2957, 4632],
#  [4130, 2233, 4784],
#  [4334, 404, 1019, 4025, 2080, 2129, 2957],
#  [3016,
#   2316,
#   596,
#   3016,
#   1853,
#   1289,
#   5400,
#   4837,
#   4936,
#   4632,
#   3016,
#   1258,
#   6906,
#   5073,
#   2377,
#   5073,
#   2377,
#   3306,
#   2515],
#  [3016, 1853, 2795, 1289, 5070, 975, 4025, 2499, 3016, 1806, 1481, 3373],
#  [3381, 5925, 4632, 2504, 2041, 2703, 6478, 4767, 3754],
#  [2795, 5474, 3306, 2795, 3374, 3267, 2546, 1156, 2219, 925, 2302, 1695, 1382],
#  [3016, 1284],
#  [1156, 3918, 4190, 4253, 2707],
#  [2199, 554, 3158, 1050, 5345, 6168, 4075, 6474, 1514, 3615],
#  [6074, 6587, 3182, 2041, 3306, 5190, 4075],
#  [3306,
#   4218,
#   5925,
#   4632,
#   4334,
#   2863,
#   6178,
#   2018,
#   823,
#   3442,
#   3436,
#   1535,
#   2018,
#   732,
#   912,
#   3545,
#   1247,
#   4936,
#   163,
#   1749,
#   3436,
#   1289,
#   2703,
#   3057],
#  [4784,
#   912,
#   1114,
#   975,
#   1695,
#   1238,
#   722,
#   4028,
#   1238,
#   2407,
#   6504,
#   3932,
#   5806,
#   5571,
#   5934,
#   4441,
#   3774,
#   3436,
#   6090,
#   6074,
#   6572,
#   4784,
#   610],
#  [948, 3016, 4545, 3016, 1481, 3867, 5738, 3016, 1481, 5674, 2872, 4066],
#  [3918, 311, 6257, 948, 3306, 3050, 912, 2095, 1218, 3306, 1289, 5540, 610],
#  [4961, 6679, 4961, 3182, 6679],
#  [300, 3641, 3933, 1823, 3575],
#  [3306, 5056, 163],
#  [2329, 3199, 2626, 5928, 116, 2626, 5766, 6000],
#  [5911,
#   148,
#   300,
#   3381,
#   554,
#   3158,
#   4222,
#   2504,
#   5877,
#   1001,
#   2329,
#   2219,
#   6657,
#   5175,
#   3854,
#   546,
#   2703,
#   2766,
#   2767,
#   5633,
#   2234,
#   5686,
#   5633,
#   435,
#   5134],
#  [5686, 5686, 5305, 3575, 2222, 3575, 3809, 912, 146, 5134, 3770, 533],
#  [3016,
#   2699,
#   2966,
#   6587,
#   3182,
#   3575,
#   5686,
#   1855,
#   4281,
#   1035,
#   4420,
#   6766,
#   4066,
#   148,
#   4420,
#   6766,
#   3933],
#  [1019, 5928, 4681],
#  [5911, 5031, 1035, 5686],
#  [2326, 3306, 1696, 4015],
#  [1823, 369, 1823, 4700, 6645, 1823, 5928, 4420, 6489, 4420, 3306, 5572, 4115],
#  [1791,
#   3865,
#   1035,
#   2129,
#   5928,
#   2223,
#   6645,
#   3016,
#   2699,
#   3199,
#   5686,
#   6324,
#   4075,
#   3016,
#   2233,
#   3774,
#   3436],
#  [6912, 5911, 5904, 4868, 5540, 6587, 3182, 1218],
#  [5994,
#   6074,
#   1638,
#   2795,
#   4403,
#   1001,
#   3774,
#   3436,
#   3050,
#   1382,
#   3016,
#   2041,
#   3182,
#   1638,
#   2767,
#   4178,
#   2191,
#   4326],
#  [6074,
#   1866,
#   1218,
#   1885,
#   11,
#   5911,
#   1885,
#   22,
#   912,
#   6822,
#   396,
#   216,
#   1019,
#   5779,
#   6168,
#   2778,
#   3774,
#   3436,
#   859,
#   3381,
#   1242,
#   5842,
#   5873,
#   4066,
#   5591,
#   3774,
#   3436],
#  [2316, 3620, 2316, 2860, 912, 2041, 4913, 2703, 3867, 5928, 6370],
#  [6168, 4075, 6121, 3731, 4349, 1749, 326, 3774, 3436],
#  [6168, 404, 6822, 5471, 2312, 5374, 6822, 4075, 1033, 5842, 2778],
#  [5779,
#   6168,
#   2545,
#   5785,
#   4066,
#   3182,
#   3484,
#   5591,
#   3620,
#   2860,
#   1695,
#   5779,
#   1768,
#   5480,
#   1242,
#   1331,
#   4025],
#  [3774, 3436, 1152, 4936, 3867, 5125, 4025, 903, 5810, 3764, 903, 1382],
#  [3016,
#   2041,
#   87,
#   1638,
#   6822,
#   2795,
#   3774,
#   3436,
#   993,
#   1498,
#   4326,
#   3016,
#   668,
#   1638],
#  [1866, 1214, 3306, 1885],
#  [3918, 1146, 6278, 481, 5185, 4420, 2594, 5185, 1289, 2594, 5235, 3732],
#  [3918, 6220, 2251],
#  [5911, 3306, 3050, 859, 1695, 1289, 5540],
#  [6556, 926, 1868, 2703, 2219, 6694, 3754],
#  [6168, 4652, 369, 3225],
#  [6478,
#   3774,
#   3436,
#   2750,
#   2750,
#   6814,
#   6587,
#   3436,
#   3971,
#   6906,
#   3583,
#   396,
#   5313,
#   3436,
#   3971,
#   6912],
#  [2722, 2132],
#  [4151, 5468, 554, 3158, 2199, 2393, 5468, 1695, 3809, 3867, 2795],
#  [163, 1638, 2795, 1695, 163],
#  [3016, 4337, 2535, 2795, 3774, 3436, 1019, 554, 3158, 1489, 6141, 1638],
#  [2326, 5576, 5806, 5911, 353, 3576, 6090, 2482],
#  [4881, 3111, 2508, 569, 1453, 1660, 3225],
#  [6822, 3252, 906, 240, 5572, 1258, 569],
#  [906, 6553, 5839],
#  [6553, 5839, 6382, 2594],
#  [3182, 3918, 2281],
#  [5911, 3381, 1453, 1660, 2504, 4130, 6553, 4745, 401, 5674, 3385, 3344],
#  [3306, 3731],
#  [2761],
#  [771, 1019, 456, 6257, 5572, 903],
#  [3442,
#   2911,
#   456,
#   5643,
#   6257,
#   5093,
#   5623,
#   1122,
#   3091,
#   1990,
#   5522,
#   903,
#   4881,
#   5345,
#   5766,
#   1420,
#   2482,
#   3537,
#   369,
#   1607,
#   3774,
#   3436],
#  [5055, 1382, 2360, 5522, 903, 1420, 2482, 771, 2246, 6912],
#  [1050, 5394, 554, 3158, 5934],
#  [1986,
#   2223,
#   369,
#   3225,
#   3699,
#   1791,
#   1238,
#   912,
#   6636,
#   2799,
#   3381,
#   3883,
#   4676,
#   5558,
#   4134,
#   5235,
#   5839],
#  [6168, 4676, 2129, 903, 5558, 5839, 2364, 5839, 3225],
#  [6168, 4652, 3225, 6168, 1289, 2302, 311, 1695, 4440, 6645, 1419],
#  [6168, 4652, 5951],
#  [5911, 6822, 4229, 2302],
#  [4349,
#   1520,
#   5070,
#   2383,
#   4349,
#   6402,
#   4424,
#   6199,
#   3809,
#   1535,
#   5911,
#   6830,
#   406,
#   698,
#   2256,
#   903,
#   5031,
#   683,
#   4025,
#   903,
#   6553,
#   5839,
#   3387,
#   369,
#   2776,
#   6581,
#   2223,
#   369,
#   3225],
#  [3182, 163, 2385, 2982, 1114, 912, 1298, 1238, 2219, 1695, 818],
#  [6168,
#   1638,
#   67,
#   5767,
#   683,
#   243,
#   4025,
#   6090,
#   6017,
#   554,
#   3158,
#   3556,
#   5345,
#   2281,
#   1638,
#   5468,
#   6451,
#   563,
#   563,
#   5227],
#  [2644],
#  [4092, 5911, 5305, 3306, 2132, 177, 4337, 6074, 1033, 993, 2132],
#  [2132,
#   4028,
#   3091,
#   1055,
#   1905,
#   4662,
#   3091,
#   1055,
#   3419,
#   3091,
#   329,
#   2297,
#   329,
#   170,
#   2730,
#   329,
#   2746,
#   1934,
#   4559,
#   329,
#   1977,
#   4990,
#   5911,
#   2440,
#   2234,
#   4648],
#  [2281, 459, 2234, 4648, 2440],
#  [2644, 6051, 6474, 1137, 6168, 5330, 1695, 2778, 1033],
#  [2644, 4648],
#  [2132, 459, 2860, 2041, 22, 1931, 2662, 2602],
#  [3317,
#   4652,
#   847,
#   4075,
#   4652,
#   6220,
#   369,
#   3551,
#   2860,
#   4454,
#   2795,
#   293,
#   2795,
#   4774],
#  [3317, 3057, 3317, 2504, 3182, 2894],
#  [2722, 459, 4886, 3317, 4648],
#  [1107, 2226, 3867, 2795, 3182, 3836, 459, 2770, 912, 5468, 459, 3317, 4648],
#  [6912, 1868, 6074, 5911, 459, 2281, 2234, 4648, 1742, 4648, 1238],
#  [3199, 5400, 312, 3447, 925, 1258, 1465, 148, 6168, 6168],
#  [1827, 682, 140, 4134],
#  [1055, 6168, 1954, 5779, 163],
#  [5779, 353, 1172, 5779, 1055, 1742],
#  [6074, 1742, 5095, 4559, 2297, 369, 5779, 6090, 353],
#  [3381,
#   2691,
#   3155,
#   459,
#   2504,
#   554,
#   3158,
#   583,
#   1256,
#   2480,
#   3057,
#   5777,
#   3057,
#   4345,
#   3912,
#   3339],
#  [5911, 3182, 1287, 6090, 3286, 5602, 459, 3286],
#  [6168,
#   3182,
#   2439,
#   2966,
#   2703,
#   6141,
#   533,
#   1476,
#   993,
#   163,
#   2259,
#   993,
#   163,
#   3640],
#  [3182, 2703, 6141],
#  [3182, 2219, 5767],
#  [5031, 2132, 5031, 2722],
#  [2761, 4403, 5130],
#  [2439, 4130, 5130, 6051, 243, 4025],
#  [5911, 5305, 554, 3158, 3306, 177, 2722, 6857, 6074, 993, 2722],
#  [1954, 6168],
#  [4533, 3180, 906, 2703, 6168, 3783, 3073, 5056, 4068, 4676, 5558, 5839, 3225],
#  [6518, 3016, 3199, 4435, 5934, 569, 6894],
#  [1827, 5602, 311, 2233, 5600, 5911, 420],
#  [5934, 6694, 1513, 5911, 3134, 4653, 6090, 2312],
#  [4403, 96, 4403, 2924, 1242, 5979, 4025, 2766, 3182, 3182, 5468],
#  [3182,
#   3306,
#   332,
#   6278,
#   3774,
#   3436,
#   3381,
#   4115,
#   2199,
#   3912,
#   3306,
#   332,
#   6278,
#   3731,
#   5679,
#   1987,
#   4774,
#   1645],
#  [3467],
#  [5911,
#   2913,
#   3199,
#   4270,
#   4442,
#   4809,
#   2363,
#   4028,
#   3182,
#   3306,
#   332,
#   6278,
#   311,
#   5795,
#   3774,
#   3436],
#  [5911, 2924, 912, 5070, 975, 2924, 1513],
#  [5911, 6074, 6551, 912, 3275],
#  [5540, 2051, 1506, 2129],
#  [3016,
#   148,
#   3339,
#   5934,
#   3381,
#   554,
#   3158,
#   4833,
#   2504,
#   5911,
#   5036,
#   4784,
#   5540,
#   5788,
#   1645,
#   5225,
#   5911,
#   1513],
#  [1645, 3385, 1453, 1660, 3385, 2466, 3385, 6699, 3385, 204, 4025],
#  [4774,
#   1645,
#   5716,
#   682,
#   4028,
#   3182,
#   5351,
#   923,
#   6139,
#   4085,
#   2900,
#   4155,
#   1695,
#   4215,
#   431,
#   569,
#   4044],
#  [1035, 2691, 6090, 5185, 404],
#  [3339, 1866, 3910, 28],
#  [2199, 5934, 554, 3158, 4103, 847, 4075],
#  [5788, 4075, 456, 1035, 3306, 2482],
#  [6912, 3286, 5419, 554, 3158, 926, 2438, 1298, 4044, 2438, 1645, 3731, 5679],
#  [1033,
#   926,
#   3615,
#   6168,
#   6427,
#   4784,
#   1156,
#   1156,
#   3050,
#   1156,
#   2692,
#   4384,
#   2219,
#   1528,
#   4900,
#   3182,
#   5572,
#   698,
#   4234,
#   3506,
#   3057,
#   2594,
#   5572,
#   4849,
#   5707,
#   3436,
#   6814,
#   6587,
#   3436],
#  [5934, 948, 3477, 926, 5070, 3791, 5679],
#  [5934, 3306, 1512, 1645, 4345, 5572, 4091, 5306, 4270, 107, 4635, 1645],
#  [3615, 6759, 6505, 2900, 2219, 926],
#  [5911, 1475, 2766, 3057],
#  [554, 3158, 148, 5345, 6556, 926, 2556, 456, 420, 926, 157, 243, 1638, 1695],
#  [5315, 554, 3158, 847, 4663, 4969, 3016, 456, 4763, 5576],
#  [2253, 948, 5586, 2018, 3373, 6017, 4784, 6478],
#  [583, 4075, 353, 3910, 28],
#  [456, 4763, 3016, 1176, 6822, 3892, 2750],
#  [5572, 4767, 3754, 554, 3158, 4334, 2414, 2414, 2682, 6553, 5788, 6906, 1513],
#  [6587, 5540, 2051],
#  [4307, 369],
#  [6168, 2233, 3225],
#  [2219, 6168, 5911, 912, 1420, 2482, 4130, 2264, 3774, 3436, 3016, 2233, 4103],
#  [4349, 1520, 583, 6694],
#  [4424, 6199, 1018, 583, 3073, 2233, 5839, 4632, 3381, 3883],
#  [5070, 2383, 3442, 3436, 583, 3387, 968],
#  [4655, 3050, 2703, 3699],
#  [6074, 2233, 204, 4349, 4103, 3225],
#  [5839,
#   140,
#   4662,
#   5716,
#   140,
#   294,
#   1431,
#   4044,
#   300,
#   4349,
#   3584,
#   6382,
#   682,
#   140,
#   3225],
#  [6074, 1742, 5130, 275, 1742, 5130, 6090, 818],
#  [6912,
#   3774,
#   3436,
#   6822,
#   1226,
#   3073,
#   6822,
#   1360,
#   3796,
#   2682,
#   391,
#   6553,
#   2681,
#   3252,
#   4403,
#   1902,
#   5190,
#   3225],
#  [5766, 5842, 163],
#  [6168, 278, 2920, 2702, 4837, 6220, 1729, 4837, 35, 5915],
#  [583, 1055, 6134, 6168, 2920, 2702],
#  [6518,
#   5070,
#   3562,
#   5806,
#   3436,
#   3436,
#   1055,
#   6134,
#   1128,
#   2455,
#   2722,
#   2702,
#   3016,
#   4231,
#   6822,
#   2329,
#   3016,
#   4077],
#  [3134, 67, 1289, 6168],
#  [5572, 3809, 2129, 1521, 343],
#  [6168,
#   2877,
#   2455,
#   5031,
#   1962,
#   1695,
#   6735,
#   6168,
#   5055,
#   1606,
#   1695,
#   4025,
#   3182,
#   5572,
#   1521,
#   2989],
#  [2234,
#   2219,
#   3912,
#   412,
#   2364,
#   3798,
#   3774,
#   3436,
#   1905,
#   4662,
#   4028,
#   2776,
#   5070,
#   652,
#   6912,
#   96,
#   1521,
#   96],
#  [5307, 2766, 3809, 682, 6504, 3182, 6822, 1521, 96],
#  [6573, 4453, 3912, 412, 3692, 3798],
#  [5070,
#   652,
#   5811,
#   2989,
#   2481,
#   4068,
#   583,
#   1905,
#   4662,
#   4028,
#   6587,
#   925,
#   3850,
#   5198,
#   3275,
#   4077,
#   3447],
#  [6912,
#   5070,
#   3562,
#   6822,
#   1258,
#   6581,
#   5070,
#   6783,
#   3222,
#   554,
#   6783,
#   3222,
#   6807,
#   3888,
#   6038,
#   2132,
#   6038,
#   6319,
#   1592,
#   554,
#   490,
#   4969,
#   5811,
#   583,
#   1905,
#   5716,
#   4028,
#   6587,
#   1468,
#   3850,
#   731,
#   3447],
#  [5540, 4442, 311, 912, 1506, 2129, 5877, 5806],
#  [4837,
#   35,
#   5915,
#   5635,
#   2126,
#   2702,
#   5468,
#   2934,
#   3641,
#   3933,
#   1028,
#   1645,
#   5468,
#   3774,
#   3436],
#  [6518,
#   6168,
#   3539,
#   3381,
#   1242,
#   3774,
#   3436,
#   2364,
#   2489,
#   1934,
#   1114,
#   1837,
#   4025,
#   4531,
#   5471,
#   5228,
#   4564,
#   6759,
#   682,
#   4028,
#   3933,
#   4531,
#   5471,
#   5228,
#   2592],
#  [2877,
#   5928,
#   3057,
#   1695,
#   4774,
#   1645,
#   6636,
#   1645,
#   2869,
#   311,
#   609,
#   6763,
#   3867,
#   5965,
#   2313,
#   3057,
#   1645,
#   2219],
#  [2451, 3168, 1742, 275],
#  [3339,
#   5934,
#   1055,
#   5716,
#   3091,
#   2722,
#   935,
#   6038,
#   521,
#   1905,
#   4028,
#   3933,
#   1731,
#   6090,
#   1742],
#  [554, 3158, 1158, 1107, 1337, 948, 1521, 1731, 6090, 1742, 4822, 6090],
#  [6912,
#   818,
#   1331,
#   5928,
#   4420,
#   818,
#   6489,
#   4420,
#   818,
#   1990,
#   818,
#   1742,
#   6178,
#   5058,
#   5766,
#   6382],
#  [5961, 818, 4850, 6906],
#  [2252, 2119, 329, 3053, 4822, 6090],
#  [6633, 903, 4841, 2252, 5147, 1742, 5965],
#  [311, 912, 3774, 3436, 2219, 6857, 6857, 6478, 5928],
#  [6255, 6551],
#  [1033, 993, 3774, 6220, 3943, 5686, 5249, 3091],
#  [2219, 6857, 6857],
#  [148, 521, 3267, 3641, 3933, 4700, 6645, 1055, 5716, 3091],
#  [1033, 1331, 993, 5760],
#  [3016,
#   3199,
#   2789,
#   6849,
#   975,
#   6822,
#   2313,
#   3774,
#   6220,
#   2877,
#   2795,
#   6636,
#   5948,
#   6257,
#   2069,
#   912,
#   569,
#   6551,
#   4025,
#   912,
#   3275,
#   6587,
#   6551,
#   912,
#   2651],
#  [554, 3158, 5848, 5934],
#  [3286, 4105, 6551, 912, 3275],
#  [3381, 2069, 5571, 2504, 5911, 912, 5511, 5241, 3774, 3436, 1287],
# ...
#  [5911, 5926, 3754, 2439, 1214],
#  [6168,
#   1645,
#   6763,
#   5540,
#   1055,
#   3419,
#   3091,
#   5679,
#   4663,
#   569,
#   2570,
#   5330,
#   5017,
#   912,
#   1218,
#   4837,
#   3774,
#   3436,
#   3253,
#   5779,
#   4837,
#   4881,
#   3306,
#   6168,
#   6168,
#   3306,
#   1289,
#   5540,
#   3182,
#   1481,
#   2594],
#  [6658],
#  [5070, 3562, 204, 1645],
#  [6822, 3754, 4533, 1055, 3419, 3091],
#  [4115, 6553, 682, 1695, 3053, 818, 3108, 5130, 3313],
#  [5190, 2087, 5760, 6908, 2451, 6203, 3053, 3091],
#  [3053, 3774, 3436, 1242, 4822, 6822, 3053],
#  [5920,
#   1824,
#   2703,
#   4015,
#   6220,
#   396,
#   5441,
#   2438,
#   6551,
#   4822,
#   6090,
#   2795,
#   1987,
#   5862,
#   3632,
#   2691,
#   6913,
#   157,
#   2955,
#   622,
#   2556,
#   2281,
#   5572,
#   993,
#   5611,
#   2955,
#   4822,
#   6090],
#  [1050,
#   4366,
#   6478,
#   3774,
#   3436,
#   5920,
#   1824,
#   5911,
#   3306,
#   1885,
#   2281,
#   3551,
#   1695,
#   1218],
#  [6009, 5070, 3562, 1247, 6587, 3182, 2703, 3699, 5911, 2281, 3699],
#  [2795, 6636, 5779, 2405, 6522, 2782, 3374, 3267, 3091, 5788, 3091],
#  [6168,
#   6587,
#   3182,
#   2703,
#   5926,
#   952,
#   3962,
#   5920,
#   2264,
#   5779,
#   6168,
#   1172,
#   2264,
#   5667,
#   2264,
#   404,
#   4015,
#   2312,
#   2778,
#   1033,
#   5070,
#   3562,
#   5920],
#  [27,
#   5779,
#   6168,
#   6822,
#   3306,
#   5915,
#   1695,
#   5928,
#   27,
#   5679,
#   6551,
#   1768,
#   1791,
#   4663,
#   569,
#   5779,
#   6168],
#  [6168, 4066, 6766, 3306, 5779],
#  [3180,
#   6556,
#   6051,
#   6168,
#   563,
#   5915,
#   157,
#   4334,
#   3912,
#   5044,
#   5591,
#   2202,
#   236,
#   2219,
#   4334,
#   1528,
#   5947,
#   4852,
#   3306,
#   1803,
#   1382,
#   3149,
#   6168,
#   3306,
#   5915],
#  [1742, 4559, 1742, 2129, 5510, 5842, 3639, 2219, 3016, 148, 5965, 3606, 610],
#  [3306, 563, 5738, 1242, 5842, 6382],
#  [4130, 5925, 5419, 6478, 5070, 3562],
#  [3809,
#   1742,
#   3918,
#   5928,
#   116,
#   170,
#   2730,
#   5147,
#   6791,
#   5591,
#   404,
#   2312,
#   3774,
#   3436],
#  [3912, 6822, 2211, 2682, 4662, 6140, 4898, 3615],
#  [6694,
#   4784,
#   3774,
#   3436,
#   4653,
#   4115,
#   3182,
#   3306,
#   332,
#   6278,
#   3774,
#   3436,
#   376,
#   1695,
#   4025],
#  [2234,
#   4531,
#   2989,
#   5979,
#   4662,
#   4898,
#   5822,
#   6140,
#   4786,
#   5332,
#   3243,
#   5716,
#   4028,
#   6587,
#   1675,
#   1521],
#  [4337, 583, 5952, 2233, 1453, 1660, 4103],
#  [6168, 5572, 4670, 3306, 5572, 903, 369, 3225, 3134, 3754, 6573, 4676],
#  [2119, 5501, 1957, 1957, 6141, 2095, 2226, 3006],
#  [5934,
#   3016,
#   2703,
#   6556,
#   5928,
#   4420,
#   6489,
#   4420,
#   3774,
#   3436,
#   4334,
#   4552,
#   2129,
#   2779],
#  [4837, 1521, 3627, 1331, 6652, 521, 935, 1521, 3627, 6489, 4420],
#  [5911, 3809, 163, 1638, 2281, 1238, 1298, 3319, 4886],
#  [4334, 5572, 3744, 4025],
#  [4334, 924, 3506],
#  [148,
#   6141,
#   4648,
#   6048,
#   6556,
#   6051,
#   5571,
#   4025,
#   6090,
#   5779,
#   353,
#   4334,
#   5911,
#   4345,
#   4850,
#   1838,
#   4334,
#   148,
#   5911,
#   2119,
#   4345,
#   312,
#   1695],
#  [818,
#   5268,
#   1990,
#   818,
#   5268,
#   6489,
#   4420,
#   3108,
#   3182,
#   2576,
#   5147,
#   1695,
#   3307,
#   4066],
#  [148,
#   913,
#   2281,
#   6278,
#   6141,
#   4564,
#   6679,
#   5633,
#   4564,
#   6489,
#   4420,
#   4670,
#   6912,
#   3654,
#   5571],
#  [554, 3158, 1287, 3867, 5965, 2310, 5133, 5928, 4420],
#  [404, 4066, 163, 3850, 6694, 4334],
#  [6168],
#  [6168,
#   2223,
#   3374,
#   6894,
#   3091,
#   2920,
#   5679,
#   3306,
#   3253,
#   5779,
#   4025,
#   2219,
#   1176,
#   4218,
#   4091,
#   6906,
#   4091,
#   569,
#   4837,
#   3253,
#   2952,
#   6651,
#   569,
#   4850,
#   148,
#   4850,
#   6131,
#   5470,
#   3182,
#   3306,
#   3253,
#   6588,
#   569,
#   1331],
#  [1695,
#   5779,
#   6168,
#   5147,
#   4066,
#   6698,
#   3699,
#   5591,
#   1289,
#   5471,
#   2302,
#   148,
#   2302,
#   3797],
#  [6825, 1238],
#  [4334,
#   1868,
#   1866,
#   3867,
#   6587,
#   5604,
#   3189,
#   4784,
#   3182,
#   243,
#   4784,
#   3057,
#   5604,
#   3008,
#   2779,
#   3008,
#   4909],
#  [776, 6168, 5268, 3912, 4531, 2989, 6382, 2316, 5572, 3182, 5190, 5056],
#  [3362, 401],
#  [554, 3158, 456, 4652, 5788, 204, 5603, 204, 5467, 926],
#  [6518, 2928, 6168, 5738, 4234],
#  [456, 6121, 2044, 4635, 1618, 622],
#  [5934, 2219, 5178, 2083, 4334, 5572, 1352, 4569, 6382, 3374, 935],
#  [6587, 2393, 1352, 3921, 3908, 3500, 4092, 5125, 1139],
#  [1352,
#   2795,
#   876,
#   3016,
#   2545,
#   1934,
#   6382,
#   3512,
#   818,
#   6382,
#   3339,
#   2101,
#   4543,
#   677,
#   6382,
#   3708,
#   534,
#   2219,
#   554,
#   3158,
#   5611],
#  [1055, 935, 4947, 3031, 935, 1352, 2219, 2795, 2219, 554, 3158, 6038, 459],
#  [563, 5738, 3286, 4334, 2489, 6382, 1337, 157, 4569, 6382],
#  [4334, 2644, 5604],
#  [4334, 1289, 569, 4506, 5095, 1315, 515, 4327],
#  [6912, 5070, 3562, 3436, 2440, 1592, 6556, 4569, 6382, 1352],
#  [4357,
#   2455,
#   2869,
#   5738,
#   3284,
#   5782,
#   3606,
#   610,
#   3284,
#   148,
#   5782,
#   1760,
#   3108,
#   1521,
#   3639,
#   4559],
#  [6822, 5306, 1420, 6090, 4719, 6090, 3731],
#  [3286, 3692, 4337, 3199, 926, 2438, 11, 2069],
#  [2795,
#   3774,
#   3436,
#   4648,
#   4784,
#   4648,
#   2531,
#   2233,
#   6645,
#   1695,
#   5315,
#   4103,
#   4337,
#   1624,
#   3397,
#   2022,
#   4720,
#   2900,
#   5070,
#   975],
#  [5911, 2703, 3057, 3286, 5095, 1635],
#  [6518,
#   5095,
#   1197,
#   6168,
#   5173,
#   4382,
#   2746,
#   2202,
#   3016,
#   1258,
#   4420,
#   963,
#   2041,
#   3335,
#   1197],
#  [5571,
#   1481,
#   6906,
#   2504,
#   1481,
#   6906,
#   2504,
#   2328,
#   4784,
#   3182,
#   5510,
#   5911,
#   3008,
#   4909],
#  [3527, 2627, 4025],
#  [1868, 1033, 148],
#  [3723, 993, 6478, 3446],
#  [1033, 3134, 1214],
#  [67, 2545, 1284, 3641, 5249, 4662, 3091, 1986, 4345, 1789, 1476, 1645, 329],
#  [4130, 2233, 3936, 4103],
#  [148, 3284, 5782, 3888, 618],
#  [1868, 1033, 5571, 6556, 5928, 116, 3512],
#  [1868, 1033, 993, 5760, 993, 3723, 4363, 2041, 4913],
#  [362, 4057, 4711, 3306, 5428, 20, 5147],
#  [6912,
#   3016,
#   6074,
#   3286,
#   554,
#   3158,
#   4763,
#   456,
#   3306,
#   2913,
#   5685,
#   5295,
#   1033,
#   3306,
#   2913,
#   6551,
#   5733],
#  [925,
#   1033,
#   148,
#   5468,
#   554,
#   3158,
#   2294,
#   2714,
#   6074,
#   6051,
#   2253,
#   6551,
#   3180,
#   2006,
#   2264,
#   2644,
#   4784],
#  [6912, 6168, 1828, 6168, 2545, 859, 6090, 2691, 5185, 404],
#  [2900, 20, 2900, 5576, 5825, 2900, 340, 300, 657, 2996],
#  [2041, 1055, 3447, 5807],
#  [6017, 20, 1033, 2535, 6474, 20, 2778],
#  [20, 1525, 4028, 22, 912],
#  [1114, 5326, 2860],
#  [5779, 3419, 6397, 3316, 1598],
#  [3234, 1638, 2795, 6051, 5093, 5686, 5777, 170],
#  [5572, 5190, 2253, 2044, 1972, 2253, 1453, 1660],
#  [5662,
#   20,
#   1770,
#   3016,
#   993,
#   1577,
#   2290,
#   993,
#   3943,
#   844,
#   3326,
#   5698,
#   3503,
#   2860,
#   4662,
#   4028,
#   3933,
#   4420,
#   1905,
#   5686,
#   5249,
#   6140,
#   4898],
#  [554, 3158, 6478, 4292, 5394, 6474],
#  [2114, 2069, 3326, 5698],
#  [2114, 2041, 2703, 6502, 20, 3006, 2589, 2041, 2703, 6090, 2589],
#  [3326, 5698],
#  [3326, 5698, 1298, 6168, 2069, 328, 3016, 20, 5428, 521, 1542, 1695],
#  [3381, 6478, 2504, 4410, 3892, 554],
#  [6760,
#   6090,
#   3306,
#   116,
#   3918,
#   3918,
#   2041,
#   6694,
#   1403,
#   6017,
#   6200,
#   1403,
#   3182,
#   3306,
#   260,
#   20,
#   5825,
#   4347],
#  [3199, 3496, 5468, 6051, 3326, 5095, 925, 1139, 1807],
#  [148,
#   583,
#   1158,
#   1107,
#   3016,
#   5572,
#   6679,
#   2347,
#   1742,
#   1660,
#   5686,
#   1889,
#   2900,
#   3326],
#  [6168,
#   155,
#   5698,
#   5686,
#   831,
#   4661,
#   831,
#   4552,
#   2703,
#   5767,
#   362,
#   116,
#   2545,
#   1910,
#   818,
#   5779,
#   1695,
#   353],
#  [5911,
#   4363,
#   4015,
#   1562,
#   6551,
#   3774,
#   3436,
#   5782,
#   243,
#   6220,
#   329,
#   6906,
#   406,
#   554,
#   3158,
#   6672,
#   403,
#   3306,
#   3306,
#   376,
#   6038,
#   554,
#   2722,
#   2132,
#   583,
#   6074,
#   5408,
#   6251,
#   6382,
#   569],
#  [1862,
#   3774,
#   3436,
#   3306,
#   4420,
#   2312,
#   6551,
#   4334,
#   4652,
#   2430,
#   5928,
#   4334,
#   6449,
#   6178],
#  [828, 1298, 422, 1866, 2264, 28, 3910],
#  [6051, 4280, 3774, 3436, 2750, 993, 3774, 3436, 554, 2233, 3225, 600, 5839],
#  [2750, 2900, 6553, 5839],
#  [6168, 5779, 5044, 912, 4177, 3167, 1114, 2461, 4333],
#  [3809, 903, 5468, 4478],
#  [5031, 3247],
#  [],
#  [1298, 3306, 3373, 1258, 5345, 5408, 3306, 2233, 3865, 2493, 2594],
#  [3016, 406, 5125, 1035, 2233, 2750, 3225, 600, 5839],
#  [3199, 5611],
#  [1055,
#   358,
#   1682,
#   5934,
#   6478,
#   6587,
#   4334,
#   5279,
#   4403,
#   1238,
#   5733,
#   459,
#   925,
#   2860],
#  [6822, 148, 5572, 6822, 3639, 4130, 4130, 3374, 358, 1682],
#  [3500, 2795, 1156, 2383, 1461],
#  [3699,
#   1742,
#   4293,
#   2795,
#   1287,
#   353,
#   3738,
#   5070,
#   652,
#   1742,
#   4077,
#   3641,
#   3933,
#   2069,
#   1742,
#   4077,
#   5716,
#   3641,
#   3933,
#   3091,
#   831,
#   5468],
#  [6168, 3134, 3575, 1352, 3770, 778, 312, 2222],
#  [3921,
#   4117,
#   5305,
#   4420,
#   3252,
#   1033,
#   4990,
#   2672,
#   5471,
#   1957,
#   903,
#   6822,
#   4025,
#   329,
#   3053,
#   4822,
#   6090],
#  [5779, 6382, 1742, 2703, 1521, 3912, 5591, 6382],
#  [3016, 4410, 1513, 6694],
#  [329, 2041, 6906, 20, 5428, 4115],
#  [6168,
#   4334,
#   2316,
#   2023,
#   5306,
#   6822,
#   3708,
#   1770,
#   1033,
#   4334,
#   2316,
#   2023,
#   2385,
#   646,
#   683],
#  [311, 3539, 5653, 1695, 5733, 5148, 993, 6906],
#  [1868, 5055, 163, 1480, 28, 6251],
#  [5934,
#   3381,
#   3326,
#   5698,
#   2504,
#   20,
#   3326,
#   5698,
#   2219,
#   2545,
#   4996,
#   1242,
#   2439,
#   3326,
#   3306,
#   5572,
#   166,
#   1910,
#   6763,
#   3326,
#   5698,
#   2504,
#   4837,
#   5779,
#   6382,
#   5345],
#  [1868, 1033, 6857, 5673],
#  [329, 5073, 285],
#  [2761,
#   4334,
#   5806,
#   2920,
#   2702,
#   2778,
#   311,
#   4063,
#   2692,
#   1158,
#   3247,
#   859,
#   6007,
#   4075,
#   2778,
#   3551,
#   2290,
#   285],
#  [2121, 6551, 3512, 2952, 1481, 2594],
#  [2439,
#   3942,
#   435,
#   6618,
#   3447,
#   6551,
#   3447,
#   6822,
#   2644,
#   140,
#   1057,
#   4533,
#   6906,
#   569,
#   5536,
#   1729,
#   2264,
#   3912,
#   5536,
#   2594,
#   5147,
#   1695,
#   5536,
#   1838,
#   391,
#   6427,
#   1331],
#  [35, 5345, 6551, 2651],
#  [5070,
#   6783,
#   78,
#   1749,
#   6652,
#   1709,
#   583,
#   3551,
#   6518,
#   5145,
#   5113,
#   2913,
#   6168,
#   4775,
#   2051],
#  [583, 3809, 1695, 4759, 5145, 5147, 2889, 3167, 2889, 5408],
#  [2439, 583, 3809, 1695, 27, 2041, 4913, 3998, 4846, 3774, 3436],
#  [6518, 5928, 116, 2041, 4913, 4015],
#  [5070, 2906, 3199, 6553, 6759, 912, 3867],
#  [3867,
#   5766,
#   1837,
#   4025,
#   5330,
#   6168,
#   3275,
#   1468,
#   2651,
#   2860,
#   1801,
#   1760,
#   5591],
#  [6912, 5911, 3809, 6822, 6255, 5070, 2173, 6551],
#  [6759,
#   5685,
#   5295,
#   1139,
#   4035,
#   2966,
#   3182,
#   6894,
#   1695,
#   1695,
#   2556,
#   3016,
#   3286,
#   2889,
#   2430],
#  [3267,
#   993,
#   1047,
#   5332,
#   1114,
#   993,
#   5965,
#   1431,
#   4044,
#   1055,
#   6043,
#   1675,
#   5611,
#   6478,
#   1139,
#   6553,
#   5653,
#   1695,
#   2219,
#   5391,
#   6215,
#   6906,
#   4886,
#   4913,
#   1420,
#   3053,
#   2671,
#   1695,
#   3053],
#  [1695, 993, 6906, 329, 1247, 993, 6906],
#  [5455, 563, 166, 329, 6694, 5467],
#  [2414,
#   2414,
#   2795,
#   1987,
#   6017,
#   579,
#   926,
#   157,
#   5070,
#   2955,
#   1638,
#   5185,
#   5572,
#   1465,
#   2955,
#   5611,
#   6822,
#   300,
#   1987],
#  [6697,
#   4838,
#   6553,
#   3189,
#   1695,
#   300,
#   1055,
#   6759,
#   3091,
#   6697,
#   2682,
#   5686,
#   4838,
#   300,
#   1055,
#   4809,
#   2546,
#   5611,
#   2041,
#   847,
#   4075,
#   1047,
#   5332,
#   5070,
#   2383,
#   583],
#  [2592, 5779, 1176],
#  [3016, 6074, 6551, 2651],
#  [5311, 1258, 2667, 435],
#  [5311, 1258, 2667, 5467],
#  [376, 311, 1695, 11, 3172, 4465, 3016, 2041, 4913, 4281],
#  [391,
#   1695,
#   4885,
#   2766,
#   4307,
#   752,
#   3933,
#   6647,
#   776,
#   391,
#   456,
#   5540,
#   2728,
#   4420,
#   4420,
#   1837,
#   1695,
#   3053,
#   4822,
#   6090,
#   329,
#   2703,
#   5928,
#   1835],
#  [1055, 4420],
#  [3933, 5431, 6806, 3809, 1695, 5806, 5779, 2766],
#  [6518, 6324, 3751, 2877, 2281],
#  [4652, 1742, 3306, 353, 1270, 5146],
#  [3537,
#   3381,
#   2290,
#   793,
#   2504,
#   3381,
#   1992,
#   2290,
#   2504,
#   6822,
#   6278,
#   6141,
#   4334,
#   5572,
#   2913,
#   240,
#   1033,
#   3867,
#   704,
#   243,
#   3006,
#   2439,
#   1480,
#   1957,
#   2594],
#  [6090, 1001, 913, 468, 236],
#  [5911, 4784, 1001],
#  [2114, 1742, 1033, 5928, 4420, 5471, 4420],
#  [2869,
#   1695,
#   431,
#   1331,
#   1934,
#   558,
#   1934,
#   3381,
#   3883,
#   1695,
#   6319,
#   5777,
#   5760,
#   5394],
#  [3921, 6278, 4015, 4343, 468, 5928, 4420, 1033],
#  [1514,
#   5147,
#   1156,
#   3374,
#   1645,
#   1156,
#   5572,
#   3639,
#   1742,
#   6725,
#   1934,
#   1695,
#   1478,
#   1476,
#   1742,
#   5928,
#   5147,
#   3053,
#   329,
#   4822,
#   6090],
#  [3774, 3436, 3932, 5806, 1001, 376, 4343, 481],
#  [6218,
#   4343,
#   3921,
#   2913,
#   1827,
#   1033,
#   6759,
#   3963,
#   5911,
#   2913,
#   2667,
#   2290,
#   285,
#   4017],
#  [6822, 4442, 2440, 5070, 3562, 583, 3326, 2440, 3892, 4292],
#  [583, 2253, 790, 5777, 2703, 1055, 2290],
#  [2440, 3892, 2761, 2041, 3306],
#  [4130, 2290],
#  [3500,
#   1156,
#   2714,
#   1416,
#   1033,
#   2439,
#   4420,
#   2114,
#   2920,
#   3735,
#   148,
#   2276,
#   2766,
#   5965,
#   3933,
#   3797,
#   3575,
#   1902,
#   4420,
#   4477,
#   5928,
#   4066],
#  [1862, 3306, 5806, 4420, 6478, 1218, 4420, 6766, 1333, 6007, 4075],
#  [2019, 3770, 148, 2114, 2920, 3735],
#  [2316, 2023, 4025, 5306],
#  [2316, 788, 1033, 3620, 6822, 1033, 3306, 2316, 1289, 1416],
#  [1107,
#   3809,
#   1695,
#   5235,
#   4025,
#   5474,
#   3223,
#   4885,
#   5638,
#   3306,
#   163,
#   5190,
#   3316,
#   3933,
#   5431],
#  [3524, 3264, 3286, 6694, 5806, 3223, 859, 1033, 6587, 3933],
#  [2219, 4334, 5268],
#  [1866, 4166, 4293, 2795, 3918],
#  [6822,
#   5070,
#   4162,
#   682,
#   3267,
#   1770,
#   5576,
#   3326,
#   5698,
#   6474,
#   5576,
#   5825,
#   2900,
#   20],
#  [2644],
#  [5069, 5394, 1435],
#  [4349,
#   1520,
#   583,
#   2871,
#   6047,
#   3306,
#   903,
#   1453,
#   1660,
#   3016,
#   4794,
#   5532,
#   6907,
#   1156,
#   406],
#  [4349, 1824, 583, 5474],
#  [6822, 6905, 126, 2795, 5070, 6822, 6910, 4424, 158],
#  [3199,
#   6553,
#   2681,
#   3252,
#   1645,
#   3073,
#   1238,
#   391,
#   6553,
#   2681,
#   3252,
#   3552,
#   1902,
#   2302],
#  [3918,
#   4293,
#   2795,
#   5767,
#   1419,
#   1453,
#   1660,
#   3267,
#   4662,
#   140,
#   294,
#   1431,
#   4044,
#   300,
#   2750,
#   6382],
#  [5394, 5928, 2750],
#  [2439,
#   2750,
#   2302,
#   3774,
#   3436,
#   2233,
#   3313,
#   11,
#   3225,
#   600,
#   5965,
#   752,
#   2750,
#   6382],
#  [2626, 166, 2556, 6521],
#  [5070, 2906, 5093, 4632, 583, 2750, 47, 4044, 625, 1453, 1660, 2750, 6382],
#  [5911, 4063, 5070, 3562, 3436, 2440, 5241, 948, 5693],
#  [5580, 2766, 803, 1156, 5927, 3373],
#  [5743, 903, 2385, 2830, 2766, 803],
#  [2644, 3442, 3436, 5070, 2383, 583, 5839, 2246],
#  [5031,
#   6074,
#   3016,
#   2696,
#   554,
#   3158,
#   3016,
#   1489,
#   6478,
#   1489,
#   1986,
#   376,
#   6565,
#   2414,
#   5806,
#   3199,
#   3306,
#   6588,
#   5839,
#   4347,
#   4388,
#   5217,
#   569,
#   2041,
#   4388,
#   5093,
#   3774,
#   3436,
#   5093,
#   6906,
#   5934,
#   903,
#   3016,
#   4745],
#  [2199, 554, 5238, 5782, 1164, 6478, 993, 3723, 2934],
#  [5911, 554, 4784, 2900, 376, 2722, 376, 2132, 1164, 554, 3158, 6478],
#  [1382, 926, 2482, 4334, 1382],
#  [5351, 6907, 6658, 683, 4025, 903, 5810],
#  [5934,
#   6427,
#   1156,
#   5125,
#   5345,
#   3306,
#   2233,
#   1114,
#   6382,
#   4745,
#   3551,
#   4347,
#   1238,
#   5767,
#   1230,
#   4025,
#   5093,
#   5934,
#   6583],
#  [3286, 1453, 1660, 3374, 5031, 3225],
#  [5225, 4745, 5306, 4347, 67],
#  [6822,
#   4663,
#   1158,
#   1107,
#   2795,
#   2385,
#   5345,
#   4334,
#   2703,
#   420,
#   5965,
#   5306,
#   5345,
#   3306,
#   2703,
#   1844,
#   5934,
#   6894],
#  [3381, 2795, 6636, 2504, 4194, 614, 2044, 4130],
#  [3809,
#   2036,
#   5305,
#   2714,
#   1442,
#   1298,
#   5911,
#   3544,
#   3442,
#   2906,
#   4763,
#   1453,
#   1660,
#   2233,
#   5181,
#   4103,
#   4103,
#   1124,
#   4103,
#   3225],
#  [6912,
#   5070,
#   2173,
#   3286,
#   1337,
#   3442,
#   2906,
#   5093,
#   4632,
#   5911,
#   4652,
#   1866,
#   2869,
#   3442,
#   2906,
#   148,
#   5345,
#   5093,
#   4632,
#   1902,
#   3682,
#   1453,
#   3544,
#   1298,
#   340,
#   583,
#   1453,
#   925,
#   1242,
#   2233],
#  [1292,
#   1287,
#   554,
#   3774,
#   3436,
#   2440,
#   376,
#   554,
#   459,
#   993,
#   6912,
#   376,
#   2132,
#   1287,
#   2440,
#   6478,
#   554,
#   406,
#   6251,
#   5345,
#   5408,
#   3774,
#   3436,
#   2233,
#   1176,
#   5839],
#  [2722,
#   1682,
#   3225,
#   563,
#   583,
#   993,
#   993,
#   1292,
#   2440,
#   1292,
#   1114,
#   1292,
#   6074,
#   6557,
#   554,
#   6114,
#   3723,
#   2934],
#  [4833, 554, 3158, 1055, 2628],
#  [554, 4784, 3569, 926, 5468],
#  [4334, 4767, 1419],
#  [6168, 1289, 2302, 5217, 569, 4103, 600, 3225, 1866, 2761, 903],
#  [5994, 6074, 2750, 2383, 5693, 5928, 2750],
#  [5939, 3103, 1337, 6251, 5839],
#  [1337, 4130, 6556, 1453, 1660],
#  [2628,
#   3774,
#   3436,
#   3850,
#   6429,
#   6429,
#   5601,
#   2505,
#   6822,
#   77,
#   6074,
#   6822,
#   1025,
#   77,
#   3850,
#   4177,
#   77],
#  [2628, 1156, 569, 5601, 6825, 912],
#  [865,
#   1331,
#   4652,
#   6822,
#   1114,
#   2044,
#   554,
#   3158,
#   5022,
#   4681,
#   2035,
#   6822,
#   4763,
#   3397,
#   6822,
#   456,
#   4763,
#   4465,
#   1114,
#   1679,
#   6822,
#   2219,
#   1763,
#   4784,
#   912,
#   5345,
#   3016,
#   5070,
#   975,
#   4465,
#   6822,
#   1679,
#   1820,
#   3016,
#   4465,
#   5070,
#   975,
#   1884,
#   6822,
#   1679,
#   3774,
#   3436,
#   6822,
#   3477],
#  [5911, 2795, 4442, 1298, 4533, 5806, 1679, 4632, 3306],
#  [5911, 2795, 4442, 5185, 1679],
#  ...]

# %% [markdown]
# ## Padding sequences

# %%
# finding max sentence length

vec_lengths = []
for i in encoded_vocab:
    vec_lengths.append(len(i))


max_length = np.unique(vec_lengths)[-1]
max_length
# Out:
# 65

# %%
embedded_docs=pad_sequences(encoded_vocab,padding='post',maxlen=max_length)
print(embedded_docs)
# Out:
# [[2644 5474    0 ...    0    0    0]
#  [6759 1742 2383 ...    0    0    0]
#  [4222 5408 5070 ...    0    0    0]
#  ...
#  [1033  912    0 ...    0    0    0]
#  [3918 1048 1415 ...    0    0    0]
#  [5056   22  340 ...    0    0    0]]

# %% [markdown]
# ## Creating the model

# %%
from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import LSTM, Dense, Bidirectional, Dropout, Flatten, GlobalMaxPool1D, Embedding

from tensorflow.keras.backend import clear_session

# %%
clear_session()

# %%
model=Sequential()
model.add(Embedding(vocabulary_size,200,input_length=max_length))
#model.add(Bidirectional(LSTM(100)))
model.add(LSTM(10, return_sequences=True))
model.add(LSTM(10))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 65, 200)           1383200
#
#  lstm (LSTM)                 (None, 65, 10)            8440
#
#  lstm_1 (LSTM)               (None, 10)                840
#
#  dropout (Dropout)           (None, 10)                0
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 1,392,491
# Trainable params: 1,392,491
# Non-trainable params: 0
# _________________________________________________________________

# %%
labels = df['Verdict'].copy()

# %%
labels = labels.apply(lambda x: 1 if x==1 else 0)

# %%
labels
# Out:
# index
# 0        0
# 1        0
# 2        1
# 3        1
# 4        0
#         ..
# 23528    0
# 23529    0
# 23530    0
# 23531    0
# 23532    0
# Name: Verdict, Length: 23533, dtype: int64

# %%
# Preparing for training the model
X_embedded = np.array(embedded_docs)
# y = labels
y = df['Verdict'].values

# check shapes
print(f"X shape: {X_embedded.shape}. y shape: {y.shape}")
# Out:
# X shape: (23533, 65). y shape: (23533,)

# %%
# Train test split
X_embedded_train = X_embedded[:sum(mask)]
y_embedded_train = y[:sum(mask)]

X_embedded_test = X_embedded[sum(mask):]
y_embedded_test = y[sum(mask):]

print('Train shape: ', (X_embedded_train.shape, y_embedded_train.shape))
print('Test shape: ', (X_embedded_test.shape, y_embedded_test.shape))
# Out:
# Train shape:  ((18170, 65), (18170,))
# Test shape:  ((5363, 65), (5363,))

# %%
model.fit(X_embedded_train,y_embedded_train,validation_data=(X_embedded_test,y_embedded_test),epochs=10,batch_size=790)
# Out:
# Epoch 1/10
# 23/23 [==============================] - 5s 169ms/step - loss: -8.0211 - accuracy: 0.1015 - val_loss: -6.5755 - val_accuracy: 0.1162
# Epoch 2/10
# 23/23 [==============================] - 4s 166ms/step - loss: -8.1575 - accuracy: 0.1015 - val_loss: -6.6652 - val_accuracy: 0.1162
# Epoch 3/10
# 23/23 [==============================] - 4s 168ms/step - loss: -8.2696 - accuracy: 0.1015 - val_loss: -6.7553 - val_accuracy: 0.1162
# Epoch 4/10
# 23/23 [==============================] - 4s 168ms/step - loss: -8.3745 - accuracy: 0.1017 - val_loss: -6.8451 - val_accuracy: 0.1162
# Epoch 5/10
# 23/23 [==============================] - 4s 169ms/step - loss: -8.4815 - accuracy: 0.1017 - val_loss: -6.9352 - val_accuracy: 0.1162
# Epoch 6/10
# 23/23 [==============================] - 4s 167ms/step - loss: -8.6222 - accuracy: 0.1035 - val_loss: -7.0248 - val_accuracy: 0.1162
# Epoch 7/10
# 23/23 [==============================] - 4s 165ms/step - loss: -8.7245 - accuracy: 0.1018 - val_loss: -7.1154 - val_accuracy: 0.1162
# Epoch 8/10
# 23/23 [==============================] - 4s 166ms/step - loss: -9.3960 - accuracy: 0.1224 - val_loss: -8.0597 - val_accuracy: 0.1384
# Epoch 9/10
# 23/23 [==============================] - 4s 165ms/step - loss: -10.2351 - accuracy: 0.1309 - val_loss: -8.2483 - val_accuracy: 0.1904
# Epoch 10/10
# 23/23 [==============================] - 4s 168ms/step - loss: -10.3642 - accuracy: 0.1417 - val_loss: -8.4563 - val_accuracy: 0.1756

# %%
validation_data=(X_embedded_test,y_embedded_test)

# %%
model1 = Sequential()
model1.add(Embedding(input_dim=vocabulary_size, 
                           output_dim=100, 
                           input_length=max_length))
model1.add(GlobalMaxPool1D())
model1.add(Dense(100, activation='relu'))

model1.add(Dense(1, activation='sigmoid'))
model1.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 65, 100)           691600
#
#  global_max_pooling1d (Globa  (None, 100)              0
#  lMaxPooling1D)
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 701,801
# Trainable params: 701,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.fit(X_embedded_train,y_embedded_train,validation_data=(X_embedded_test,y_embedded_test),epochs=10,batch_size=395)
# Out:
# Epoch 1/10
# 46/46 [==============================] - 1s 16ms/step - loss: -559016.0625 - accuracy: 0.1014 - val_loss: -460600.8438 - val_accuracy: 0.1162
# Epoch 2/10
# 46/46 [==============================] - 1s 16ms/step - loss: -575276.6875 - accuracy: 0.1014 - val_loss: -473852.0312 - val_accuracy: 0.1162
# Epoch 3/10
# 46/46 [==============================] - 1s 16ms/step - loss: -591782.3750 - accuracy: 0.1014 - val_loss: -487566.5312 - val_accuracy: 0.1162
# Epoch 4/10
# 46/46 [==============================] - 1s 15ms/step - loss: -608704.4375 - accuracy: 0.1014 - val_loss: -501357.9375 - val_accuracy: 0.1162
# Epoch 5/10
# 46/46 [==============================] - 1s 15ms/step - loss: -625897.1875 - accuracy: 0.1014 - val_loss: -515397.6875 - val_accuracy: 0.1162
# Epoch 6/10
# 46/46 [==============================] - 1s 16ms/step - loss: -643380.3125 - accuracy: 0.1014 - val_loss: -529774.1875 - val_accuracy: 0.1162
# Epoch 7/10
# 46/46 [==============================] - 1s 16ms/step - loss: -661202.1250 - accuracy: 0.1014 - val_loss: -544379.0000 - val_accuracy: 0.1162
# Epoch 8/10
# 46/46 [==============================] - 1s 16ms/step - loss: -679338.1875 - accuracy: 0.1014 - val_loss: -559198.6875 - val_accuracy: 0.1162
# Epoch 9/10
# 46/46 [==============================] - 1s 16ms/step - loss: -697759.3125 - accuracy: 0.1014 - val_loss: -574322.5625 - val_accuracy: 0.1162
# Epoch 10/10
# 46/46 [==============================] - 1s 16ms/step - loss: -716518.0000 - accuracy: 0.1014 - val_loss: -589664.8750 - val_accuracy: 0.1162

# %%
from tensorflow.keras.layers import GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D


clear_session()

# %%
embedding_dim = 100

model = Sequential()
model.add(Embedding(vocabulary_size, embedding_dim, input_length=max_length))
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 65, 100)           691600
#
#  conv1d (Conv1D)             (None, 61, 128)           64128
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 10)                1290
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 757,029
# Trainable params: 757,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_embedded_train,y_embedded_train,validation_data=(X_embedded_test,y_embedded_test),epochs=10,batch_size=46)
# Out:
# Epoch 1/10
# 395/395 [==============================] - 5s 12ms/step - loss: -4017.6414 - accuracy: 0.1016 - val_loss: -16797.5840 - val_accuracy: 0.1162
# Epoch 2/10
# 395/395 [==============================] - 5s 12ms/step - loss: -127966.9453 - accuracy: 0.1014 - val_loss: -262780.4062 - val_accuracy: 0.1162
# Epoch 3/10
# 395/395 [==============================] - 5s 12ms/step - loss: -798801.1875 - accuracy: 0.1014 - val_loss: -1192722.6250 - val_accuracy: 0.1162
# Epoch 4/10
# 395/395 [==============================] - 5s 12ms/step - loss: -2656025.0000 - accuracy: 0.1014 - val_loss: -3376891.5000 - val_accuracy: 0.1162
# Epoch 5/10
# 395/395 [==============================] - 5s 12ms/step - loss: -6406045.5000 - accuracy: 0.1015 - val_loss: -7382513.5000 - val_accuracy: 0.1162
# Epoch 6/10
# 395/395 [==============================] - 5s 12ms/step - loss: -12767234.0000 - accuracy: 0.1015 - val_loss: -13790284.0000 - val_accuracy: 0.1162
# Epoch 7/10
# 395/395 [==============================] - 5s 12ms/step - loss: -22423158.0000 - accuracy: 0.1015 - val_loss: -23116540.0000 - val_accuracy: 0.1162
# Epoch 8/10
# 395/395 [==============================] - 5s 12ms/step - loss: -35966804.0000 - accuracy: 0.1015 - val_loss: -35864292.0000 - val_accuracy: 0.1162
# Epoch 9/10
# 395/395 [==============================] - 5s 12ms/step - loss: -54099156.0000 - accuracy: 0.1015 - val_loss: -52559904.0000 - val_accuracy: 0.1162
# Epoch 10/10
# 395/395 [==============================] - 5s 12ms/step - loss: -77412000.0000 - accuracy: 0.1015 - val_loss: -73780440.0000 - val_accuracy: 0.1162
