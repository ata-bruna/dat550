# %% [markdown]
# # Detect claims to fact check in political debates
#
# In this project you will implement various classifiers using both neural and feature based technqiues to detect which sentences in political debates should be fact checked.
# Dataset from ClaimBuster: https://zenodo.org/record/3609356
# Evaluate your classifiers using the same metrics as http://ranger.uta.edu/~cli/pubs/2017/claimbuster-kdd17-hassan.pdf (Table 2)
#
# Classification report from sklearn provides everything

# %%
# TODO:  Create advanced model(s) (suggestions are given below)
#           -- Generate more features that a model can use. For example the context around the sentence, sentiment, named entities etc.
#           -- Rule based classifier. For example, if sentence contains certain words, tags, statistics etc.
#           -- Deep learning (word embeddings, transformer models etc.)
#           -- Sub-sentence classifier. Long sentences may include several claims, so the goal is to mark the span of claim(s) within a sentence

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import svm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import collections
import string

from sklearn.cluster import KMeans
from sklearn.metrics import *
from sklearn.linear_model import Perceptron
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier

import json
import glob
import re
import time

# %% [markdown]
# # Loading and merging the data

# %%
file1 = pd.read_csv("data/crowdsourced.csv", encoding='utf-8')
file2 = pd.read_csv("data/groundtruth.csv", encoding='utf-8')
df = pd.concat([file1, file2])


df["date"] = df["File_id"].str.strip(to_strip=".txt")

df["date"] = pd.to_datetime(df["date"])
df.sort_values("date", inplace= True)
df["mos_before_election"] = 11 - df["date"].dt.month

df['index'] = pd.RangeIndex(len(df))
df.set_index('index', inplace=True)
df
# Out:
#        Sentence_id                                               Text  \
# index
# 0             8211                   Now, this is not standing still.
# 1             8515  So these are three programs which are quite mo...
# 2             8514  The proposal advanced by you and by Mr. Javits...
# 3             8513         It does not put a deficit on the Treasury.
# 4             8512  The third is medical care for the aged which i...
# ...            ...                                                ...
# 23528        34028  First of all, the media is so dishonest and so...
# 23529        34027        What I've seen -- what I've seen is so bad.
# 23530        34026                       I'll look at it at the time.
# 23531        34039                 So I talk about the corrupt media.
# 23532        33341  They work hard, they do everything they can to...
#
#                 Speaker       Speaker_title Speaker_party         File_id  \
# index
# 0      Richard M. Nixon      Vice President    REPUBLICAN  1960-09-26.txt
# 1       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 2       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 3       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 4       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# ...                 ...                 ...           ...             ...
# 23528      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23529      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23530      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23531      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23532   Hillary Clinton  Secretary of State      DEMOCRAT  2016-10-19.txt
#
#        Length  Line_number  Sentiment  Verdict       date  mos_before_election
# index
# 0           6          114  -0.417840       -1 1960-09-26                    2
# 1           9          418   0.249581       -1 1960-09-26                    2
# 2          42          417  -0.626563        1 1960-09-26                    2
# 3           9          416  -0.629486        1 1960-09-26                    2
# 4          22          415   0.000000       -1 1960-09-26                    2
# ...       ...          ...        ...      ...        ...                  ...
# 23528      17          907   0.032300       -1 2016-10-19                    1
# 23529       9          906  -0.669600       -1 2016-10-19                    1
# 23530       7          905   0.000000       -1 2016-10-19                    1
# 23531       7          918   0.000000       -1 2016-10-19                    1
# 23532      14          220   0.361200       -1 2016-10-19                    1
#
# [23533 rows x 12 columns]

# %% [markdown]
# # Data preprocessing

# %%
def remove_punctuation(text):
    tokens = re.sub('[^a-zA-Z]', ' ', text).lower()
    return tokens

# %%
def remove_stop_words(text):
    stop_words = stopwords.words('english')
    word_list = [word for word in text.split() if word not in stop_words]
    return word_list

# %%
def get_word_stemm(word_list):
    """Stemmers remove morphological affixes from words, leaving only the word stem."""
    stemmer = SnowballStemmer('english')
    singles = [stemmer.stem(word) for word in word_list] 
    return singles

# %%
def preprocess_data(docs, stemming=False):

    text_list = [] 
    for doc in docs:  
        # 1. Remove punctuation and set as lower case
        text = remove_punctuation(doc)

        # 2. Remove stop words and extra spaces
        word_list = remove_stop_words(text)

        if stemming:
            # 3. Stemming
            word_list = get_word_stemm(word_list)

        joined_text = " ".join(word_list)
        text_list.append(joined_text)
        
    return text_list

# %%
data = preprocess_data(df.Text.values, stemming=True)

# %%
data
# Out:
# ['stand still',
#  'three program quit moder',
#  'propos advanc mr javit would cost six hundr million dollar mr rockefel reject new york said agre financ said ought social secur',
#  'put deficit treasuri',
#  'third medic care age tie social secur financ social secur fund',
#  'say major republican oppos',
#  'say major',
#  'say democrat unit support program',
#  'extrem bill yet could get one republican join least think four eight democrat vote send floor hous one republican join democrat oppos',
#  'fact matter bill less recommend mr nixon morn propos',
#  'uh defeat teacher salari bill uh met opinion need',
#  'second feder aid educ bill',
#  'think extrem yet near two third three fourth republican hous repres vote propos',
#  'one bill dollar twenti five cent hour anyon work store compani million dollar year busi',
#  'well let look bill vice presid suggest extrem',
#  'reason presid eisenhow veto sustain reason congress send bill think veto peopl congress major know countri behind presid',
#  'must alway rememb presid stop anyth unless peopl behind',
#  'also say far senat kennedi propos concern question simpli one uh presidenti veto stop program',
#  'think show differ two parti',
#  'whether hous senat next session democrat republican countri vote candid presid propos made believ find presid republican would case would abl get program congress',
#  'one parti readi move program',
#  'well think serious',
#  'test whether america move whether feder govern plus state govern plus local govern plus biggest segment individu enterpris move',
#  'often apprais whether move ahead think feder govern',
#  'matter fact question bring point glad make',
#  'question one goal goal one mean',
#  'connect would say senat kennedi say status quo believ uh would agre sincer believ propos feder aid educ propos health care sincer held',
#  'connect think uh must look futur mind fact fight communism home law deal communist uh becom communist becom tra fellow travel also fight communism home move various injustic exist societi communist feed upon',
#  'uphold standard conduct would never follow',
#  'also essenti alert fair fair fair uphold freedom communist would destroy',
#  'rememb cold war mr khrushchev wage colleagu wage wage world wage right unit state',
#  'one continu problem year come',
#  'question communism within unit state one worri us past',
#  'agre senat kennedi apprais general respect',
#  'major threat extern continu',
#  'think unit state maintain strong societi unit state think meet intern threat',
#  'sustain uh depart justic effort f b continu alert',
#  'support uh law unit state pass order protect us uh would destroy us within',
#  'think matter continu uh give uh great care attent',
#  'parti give lip servic',
#  'exampl gross nation product approxim five hundr billion dollar',
#  'whenev major peopl program hous senat respond',
#  'would say presid abl lead presid abl get program effect support countri support peopl',
#  'someth build',
#  'build record believ secret progress know way progress',
#  'think first record prove know way',
#  'senat kennedi suggest believ know way',
#  'respect sincer make suggest',
#  'hand look various program offer seem new',
#  'seem simpli retread program truman administr preced',
#  'would suggest cours even might indic area program new mean progress',
#  'program expand educ opportun give american equal chanc educ thing necessari dear heart peopl',
#  'program addit see medic care age much much better handl present time',
#  'may indic senat kennedi disagr aim',
#  'want help old peopl',
#  'want see adequ medic care',
#  'question mean',
#  'could give better exampl whatev whether field hous health medic care school eh develop electr power program believ move america move forward build wonder record made past seven half year',
#  'look program might suggest evalu often tendenc say test program much spend',
#  'conced area refer senat kennedi would spe feder govern spend would spend',
#  'record never someth stand',
#  'sometim get opinion get program hous senat pure question legisl finagl sort thing',
#  'good record may emphas enough',
#  'offer amend',
#  'cannot cours control senat',
#  'uh would hope control hous get major hous uh elect',
#  'would say cours expect pick seat hous senat',
#  'convinc altern propos republican field health field educ field welfar extrem accomplish end uh without great cost dollar freedom could get next congress',
#  'extrem',
#  'reason particular bill various field mention pass presid peopl',
#  'major member congress felt particular propos good issu major democrat pass send presid get veto issu',
#  'presid exercis veto power peopl upo behind third congress',
#  'would say blame presid veto power inabl senat colleagu get action special session uh miss mark',
#  'would seem difficult blame four republican eight democrat get someth particular committe',
#  'would say senat kennedi refer action hous rule committe eight democrat committe four republican',
#  'first see possibl one third bodi republican hous senat stop two third two third adequ led',
#  'well obvious view littl differ',
#  'send republican presid democrat major threat veto hang congress judgment continu happen august session clash parti inact',
#  'judgment vigor democrat presid support democrat major hous senat win support program',
#  'inform time came vote adopt presid unit state would veto',
#  'forti four democrat vote one republican vote',
#  'want tie social secur',
#  'cost cost democrat platform',
#  'rough hundr billion hundr quarter billion result govern activ',
#  'growth look growth administr support polici stimul',
#  'satisfi everi american enjoy full constitut right',
#  'satisfi fifti percent steel mill capac unus',
#  'great countri think could greater countri power countri think could power countri',
#  'mean averag famili incom went fifteen per cent eisenhow year two per cent truman year',
#  'great task success address',
#  'think readi move',
#  'question american peopl decid want want countri want futur',
#  'want say year tide came year unit state start move',
#  'want historian ten year say year tide ran unit state',
#  'fail fail move ahead fail develop suffici militari econom social strength countri think uh tide could begin run us',
#  'meet respons think freedom conquer',
#  'said begin question us face republican democrat freedom next generat conquer communist go success',
#  'feel move sixti function presid set peopl unfinish busi societi franklin roosevelt thirti agenda peopl must societi meet need countri protect secur help caus freedom',
#  'think vote mr nixon',
#  'feel everyth done satisfactori relat power prestig strength unit state increas relat communist b gain secur achiev everyth nation achiev achiev better life citizen greater strength agre',
#  'mean question',
#  'third think question american peopl look countri look world around goal american',
#  'oblig upon generat',
#  'august tri get time medic care receiv support one republican senat occas',
#  'unit state stand still',
#  'think mean advoc reach goal better mean advoc',
#  'kerr bill provid assist social secur',
#  'also essenti allow dollar spent could better spent peopl',
#  'stand program mean growth progress',
#  'think big assign big task big function feder govern',
#  'reason eisenhow administr move reason fund exampl local build school hospit highway make progress administr encourag individu enterpris result greatest expans privat sector economi ever wit eight year period',
#  'test whether america move',
#  'continu alert',
#  'everi republican rule committe vote send bill consid member hous repres',
#  'might say two third republican hous vote dollar twenti five cent minimum wage major democrat sustain near two third vote dollar twenti five',
#  'object cost dollar',
#  'senat kennedi take posit',
#  'far aid school construct concern favor senat kennedi januari year said favor rather aid teacher salari',
#  'uh say experi peopl consid senat kennedi peopl consid',
#  'cours disagre senat kennedi insofar suggest done uh farm program',
#  'judgment polici work effect suppli demand balanc',
#  'well vice presid came congress togeth serv labor committe',
#  'question much feder govern spend question govern',
#  'kind program',
#  'four hundr billion approxim result individu',
#  'mr landon ran repeal',
#  'think clear contrast',
#  'get uh uh economi',
#  'determin men',
#  'reason complac',
#  'far absolut gap concern find unit state even ahead twenti year ago',
#  'percentag twenti year ago',
#  'although move faster growth find exampl today total gross nation product forti four per cent total gross nation product',
#  'start much lower base',
#  'reason obvious',
#  'soviet union move faster',
#  'first think well put perspect realli stand regard soviet union whole matter growth',
#  'want compar adversari year unit state ahead educ health build home econom strength',
#  'enough compar might done eight year ago ten year ago fifteen year ago twenti year ago',
#  'soviet union make great gain',
#  'think howev presid leadership set countri exact must next decad go maintain secur educ econom growth develop natur resourc',
#  'think power countri',
#  'second think rich uh countri',
#  'well must say reason school construct local school district will increas properti tax tremend high figur opinion almost point diminish return order sustain school',
#  'agre senat kennedi complet score',
#  'social secur act written nineti four nineti five republican vote',
#  'disagre mean would use get economi',
#  'believ examin democrat platform examin propos discuss tonight compar propos made propos make would result greater growth countri would case follow program advoc',
#  'program amend kerr bill',
#  'second vice presid mention medic care age',
#  'want see day sixti percent seventi seventi five eighti nineti percent forc power could bring bear order caus destruct',
#  'want make sure stay relationship',
#  'must say forti four percent soviet countri caus us good deal troubl tonight',
#  'point made mr nixon soviet product forti four percent',
#  'essenti man presid countri certain stand everi program mean growth',
#  'found peopl could least afford peopl retir incom uh peopl fix incom found unabl meet bill end month',
#  'point would make downgrad much thing cost think mani peopl understand better look happen truman administr govern spend took found save lifetim eaten inflat',
#  'one place think program better job',
#  'would cover sever million peopl cover social secur',
#  'program social secur would requir everybodi social secur take govern health insur whether want',
#  'compel nobodi insur want',
#  'provid choic either govern insur privat insur',
#  'health program one senat javit republican senat well support one provid peopl sixti five want health insur opportun want',
#  'one field health worth mention',
#  'mani point made would like comment upon',
#  'respect submit senat kennedi often would reli much feder govern would solv problem stimul growth',
#  'mean issu',
#  'run minimum thirteen two tenth billion dollar year present spend maximum eighteen billion dollar year present spend',
#  'cost minimum four billion dollar year maximum four nine tenth billion dollar year present spend',
#  'second support feder aid educ feder aid teacher salari',
#  'think good invest',
#  'think go',
#  'think heap burden properti tax alreadi strain mani communiti provid make sh insur opinion mani children adequ educ mani teacher adequ compens',
#  'greater return economi societi educ system second none',
#  'question develop natur resourc would pay go sens would balanc power revenu would bring back suffici money financ project way tennesse valley',
#  'believ balanc budget',
#  'condit would unbal budget would grave nation emerg serious recess',
#  'otherwis steadi rate econom growth mr nixon mr rockefel meet said five per cent econom growth would bring ten billion dollar extra tax revenu',
#  'whatev brought think financ essenti program within balanc budget busi remain order',
#  'think mr novin refer one senat kennedi speech democrat platform mention cut nation debt',
#  'think point cours possibl particular propos senat kennedi advoc either cut nation debt reduc tax',
#  'matter fact necessari rais tax',
#  'senat kennedi point far one propos concern one medic care age would financ social secur',
#  'howev rais tax pay social secur',
#  'point would make pay go basi natur resourc develop',
#  'natur resourc develop also support incident howev whenev uh uh uh appropri money one project pay appropri money eh eventu pay mean govern put money year',
#  'program advoc fail five vote unit state senat would put medic care age social secur would paid social secur system social secur tax',
#  'would say propos senat kennedi made result one two thing either rais tax unbal budget',
#  'program javit nixon nixon javit program would cost fulli use uh six hundr million dollar govern per year six hundr million dollar state',
#  'medic care age would put social secur',
#  'legisl branch',
#  'would say peopl opportun evalu mine think go abid whatev peopl decid',
#  'well say question experi question also uh judgment futur goal unit state abil implement goal',
#  'abraham lincoln came presid rather littl known uh session hous repres defeat senat fifti eight distinguish presid',
#  'certain road presid',
#  'guarante uh take uh one road anoth success presid',
#  'congress fourteen year',
#  'vote last uh eight year uh vice presid uh presid senat meet respons',
#  'met met uh decis eight hundr time matter affect domest secur unit state member senat foreign relat committe',
#  'question realli candid parti meet problem unit state go face sixti',
#  'advoc reduc feder debt believ go abl reduc feder debt much nineteen sixti one two three',
#  'think heavi oblig affect secur go meet',
#  'therefor never suggest uh abl retir debt substanti even nineteen sixti one two',
#  'reduc interest',
#  'reduc interest rate',
#  'judgment hard money tight money polici fiscal polici administr contribut slow economi help bring recess fifti four made recess fifti eight rather intens slow somewhat econom activ',
#  'talk howev kind program talk judgment uh fiscal sound',
#  'vice presid disagre',
#  'mine execut branch',
#  'unbal budget mean inflat cours cruel blow peopl older peopl talk',
#  'aw glad ge got question know got last question abl complet argument',
#  'vote favor propos support strong think provid assist teacher salari without chanc feder control vote th mr nixon disagre tie vote uh defeat break tie defeat propos',
#  'want feder govern pay teacher salari direct',
#  'money go state state determin whether shall go school construct teacher salari opinion protect local author school board school committe',
#  'therefor think sound propos support regret pass',
#  'second statement made uh democrat platform would cost good deal money favor unbalanc budget',
#  'wholli wrong wholli error fact last eight year democrat congress reduc appropri request appropri ten billion dollar',
#  'view think ought state clear record',
#  'view program care drawn within balanc budget economi move ahead',
#  'well take bill',
#  'may take bill pass senat bill uh provid dollar twenti five cent minimum wage',
#  'fail hous pass hous fail eleven vote',
#  'threaten veto pass dollar quarter extrem difficult great power presid pass bill presid oppos',
#  'presid need sustain veto bill one third plus one either hous senat',
#  'second pass feder aid educ bill senat',
#  'fail came floor hous repres',
#  'kill rule committe',
#  'fact august session four member rule committe republican join two democrat vote send aid educ bill floor hous',
#  'question vice presid disagre',
#  'favor believ best way aid school without run risk whatev feder govern tell teacher teach',
#  'state could determin whether money would spent school construct teacher salari',
#  'uh vice presid quot januari sixti believ feder govern pay direct teacher salari issu senat februari',
#  'uh think reason vote feder govern uh pay teacher salari probabl reason concern senat kennedi januari year kick press confer said favor aid school construct time feel aid teacher salari least way read remark',
#  'question feder govern aid teacher salari',
#  'take',
#  'took take reason want higher teacher salari',
#  'need higher teacher salari',
#  'also want educ free feder control',
#  'feder govern get power pay teacher inevit opinion acquir power set standard tell teacher teach',
#  'think would bad countri think would bad teach profess',
#  'anoth point made',
#  'favor higher salari teacher',
#  'senat kennedi said januari year press confer way get higher salari teacher support school construct mean local school district various state money freed rais standard teacher salari',
#  'also point put respons feder govern pay portion teacher salari local communiti state go meet respons much',
#  'believ word seen local communiti state assum respons',
#  'teacher salari fortun gone fifti percent last eight year thirti four percent rise salari',
#  'enough',
#  'believ way get salari teacher feder govern get massiv program',
#  'object potenti cost control eventu freedom american peopl give feder govern power educ greatest power govern',
#  'issu senat money would given state',
#  'republican platform cost',
#  'experi differ mine',
#  'far experi count whether experi count say',
#  'exampl first trip abroad abroad strong recommend increas exchang program particular relat exchang person leader labor field inform field',
#  'trip south america made recommend separ inter american lend agenc set south american nation would like much better lend particip lend agenc treat countri world',
#  'uh made recommend trip exampl trip abroad hungari made recommend regard hungarian refuge situat adopt presid enact law congress',
#  'within administr chairman presid committe price stabil econom growth opportun make recommend adopt within administr think reason effect',
#  'know senat kennedi suggest speech cleveland yesterday committe particular effect',
#  'would suggest take credit would presum sinc committe form price line held well within unit state',
#  'well would say latter found uh somewhat unsatisfactori figur uh mr nixon use previous speech talk truman administr',
#  'mr truman came offic nineteen uh forti four end war uh difficulti face unit state period transit price control lift rather difficult use overal figur take seven half year compar last eight year',
#  'prefer take overal percentag record last twenti year democrat eight year republican show overal period growth',
#  'regard uh price stabil uh awar committe produc recommend ever certain congress point view legisl regard control price',
#  'regard exchang student labor union chairman subcommitte africa think one unfortun phase polici toward countri minut number exchang',
#  'think true latin america also',
#  'come forward program student congo three hundr feder govern africa previous year think uh move least two area suffici vigor',
#  'well think feder govern move program withdrew support uh think would complet uh econom chao',
#  'farmer plant spring harvest fall',
#  'hundr thousand',
#  'realli abl control market well',
#  'first foreign trip made recommend adopt',
#  'bring crop livestock mani time',
#  'would suggest propos could mention',
#  'question us point view parti want lead unit state',
#  'mean program better',
#  'question administr right thing',
#  'case believ program stimul creativ energi hundr eighti million free american',
#  'believ program senat kennedi advoc tendenc stifl creativ energi believ word program would lead stagnat motiv power need countri get progress',
#  'final point would like make senat kennedi suggest speech lack compass poor old other unfortun',
#  'let us understand throughout campaign motiv mine sincer',
#  'know mean poor',
#  'know mean see peopl unemploy',
#  'know senat kennedi feel deepli problem disagr goal america mean reach goal',
#  'fourteen year period time experi uh govern compar',
#  'second think question uh program advoc parti record lead',
#  'come democrat parti centuri produc woodrow wilson franklin roosevelt harri truman support sustain program discuss tonight',
#  'mr nixon come republican parti',
#  'nomin',
#  'fact last twenti five year republican leadership oppos feder aid educ medic care age develop tennesse valley develop natur resourc',
#  'think mr nixon effect leader parti',
#  'hope would grant',
#  'would rather difficult cover eight two half minut',
#  'point came congress year',
#  'purchas buy milk hog larg compani mani case therefor farmer posit bargain effect market place',
#  'agricultur economi collaps economi rest unit state sooner later collaps',
#  'farmer produc surplus govern ask legisl war',
#  'surplus respons indemnifi farmer period get rid farmer uh surplus',
#  'get surplus farmer back howev program announc see farm incom hold',
#  'would propos hold incom type program senat kennedi suggest would rais price one would indemnifi farmer pay farmer kind uh product surplus',
#  'well would suggest mr vanocur uh know presid probabl faceti remark',
#  'uh would also suggest insofar statement concern think would improp presid unit state disclos uh instanc member offici famili made recommend made year accept reject',
#  'presid alway maintain proper entitl get advic want cabinet advis without disclos anybodi includ matter fact congress',
#  'say',
#  'year sat nation secur council',
#  'cabinet',
#  'met legisl leader',
#  'met presid made great decis regard lebanon quemoy matsu matter',
#  'presid ask advic',
#  'sometim advic taken',
#  'say made decis',
#  'would say presid ever allow anybodi els make major decis presid make decis',
#  'advis give counsel ask',
#  'fundament reason let farmer go present time',
#  'think experi twenti shown free market could agricultur',
#  'recogn govern respons get farmer troubl present govern got',
#  'think work past think work futur',
#  'farmer number one market automobil industri unit state',
#  'automobil industri number one market steel',
#  'farmer economi continu declin sharpli recent year think would recess rest countri',
#  'think case govern intervent good one',
#  'second object present farm polici effect control bring suppli demand better balanc',
#  'drop support price order limit product work highest uh surplus nine billion dollar worth',
#  'uh higher tax load treasuri farmer last year lowest farm incom mani year',
#  'think farm polici fail',
#  'done government action',
#  'therefor suggest basic commod support feder govern endors farmer commod attempt bring suppli demand balanc attempt effect product control five six per cent surplus break price fifteen twenti per cent',
#  'think mr benson program fail',
#  'must say read vice presid speech farmer read mine believ much differ mr benson',
#  'think provid effect government control',
#  'think support price tie averag market price last three year mr benson theori',
#  'therefor believ sharp enough breach past give us hope success futur',
#  'made suggest need move direct govern control suggest would also mean rais price uh consum pay product im impos upon farmer uh control acreag even far today',
#  'think wrong direct',
#  'program advoc one depart present program respect',
#  'four democrat vote',
#  'third medic care age fight go twenti five year social secur',
#  'satisfi soviet union turn twice mani scientist engin',
#  'thing think countri make societi strong mean stand still',
#  'negro babi born true also puerto rican mexican citi one half much chanc get high school white babi',
#  'one third much chanc get colleg white student',
#  'third much chanc profession man half much chanc hous',
#  'uh four time much chanc work life white babi',
#  'think better',
#  'want talent american go wast',
#  'know want turn everyth govern',
#  'unit state develop tennesse valley built grand coule dam northwest unit state present rate hydropow product hallmark industri societi soviet union produc power',
#  'want state meet respons',
#  'argument use everi piec social legisl last twenti five year',
#  'peopl unit state individu could develop tennesse valley collect could',
#  'cotton farmer georgia peanut farmer dairi farmer wisconsin minnesota cannot protect forc suppli demand market place work togeth effect government program',
#  'seventeen million american live sixti five averag social secur check seventi eight dollar month abl sustain individu sustain social secur system',
#  'believ big govern believ effect government action',
#  'think way unit state go maintain freedom',
#  'way go move ahead',
#  'think better job',
#  'think also nation respons',
#  'satisfi fail develop natur resourc unit state fullest',
#  'satisfi see men like jimmi hoffa charg largest union unit state still free',
#  'think educ system second none',
#  'elect abraham lincoln said question whether nation could exist half slave half free',
#  'elect world around us question whether world exist half slave half free whether move direct freedom direct road take whether move direct slaveri',
#  'think depend great measur upon unit state kind societi build kind strength maintain',
#  'discuss tonight domest issu would want implic given involv direct struggl mr khrushchev surviv',
#  'mr khrushchev new york maintain communist offens throughout world product power soviet union',
#  'chines communist alway larg popul',
#  'import danger mount major effort within countri',
#  'kind countri kind societi kind strength build unit state defens freedom',
#  'well meet oblig move ahead think freedom secur around world',
#  'fail freedom fail',
#  'therefor think question american peopl much',
#  'strong',
#  'strong must go maintain independ go maintain hold hand friendship look us assist look us surviv',
#  'make clear think enough satisfi american progress make',
#  'satisfi unit state last year lowest rate econom growth major industri societi world',
#  'econom growth mean strength vital mean abl sustain defens mean abl meet commit abroad',
#  'satisfi nine billion dollar worth food rot even though hungri world even though four million american wait everi month food packag govern averag five cent day per individu',
#  'saw case west virginia unit state children took home part school lunch order feed famili think meet oblig toward american',
#  'satisfi mani teacher inadequ paid children go school part time shift',
#  'think go better job go meet respons time event place upon us',
#  'cannot turn job anyon els',
#  'want individu meet respons',
#  'think depend great measur countri',
#  'look problem unit state move ahead unit state move think well take advic famous campaign let look record',
#  'true administr senat kennedi charg administr retreat defeat stagnat',
#  'true far countri concern field electr power field mention move ahead',
#  'well comparison make',
#  'record truman administr seven half year seven half year eisenhow administr',
#  'compar two record area senat kennedi discuss tonight think find america move ahead',
#  'built school last seven half year built previous seven half matter previous twenti year',
#  'develop hydroelectr power seven half year develop previous administr histori',
#  'unit state fail whole caus freedom fail',
#  'true highway',
#  'let put term us understand',
#  'often hear gross nation product discuss respect may say compar growth administr previous administr total growth eleven percent seven year administr total growth nineteen per cent seven year',
#  'show growth administr predecessor',
#  'let put let put term averag famili',
#  'happen',
#  'find wage gone five time much eisenhow administr truman administr',
#  'price pay',
#  'find price pay went five time much truman administr eisenhow administr',
#  'net result',
#  'year year recoveri find six nine tenth per cent one highest world today',
#  'look growth g n p',
#  'find built administr previous administr',
#  'last year cours',
#  'happen recess year',
#  'reason franklin roosevelt good neighbor latin america good neighbor unit state',
#  'felt american societi move',
#  'want us recaptur imag',
#  'want peopl latin america africa asia start look america see thing wonder resid unit state look khrushchev look chines communist',
#  'franklin roosevelt said inaugur generat american rendezv destini',
#  'question freedom maintain sever tack attack ever known',
#  'think',
#  'think final analysi depend upon',
#  'think time america start move',
#  'think generat american rendezv',
#  'question cannot discuss intern affair unit state without recogn tremend bear intern posit',
#  'question nation cannot stand still dead competit competit men kremlin men peke',
#  'ahead competit senat kennedi think impli',
#  'race way stay ahead move ahead',
#  'subscrib complet spirit senat kennedi express tonight spirit unit state move ahead',
#  'disagre',
#  'think disagre implic remark tonight statement made mani occas campaign effect unit state stand still',
#  'thing senat kennedi said mani us agre',
#  'heard tonight exampl statement made growth nation product last year lowest industri nation world',
#  'second wrong analog make',
#  'want make posit absolut clear regard get intellig inform',
#  'cannot afford intellig gap',
#  'lost three thousand american live',
#  'rememb pearl harbor',
#  'unit state strong countri',
#  'connect senat kennedi critic presid ground express regret allow flight take place summit confer immedi summit confer occur',
#  'whenev anyth wrong express regret',
#  'knew flight go long reason broke confer',
#  'intend see unit state ever posit negoti soviet union discontinu intellig effort',
#  'seem critic wrong part',
#  'intend ever express regret mr khrushchev anybodi els someth support congress right purpos protect secur unit state',
#  'circumst',
#  'would give statutori author committe govern contract effect way get real progress made area sinc one everi four job held allot peopl govern contract',
#  'certain think us agre anybodi govern contract certain money spent contract ought disburs equal without regard race creed color individu employ',
#  'cours reject govern contract provis special session congress mr kennedi quit activ',
#  'far area concern think look presidenti leadership',
#  'speak presidenti leadership refer exampl attitud sit strike',
#  'talk negro mother',
#  'heard explain tri explain tell children go store buy loaf bread go store sit counter get coca cola',
#  'wrong someth',
#  'well attorney general unit state direct presid call owner chain store get take action',
#  'first wrong think th er even suggest mr khrushchev might continu confer express regret',
#  'place execut lead let sum say talk everi time south civil right',
#  'intent field civil right spell republican platform',
#  'think kenn senat kennedi wrong three count',
#  'therefor pass author aid bill first time realli sinc inter american bank found year ago develop realli look need latin america associ peopl',
#  'believ increas strength world',
#  'preach peopl south southern problem northern problem western problem problem us',
#  'also question free peopl cuba peopl want free go support attain freedom',
#  'cuba lost think kind defeatist talk senat kennedi help situat one bit',
#  'speech last night indic thought cuba one day would free',
#  'critic administr polici critic mr nixon press confer havana prais compet stabil bicta bict batista dictatorship dictatorship kill twenti thousand cuban seven year',
#  'second critic call free elect',
#  'critic failur administr use great influenc persuad cuban govern hold free elect particular',
#  'third arthur gardner republican ambassador earl smith republican ambassador success indic past six week report washington castro marxist raul castro communist got effect result',
#  'instead aid continu batista ineffect never side freedom never use influenc could use effect today cuba lost freedom',
#  'hope day rise think rise continu polici toward cuba recent year fact toward latin america almost ignor need latin america beam singl voic america program spanish latin america last eight year except three month hungarian uh revolut',
#  'mr morgan suggest unit state felt could save summit confer would proper us express regret',
#  'confus word strength judgment summit use would brought us closer peac rather lie told critic respons peopl afterward would far better us follow common diplomat procedur express regret tri move',
#  'judgment statement distort uh mr nixon other debat around countri discuss',
#  'u flight proper point view protect secur',
#  'accord intern law',
#  'said felt rather tell lie told rather indic flight would continu fact believ mr nixon said may fifteenth flight would continu even though mr herter testifi senat foreign relat committe cancel may twelfth would far better express regret would save summit summit use believ',
#  'point alway left fact express regret castro winter express regret eisenhow administr express regret flight southern russia',
#  'express regret flight eastern germani administr',
#  'soviet union express regret us bere sea incid',
#  'chines communist express regret us plane incid',
#  'accept procedur nation judgment follow advic theodor roosevelt strong maintain strong posit also speak soft',
#  'believ case intern custom call express regret would kept summit go judgment proper action',
#  'believ stronger',
#  'believ stronger militari forc',
#  'mr lodg meet press month ago said ever case law side u incid',
#  'respons leadership solv problem togeth',
#  'mr khrushchev came confer determin break',
#  'point made clear far korean war concern felt decis go war korea right necessari',
#  'would meet mr khrushchev unless agreement secondari level foreign minist ambassador would indic meet would hope success use exchang idea',
#  'go move sixti one two part maintain strength suffici vigor last year believ meet crisi next presid unit state send messag congress ask revit militari strength come spring late winter go face face serious berlin crisi sinc l fifti',
#  'go test strength',
#  'go test nerv',
#  'next presid unit state first year go confront serious question defens berlin commit berlin',
#  'negoti posit power balanc wave move away us extrem difficult reach success decis berlin well question',
#  'go summit ever meet think import unit state build strength build militari strength well econom strength',
#  'let say one uh point would add',
#  'view',
#  'disagr vice presid posit',
#  'circumst therefor strong urg strong hold opportun urg hold posit summit confer would gone care prepar mr khrushchev disgrac conduct pari disgrac conduct unit nation gave assur realli want sit talk accomplish someth make propaganda',
#  'well think winter sixti one present econom condit uh uh tax uh increas would desir',
#  'otherwis find head state meet make progress find caus peac hurt rather help',
#  'go break would knew go get way berlin key matter concern pari confer',
#  'question defend right',
#  'must build hope world dash case pari',
#  'would abl wou would will meet howev unless prepar confer would give us reason certainti reason certainti go success',
#  'would will presid meet mr khrushchev world leader would serv caus peac',
#  'far summit confer concern want make posit absolut clear',
#  'presid still go presid next four month cours one could commit countri period',
#  'would appropri',
#  'cours talk prime minist macmillan',
#  'incident senat kennedi disagre indic believ polici differ advoc today',
#  'say american peopl want go back polici',
#  'go anoth summit confer must negoti diplomat level ambassador secretari state other level prior time delin issu prepar way head state meet make progress',
#  'right time particular khrushchev countri man enslav million man slaughter thousand cannot continu situat point finger unit state america say deni right citizen',
#  'fact would deflationari would caus great unemploy would caus real slowdown economi',
#  'talk everi speech fact go difficult time nineteen sixti go meet respons citizen',
#  'paid money paid peopl money',
#  'add billion dollar expenditur pay',
#  'go work way',
#  'platform suggest done econom growth done effect mirror',
#  'think also add far senat kennedi propos concern intend carri platform one adopt los angel imposs make good promis without rais tax without rise price',
#  'tax tax enough pay outgo pay mani time higher price inflat simpli',
#  'would hesit ask american peopl pay tax even l necessari maintain sound economi also maintain sound dollar',
#  'hope econom elsewher',
#  'think may necessari tax',
#  'opinion go de greater',
#  'expenditur defens expenditur mutual secur expenditur econom assist technic assist go get less',
#  'ever becom necessari wise econom essenti secur would hesit suggest tax increas polici would defend unit state',
#  'well think illus whatev respons american peopl sixti',
#  'mere say elect presid best carri unit state difficult period would want peopl elect promis easi soft life',
#  'say know sixti bring except think bring hard time uh intern sphere hope move ahead home unit state confid far better job mobil economi resourc unit state',
#  'abl consum abl produc time soviet union make great econom gain',
#  'believ polici recommend came general head strengthen unit state',
#  'problem build uh militari strength extend uh polici abroad job home',
#  'move ahead provid viabl economi peopl suffici resourc consum produc countri move stronger set better exampl world',
#  'unit state began prepar great action world war ii post war period',
#  'would want anyon elect uh presid unit state vote expect life would easier elect',
#  'know futur go bring',
#  'talk willing bear burden order maintain freedom order meet freedom around globe',
#  'talk nation mood',
#  'think go difficult confid countri meet respons',
#  'regard cuba let make one thing clear',
#  'believ strong defens formosa',
#  'posit unit state treati treati organ american state prohibit us interf intern affair state prohibit well',
#  'democrat republican',
#  'student histori senat kennedi incident found histori countri mani great presid',
#  'way elect presid countri way',
#  'would never toler presid unit state hope senat kennedi chang mind elect',
#  'opinion kind woolli think led disast america korea',
#  'start chain reaction communist quemoy matsu formosa',
#  'uh forc nationalist alli get give communist',
#  'nationalist two island',
#  'two island area freedom',
#  'peopl live import',
#  'think far quemoy matsu concern question two littl piec real estat unimport',
#  'go came',
#  'mean',
#  'suppos hope made speech get war',
#  'secretari acheson made famous speech press club earli year k korean war start indic effect south korea beyond defens zone unit state',
#  'rememb period immedi korean war south korea suppos indefens well',
#  'disagre complet senat kennedi point',
#  'long essenti defens formosa judgment ever sinc time eisenhow doctrin far east line drawn sea around island',
#  'believ line case war drawn island instead island formosa',
#  'believ strong formosa believ meet commit everi countri whose secur guarante',
#  'believ strong berlin',
#  'think uh protect commit',
#  'general ridgway mr herter general collin admir spruanc mani other think unwis take chanc drag war may lead world war two island strateg defens accord testimoni essenti defens formosa',
#  'peopl way alway understood particular time certain man one countri need',
#  'believ elect tri determin lead free world america perhap senat kennedi alreadi indic import elect histori label wear wear count',
#  'stand',
#  'consequ think enough go republican audienc never say look vote republican',
#  'republican recent year last twenti five year last eight year oppos hous oppos care age oppos feder aid educ oppos minimum wage think record tell someth',
#  'import parti tell someth record',
#  'stand whole differ approach problem face countri home abroad',
#  'stand someth',
#  'republican parti produc mckinley hard coolidg dewey landon',
#  'stood strong foreign polici strong nation defens result produc wilson presid roosevelt presid truman',
#  'stood progress stood concern peopl welfar',
#  'democrat parti centuri stood someth',
#  'abraham lincoln great presid peopl select parti key time histori parti stood someth',
#  'well let say think parti import tell someth program someth man',
#  'suggest howev interest fair could give benefit also believ believ',
#  'leav hundr mile sea',
#  'sure believ deepli move way',
#  'move forward faster move sure program',
#  'say program field educ hous defens move america forward',
#  'far run away parti concern senat kennedi said compass poor progress enemi progress term use like',
#  'think peopl put america first rather parti first',
#  'believ peopl therefor ask make mind simpli basi vote way grandfath vote way mother',
#  'peopl make mind',
#  'peopl one determin',
#  'may republican may democrat',
#  'mean best leadership',
#  'involv question leadership whole free world',
#  'think enough senat kennedi go audienc democrat side say vote democrat',
#  'deepli believ',
#  'decis final nationalist make believ consult attempt work plan line drawn island formosa',
#  'second would suggest withdraw point communist gun',
#  'leav rather air defend condit think mistak',
#  'point thing wrong think ought emphas america strength',
#  'best fed best cloth better distribut world good peopl peopl histori',
#  'peopl go bed hungri unit state far less incident use go bed hungri came power end truman administr',
#  'true',
#  'think help suggest glad correct extent seventeen million peopl go bed hungri everi night unit state',
#  'think harm time mr khrushchev harm wrong',
#  'think say prestig time low',
#  'respons accur misstat case',
#  'would also like point far senat kennedi comment concern think perfect right respons critic administr whenev think wrong',
#  'administr stop quemoy matsu stop indochina stop lebanon stop part world',
#  'truman administr six hundr million peopl went behind iron curtain includ satellit countri eastern europ communist china',
#  'necessari run america order build',
#  'like know defeat retreat',
#  'incident point senat kennedi attack foreign polici',
#  'critic polici made necessari go korea',
#  'well first agre senat kennedi cuba lost certain china lost administr came power',
#  'look cuba today believ follow right cours cours difficult cours circumst proper one see cuban peopl get chanc realiz aspir progress freedom get cooper organi state organ american state',
#  'point fact visit cuba mr batista power',
#  'point go judg administr term attitud toward dictat glad comparison previous administr',
#  'today three left includ one cuba',
#  'think pretti good progress',
#  'senat kennedi also indic regard cuba thought made mistak cuba call free elect countri',
#  'surpris senat kennedi foreign relat committe would made statement kind',
#  'matter fact book strategi peac took right posit',
#  'said polici led defeat retreat',
#  'made statement would direct uh opposit treati',
#  'get absolut clear senat kennedi must candid candid fifti two critic us wrong',
#  'hand respons accur',
#  'come defens',
#  'believ defend formosa',
#  'one problem think time south korea question whether unit state would defend attack',
#  'general ridgway said thing',
#  'admir spruanc callin said attempt defend island confer far east',
#  'mr herter secretari state said strateg undefens',
#  'extrem difficult make judgment',
#  'say defend part general attack formosa',
#  'island mile five six mile coast red china within general harbor area hundr mile formosa',
#  'say program leadership fail program leadership america need',
#  'well unit state uh occas attempt uh most middl fifti persuad chiang kai shek pull troop back formosa',
#  'effect job way',
#  'believ subject balanc budget unless nation emerg unless sever recess',
#  'said last week believ balanc budget',
#  'second mr nixon continu state state last week fantast figur democrat budget would c uh platform would cost',
#  'ought tri meet problem',
#  'get mani case adequ shelter',
#  'believ compar figur may india countri serious problem rememb prosper countri world peopl get adequ food',
#  'tell one use bean instead meat unit state twenti five million accord mr benson well fed adequ fed',
#  'seen good mani hundr thousand peopl uh adequ fed',
#  'defin someon use bean place meat',
#  'mr benson testifi food stamp plan said twenti five million american could afford elementari low cost diet',
#  'well mr nixon uh give testimoni mr georg aiken senat georg aiken rank minor member republican member former chairman senat agricultur committe testifi said twenti six million american incom afford decent diet',
#  'respons correct everi time misstat case intend continu',
#  'unless sever recess worst unbalanc budget histori twelv billion dollar larger administr histori unit state',
#  'second believ ca far better unit state instead concentr aid particular underdevelop world surplus militari equip pour three hundr million dollar surplus militari equip lao',
#  'compar econom progress countri truman administr eisenhow administr find everi index tr great deal perform progress administr one',
#  'offer retread program fail',
#  'like point last six year democrat congress member cut twenti million dollar voic america program',
#  'senat kennedi moment ago refer fact adequ voic america program latin america',
#  'well need exampl econom assist need technic assist need exchang need program diplomat charact effect area',
#  'tool need fight us',
#  'fought primarili asia africa latin america',
#  'cold war recogn fought develop program deal',
#  'everi time unit state one side side posit sustain',
#  'test prestig',
#  'look vote unit nation past seven half year',
#  'one side side',
#  'also cut four billion dollar mutual secur last six year',
#  'look exampl vote congo',
#  'would suggest premier kush khrushchev uh perform unit nation compar presid eisenhow eloqu speech present time communist prestig world time low american prestig time high',
#  'senat kennedi hit point',
#  'first hear prestig time low',
#  'far present situat concern think time nail distort unit state put',
#  'alway case long communist intern scene aggress tac uh tendenc present follow',
#  'mr morgan matter well cold war well',
#  'field execut leadership say believ essenti presid unit state set tone also must lead must act talk',
#  'submit look program program exampl regard feder reserv uh free money loos money uh high low interest rate program econom field general program adopt tri truman administr',
#  'need action',
#  'say need high hope',
#  'cours one factor signific one',
#  'also cut two billion dollar defens',
#  'talk record well recogn stand record well',
#  'let summar say satisfi cold war believ step activ launch offens mind heart soul men',
#  'senat fulbright senat humphrey tri',
#  'would strengthen develop loan fund',
#  'believ case india africa latin america emphasi',
#  'permit us make sure project invest go produc greater wealth',
#  'permit maintain self respect',
#  'believ instead concentr aid long term loan peopl pay back either hard money local currenc',
#  'meet condemn russian infiltr cuba',
#  'program put forward summer broke sugar quota cuba realli done want get',
#  'wholli indiffer latin america last month',
#  'rockefel brother report general ridgway general gavin gaither report various report congression committe indic relat strength p unit state militarili polit psycholog scientif industri relat strength unit state compar soviet union chines communist togeth deterior last eight year know american peopl told fact',
#  'governor rockefel far critic june posit world',
#  'gallup poll taken februari year ask eight nine countri ask peopl think would ahead militarili scientif major eight nine countri said soviet union would',
#  'maintain posit prestig',
#  'last year twenti nine tomorrow preliminari vote held see strengthen posit close',
#  'third seven vote favor admiss red china unit nation',
#  'know vote held week five neutralist general regard defeat unit state',
#  'second question posit unit nation',
#  'congress unit state appropri six hundr seventi seven million dollar mare presid will use till week ago',
#  'respons amend senat monroney strengthen ground forc',
#  'nineteen fifti three tri put appropri five billion dollar defens',
#  'cours mr nixon wholli inaccur say congress provid fund fact presid recommend nation defens',
#  'got get help congress order',
#  'must econom must technolog must ideolog',
#  'special session congress also session preced democrat congress two one democrat major ask presid give us fund give us power job noth special session senat kennedi call signal along senat johnson turn vote give us power despit fact bill alreadi consid alreadi hear congress alreadi knew',
#  'unless readi carri program like sixti battl econom surviv peopl wage go lost',
# ...
#  'let make clear bill mr nixon talk mention wilk barr scranton mention west virginia',
#  'pass bill year cong senat die rule committe hous repres',
#  'pass area redevelop bill far effect bill administr suggest two occas presid veto time',
#  'came committe chairman labor subcommitte fifti five',
#  'familiar',
#  'expect come',
#  'must use weapon purpos combat recess come',
#  'favor rather massiv feder spend program come effect usual long pass recessionari period',
#  'mean tax reform necessari tax cut stimul job',
#  'second addit get recessionari period move part economi repres privat sector mean stimul part economi creat job privat sector economi',
#  'bill far effect',
#  'believ power prestig last eight year declin',
#  'issu go futur',
#  'issu mr nixon',
#  'offer',
#  'look senat kennedi credenti suggest move america faster',
#  'stand someth stand someth build',
#  'proud record administr',
#  'particip discuss lead decis administr',
#  'let make posit cl ear',
#  'glad hear tonight suggest experi',
#  'first debat indic experi least uh particip signific make decis',
#  'well first think senat kennedi make mind regard respons',
#  'think choic clear involv futur',
#  'believ administr met respons last eight year power relat communist declin face hazard time sixti unless unit state begin move unless start go ahead believ go meet respons peopl caus freedom',
#  'experi',
#  'mr nixon part administr',
#  'uh clear decis last eight year',
#  'less two hundr countri africa need train leadership anyth',
#  'gave scholarship congo summer offer given africa year',
#  'africa unit state ignor latin uh africa',
#  'view prevail make greater nation intern effort lost prestig latin america presid brazil new incumb run offic call castro campaign thought import get vote support castro latin america',
#  'disagre fundament posit unit state view prevail think go bring import result countri sixti',
#  'argument mr nixon issu american peopl make judgment think import judgment',
#  'presid eisenhow move scene januari twentieth next four year critic year',
#  'believ american peopl make choic novemb eighth view whether move ahead faster whether satisfactori whether build greater strength home abroad mr nixon view',
#  'feel move ahead uh go recess countri econom feel power prestig stronger ever relat communist move ahead',
#  'believ economi sound go move',
#  'final regard whole problem combat recess call must use full resourc govern respect one must see credit expand go recessionari period understand believ go recess',
#  'program educ program case equal job opportun one would also deal older citizen',
#  'go combat unemploy better job area',
#  'question summit agre posit mr nixon',
#  'mani program talk econom growth care age develop natur resourc build strength unit state',
#  'use steel capac fifti five per cent today',
#  'thing right unit state emphas less peopl go bed hungri unit state major countri world',
#  'tell surplus food distribut five cent po per person n near six million american receiv adequ',
#  'never said flat defend quemoy matsu attack',
#  'believ get w go get war defens formosa ought clear defin line',
#  'primarili ideolog battl battl mind heart soul men',
#  'point would make regard econom assist technic assist unit state must rest case alon',
#  'unless adequ fund exampl inform cut congress adequ fund technic assist',
#  'think mani way elect import sinc certain almost centuri',
#  'must get across world',
#  'must associ aspir',
#  'also mind someth els regard whole situat world america move forward must think term fight communism must also think primarili term interest countri',
#  'need step exchang need step technic assist train peopl newli develop countri oper economi',
#  'also tremend import bear mind pour money without pour technic assist w well disastr situat',
#  'senat kennedi put great deal stress necess econom assist',
#  'build economi way afford thing must',
#  'believ',
#  'believ essenti next ten year balanc power go begin move world one direct anoth toward us toward communist unless begin identifi anti communist fight also fight poverti hunger peopl go begin turn communist exampl',
#  'countri move ahead develop economi fullest judgment resourc meet militari commit also commit oversea',
#  'goe surviv',
#  'must let know great american ideal independ right peopl free right progress ideal belong alon belong everybodi',
#  'third believ step use surplus food area abl get peopl back work',
#  'floor manag',
#  'senat kennedi made strong critic part alleg part happen cuba',
#  'second consid problem unemploy realiz',
#  'made recommend discuss previous spell campaign',
#  'point one highest prioriti must get bill depress area next congress',
#  'hand found bill got legisl difficulti consequ action taken',
#  'bill presid submit would provid aid area realli need area like scranton wilk barr area west virginia one senat kennedi support',
#  'last congress special session congress bill one presid one senat kennedi member parti',
#  'combat unemploy first must concentr area refer call depress area',
#  'must stand ideal',
#  'must meet communist pure field gross atheist materi',
#  'well mr nixon state record inaccur regard depress area bill',
#  'analyz figur find unemploy exist among older citizen exist also among inadequ train adequ opportun educ',
#  'eleven dictat south america central america came',
#  'first place never suggest cuba lost except present',
#  'presid unit state someth right someth purpos defend secur countri surpris attack never express regret apolog anybodi includ mr khrushchev',
#  'think make progress first field employ',
#  'second field school believ provis wherebi feder govern would give assist district want integr school',
#  'situat caus us concern caus us concern denial right peopl equal think belong everybodi',
#  'goldfish bowl world',
#  'let look also',
#  'seventi vote posit none',
#  'look ought futur',
#  'tri provid appropri billion half five year long term loan basi administr oppos',
#  'question defend guantanamo attack',
#  'also exist among minor group',
#  'let look situat regard econom growth realli',
#  'let look vote congo vote seventi noth soviet union',
#  'stimul incent compani go explor oil develop',
#  'well would say first senat kennedi statement made go help gallup poll abroad go help prestig either',
#  'could look also item senat kennedi name conclud say whole matter prestig final analysi whether stand right',
#  'well ahead stay ahead provid confid america run order build',
#  'includ oil includ kind miner includ everyth within rang taxat',
#  'want sure fair equit',
#  'perhap oil abroad treat differ oil home',
#  'oil industri recent hard time',
#  'particular smaller produc',
#  'move eight nine day texa',
#  'assur elect presid whole spectrum tax gone care',
#  'get back matter discuss outset matter quemoy matsu',
#  'inequ oil commod would vote close loophol vote past reduc deplet allow largest produc five million dollar maintain twenti seven half per cent',
#  'senat kennedi posit mine complet differ',
#  'favor present deplet allow',
#  'favor want make lot oil men rich want make america rich',
#  'deplet allow',
#  'deplet allow certain believ present amount would oil explor cut substanti countri',
#  'far posit concern exact opposit senat',
#  'belief america go growth talk talk want thing discourag individu enterpris discourag peopl go discov oil miner encourag',
#  'suggest number item whole deplet field could taken account',
#  'also said moment ago would get money financ program revis tax law includ deplet',
#  'believ studi allow tax expens dividend expens rest make determin stimul growth provid revenu need move countri forward',
#  'think noth greater blow prestig unit state among free nation asia us take senat kennedi advan advic go go major member senat democrat republican said say advanc surrend area communist',
#  'word unit state go maintain strength prestig must strong militarili econom must firm diplomat',
#  'thi certain speak know whether retreat defeat',
#  'whole th unit state treati vote unit state senat defend formosa pescador island',
#  'treati includ two island',
#  'believ move full time missil product particular minuteman polari',
#  'mani war histori mankind',
#  'may succeed',
#  '',
#  'certain go peac give indic advanc go defend becom symbol freedom',
#  'would take action necessari defend treati formosa pescador island',
#  'suggest support',
#  'last televis debat point posit american must choos best man either parti could produc',
#  'uh also get uh opportun question question next televis debat',
#  'difficulti presid cours quit limit',
#  'judgment program vice presid put forward extens mr benson program cost billion dollar present program cost six billion dollar year expens histori',
#  'believ ought pay bill inflat phoni interest rate',
#  'got grow enough maintain forc abroad wage non militari battl war uh world asia africa latin america',
#  'move area program make adequ use resourc area',
#  'would exact wrong thing',
#  'oppos want us oil explor less',
#  'believ must abl compet market steel basic commod abroad must abl compet alway technolog lead',
#  'everi ca african countri either abstain vote us',
#  'let rememb way win retreat surrend',
#  'point far deplet allow concern oil deplet allow one provid eighti percent involv deplet go get much revenu insofar deplet allow concern unless move area indic',
#  'let look side coin',
#  'oppos reason mention',
#  'mean must continu balanc budget home everi possibl circumst moment loss confid fiscal polici home result gold flow',
#  'signific prestig realli identifi caus freedom',
#  'therefor mount rise influenc spread prestig spread uh stand razor edg decis us communist system wonder whether use system freedom develop countri system communism persuad follow exampl',
#  'sever indic prestig high',
#  'mr georg allen head inform servic said result second space sputnik quot believ paraphras accur',
#  'said mani countri equat space develop scientif product scientif advanc',
#  'therefor said mani countri feel soviet union backward par unit state',
#  'second econom growth soviet union greater',
#  'mr dull suggest two three time great',
#  'great effect underdevelop world face problem low incom high popul densiti inadequ resourc',
#  'well think mani uh test mr drummond prestig',
#  'three gallup poll taken februari ask peopl ten countri countri thought would first scientif militarili',
#  'four vote u n particular vote deal red china last saturday receiv support posit taken two african countri one liberia tie us centuri union south africa popular countri africa',
#  'countri vote us asia issu vote us',
#  'neutralist resolut much oppos thing happen',
#  'candid candid presid brazil took trip cuba call mr castro elect order get benefit castro support uh within brazil',
#  'guinea ghana two independ countri within last three year guinea fifti seven ghana within last eighteen month support soviet foreign polici u n mr herter said',
#  'lao move direct',
#  'would say prestig high',
#  'longer give imag rise',
#  'longer give imag vital',
#  'major everi countri except greec felt would soviet union l',
#  'persuad countri restrict good come act dollar gap third persuad assum respons till maintain assist underdevelop countri africa latin america asia make econom breakthrough',
#  'sure maintain',
#  'dollar shortag yet mani countri continu move good',
#  'second increas export compar import',
#  'strong program go forward depart commerc',
#  'beyond far gold suppli concern far movement gold concern uh bear mind must get help alli abroad great ventur free men involv win battl freedom',
#  'america carri tremend load respect',
#  'think right carri',
#  'favor program abroad econom assist militari assist',
#  'find countri europ exampl aid japan aid far east countri former enemi recov complet',
#  'got bear greater share load econom assist abroad',
#  'advoc develop cours next administr cours get opportun program enlist aid countri concert basi program econom develop africa asia latin america',
#  'unit state cannot continu carri major share burden',
#  'big share got help friend abroad three factor think help revers gold flow spoke',
#  'uh correct record mr nixon said deplet record opposit mine',
#  'said matter thorough gone make sure loophol',
#  'record opposit mean want go',
#  'question gold',
#  'difficulti cours heavi oblig abroad therefor maintain favor balanc trade also send good deal dollar oversea pay troop maintain base sustain economi',
#  'word go continu maintain posit sixti maintain sound monetari fiscal polici',
#  'control inflat also favor balanc trade',
#  'abl compet world market',
#  'abl sell abroad consum uh abroad go abl meet oblig',
#  'addit mani countri around world still keep restrict goad go way back day dollar shortag',
#  'von fremd first thing continu keep confid abroad american dollar',
#  'one must step',
#  'know weapon vice presid talk',
#  'uh mr mcgee hundr four commod kind deplet allow differ kind miner includ oil',
#  'stand',
#  'concept complet repugn',
#  'general ridgway said chief staff go war quemoy matsu would seem unwarr tragic cours take',
#  'general twine said still',
#  'uh sent mission presid mr uh robertson admir radford',
#  'suggest chiang kai shek administr attempt sinc persuad chiang kai shek lessen troop commit',
#  'talk vice presid determin guarante quemoy matsu four five mile coast red china within treati area',
#  'complet sustain treati',
#  'therefor treati commit unit state defend anyth except formosa pescador deal act treati area',
#  'done much thought deliber',
#  'mr dull press confer said treati republ china exclud quemoy matsu treati area',
#  'think possibl mr nixon state record distort fact precis',
#  'instanc good intent cours desir peac',
#  'road war alway pave good intent',
#  'stand secretari state mr herter said island indefens',
#  'may say would trust senat kennedi would chang posit chang long major presidenti candid continu suggest go turn island encourag aggressor chines communist soviet aggressor press unit state press us point war would inevit',
#  'incident senat johnson among reject posit vote seventi twelv',
#  'think senat right includ major democrat major republican reject senat kennedi posit',
#  'learn lesson korea must learn',
#  'went tragic experi lead world war ii',
#  'point follow cours action indic go defend particular area inevit result encourag man determin conquer world press point return',
#  'first quemoy matsu next may formosa',
#  'whenev inevit dictat encourag tri',
#  'uh relat moment ago presid alway indic must make mistak deal dictat indic go make concess point gun',
#  'far presid eisenhow concern often heard discuss question',
#  'mani infantrymen enough heavi artilleri certain think implic secretari dull statement quemoy matsu defend event attack attack preliminari attack formosa',
#  'well mr drummond first refer secretari dull press confer think read know find secretari dull also indic press confer troop withdrawn quemoy implic certain everyth said quemoy could better defend',
#  'amend put senat unit state record major senat parti vote well major republican put record posit senat take surrend indic advanc unit state defend offshor island',
#  'forget debat formosa resolut said vote vote amend record amend particular amend say pass senat overwhelm seventi twelv',
#  'comment senat kennedi last answer',
#  'senat right knew lesson histori',
#  'must absolut guarante',
#  'believ meet commit chines communist attack pescador formosa know mean war',
#  'mere say treati quit precis sustain treati',
#  'object constant refer surrend island',
#  'refer question regard quemoy matsu',
#  'answer unit state afford es es espionag lack uh lag say uh intellig lag afford missil lag',
#  'answer cours communist espionag goe time',
#  'note exampl read uh particular discuss senat kennedi dave garroway short uh statement regret uh made statement felt particular flight uh one occur right time indic would mr khrushchev felt uh flight uni would felt mr khrushchev ha uh flight unit state uh visit',
#  'think presid correct certain decis continu flight confer go',
#  'think presid correct order flight',
#  ...]

# %%
# add clean text to dataframe
df["Clean_text"] = pd.Series(data)

# %%
df.head()
# Out:
#        Sentence_id                                               Text  \
# index
# 0             8211                   Now, this is not standing still.
# 1             8515  So these are three programs which are quite mo...
# 2             8514  The proposal advanced by you and by Mr. Javits...
# 3             8513         It does not put a deficit on the Treasury.
# 4             8512  The third is medical care for the aged which i...
#
#                 Speaker   Speaker_title Speaker_party         File_id  Length  \
# index
# 0      Richard M. Nixon  Vice President    REPUBLICAN  1960-09-26.txt       6
# 1       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt       9
# 2       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt      42
# 3       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt       9
# 4       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt      22
#
#        Line_number  Sentiment  Verdict       date  mos_before_election  \
# index
# 0              114  -0.417840       -1 1960-09-26                    2
# 1              418   0.249581       -1 1960-09-26                    2
# 2              417  -0.626563        1 1960-09-26                    2
# 3              416  -0.629486        1 1960-09-26                    2
# 4              415   0.000000       -1 1960-09-26                    2
#
#                                               Clean_text
# index
# 0                                            stand still
# 1                               three program quit moder
# 2      propos advanc mr javit would cost six hundr mi...
# 3                                   put deficit treasuri
# 4      third medic care age tie social secur financ s...

# %%
mask = df["date"].dt.year < 2012

X_train = df.loc[mask, "Clean_text"].values
y_train = df.loc[mask, "Verdict"].values

X_test = df.loc[~mask, "Clean_text"].values
y_test = df.loc[~mask, "Verdict"].values

# %% [markdown]
# # Word Embedding using keras - NOT WORKING YET :D

# %%
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
# defining vocabulary
vocabulary = {}
sentences_len = []
for sentence in X_train:
    for term in sentence.split():
        vocabulary.setdefault(term, len(vocabulary))

# %%
# Defining vocabulary size
vocabulary_size = list(vocabulary.values())[-1] + 1

print(f"vocabulary is composed of {vocabulary_size} unique words")
# Out:
# vocabulary is composed of 6388 unique words

# %% [markdown]
# ## One hot encoding representation

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# Encodding train data

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)
encoded_docs = tokenizer.texts_to_sequences(X_train)

# %% [markdown]
# Encodding Test data

# %%
encoded_test = tokenizer.texts_to_sequences(X_test)

# %% [markdown]
# ## Padding sequences

# %%
# finding max sentence length

vec_lengths = []
for i in encoded_docs:
    vec_lengths.append(len(i))


max_length = np.unique(vec_lengths)[-1]

# %%
embedded_docs=pad_sequences(encoded_docs,padding='post',maxlen=max_length)
print(embedded_docs)
# Out:
# [[ 190  179    0 ...    0    0    0]
#  [ 163   41  658 ...    0    0    0]
#  [ 113  933   37 ...    0    0    0]
#  ...
#  [   2 2635   19 ...    0    0    0]
#  [ 135   60  608 ...    0    0    0]
#  [4353  230    3 ...    0    0    0]]

# %% [markdown]
# For training

# %%
embedded_docs.shape
# Out:
# (18170, 65)

# %% [markdown]
# For testing

# %%
embedded_test=pad_sequences(encoded_test,padding='post',maxlen=max_length)
print(embedded_test.shape)
# Out:
# (5363, 65)

# %% [markdown]
# ## Creating the model

# %%
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import GlobalMaxPool1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D
import tensorflow.keras.backend

# %%
tensorflow.keras.backend.clear_session()

# %%
labels = df['Verdict'].copy()

# %%
labels = labels.apply(lambda x: 1 if x==1 else 0)

# %%
# Preparing for training the model
X_embedded = np.array(embedded_docs)
y = labels
#y = df['Verdict'].values

# check shapes
print(f"X shape: {X_embedded.shape}. y shape: {y.shape}")

# %%
# Train test split
X_embedded_train = X_embedded[:sum(mask)]
y_embedded_train = y[:sum(mask)]

X_embedded_test = X_embedded[sum(mask):]
y_embedded_test = y[sum(mask):]

print('Train shape: ', (X_embedded_train.shape, y_embedded_train.shape))
print('Test shape: ', (X_embedded_test.shape, y_embedded_test.shape))

# %%
tensorflow.keras.backend.clear_session()

# %%
model_conv = Sequential()
model_conv.add(Embedding(vocabulary_size, 100, input_length=max_length))
model_conv.add(Dropout(0.2))
model_conv.add(Conv1D(100, 8, activation='relu'))
model_conv.add(MaxPooling1D(pool_size=10))
model_conv.add(LSTM(100))

model_conv.add(Dense(1, activation='sigmoid'))
model_conv.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model_conv.summary()

# %%
model_conv.fit(X_embedded_train,y_embedded_train, validation_split=0.4, epochs = 10)

# %% [markdown]
# ## Encoding the labels for multiclass problem

# %%
from sklearn.preprocessing import OneHotEncoder
one_hot_encoder = OneHotEncoder(sparse=False)
one_hot_encoder.fit(y_train.reshape(-1, 1))
y_encoded = one_hot_encoder.transform(y_train.reshape(-1, 1))

y_encoded.shape
# Out:
# (18170, 3)

# %%
embedded_docs.shape
# Out:
# (18170, 65)

# %%
y_encoded_test = one_hot_encoder.transform(y_test.reshape(-1,1))
y_encoded_test.shape
# Out:
# (5363, 3)

# %%
type(y_encoded)
# Out:
# numpy.ndarray

# %%
from tensorflow.keras.layers import GlobalMaxPooling1D
from tensorflow.keras.layers import Conv1D
import tensorflow
tensorflow.keras.backend.clear_session()

# %%
embedding_dim = 100

model = Sequential()
model.add(Embedding(vocabulary_size, embedding_dim, input_length=max_length))
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(10, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 65, 100)           638800
#
#  conv1d_1 (Conv1D)           (None, 61, 128)           64128
#
#  global_max_pooling1d_1 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense (Dense)               (None, 10)                1290
#
#  dense_1 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 704,251
# Trainable params: 704,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(embedded_docs,,validation_data=0.2,epochs=10)
# Out:
# Epoch 1/10
#  72/568 [==>...........................] - ETA: 4s - loss: 0.8714 - accuracy: 0.6593
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41108/1149769194.py in <module>
# ----> 1 model.fit(embedded_docs,y_encoded.values,validation_data=0.2,epochs=10)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# InvalidArgumentError:  indices[6,17] = 6388 is not in [0, 6388)
# 	 [[node sequential_1/embedding_1/embedding_lookup
#  (defined at C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\layers\embeddings.py:191)
# ]] [Op:__inference_train_function_921]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node sequential_1/embedding_1/embedding_lookup:
# In[0] sequential_1/embedding_1/embedding_lookup/641:
# In[1] sequential_1/embedding_1/Cast (defined at C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\layers\embeddings.py:190)
#
# Operation defined at: (most recent call last)
# >>>   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 197, in _run_module_as_main
# >>>     return _run_code(code, main_globals, None,
# >>>
# >>>   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\runpy.py", line 87, in _run_code
# >>>     exec(code, run_globals)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel_launcher.py", line 16, in <module>
# >>>     app.launch_new_instance()
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\traitlets\config\application.py", line 846, in launch_instance
# >>>     app.start()
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\kernelapp.py", line 677, in start
# >>>     self.io_loop.start()
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\tornado\platform\asyncio.py", line 199, in start
# >>>     self.asyncio_loop.run_forever()
# >>>
# >>>   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\asyncio\base_events.py", line 601, in run_forever
# >>>     self._run_once()
# >>>
# >>>   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\asyncio\base_events.py", line 1905, in _run_once
# >>>     handle._run()
# >>>
# >>>   File "C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.9_3.9.3312.0_x64__qbz5n2kfra8p0\lib\asyncio\events.py", line 80, in _run
# >>>     self._context.run(self._callback, *self._args)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\kernelbase.py", line 457, in dispatch_queue
# >>>     await self.process_one()
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\kernelbase.py", line 446, in process_one
# >>>     await dispatch(*args)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\kernelbase.py", line 353, in dispatch_shell
# >>>     await result
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\kernelbase.py", line 648, in execute_request
# >>>     reply_content = await reply_content
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\ipkernel.py", line 345, in do_execute
# >>>     res = shell.run_cell(code, store_history=store_history, silent=silent)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
# >>>     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 2898, in run_cell
# >>>     result = self._run_cell(
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 2944, in _run_cell
# >>>     return runner(coro)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
# >>>     coro.send(None)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 3169, in run_cell_async
# >>>     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 3361, in run_ast_nodes
# >>>     if (await self.run_code(code, result,  async_=asy)):
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\IPython\core\interactiveshell.py", line 3441, in run_code
# >>>     exec(code_obj, self.user_global_ns, self.user_ns)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Temp/ipykernel_41108/1149769194.py", line 1, in <module>
# >>>     model.fit(embedded_docs,y_encoded.values,validation_data=0.2,epochs=10)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 1216, in fit
# >>>     tmp_logs = self.train_function(iterator)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 878, in train_function
# >>>     return step_function(self, iterator)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 867, in step_function
# >>>     outputs = model.distribute_strategy.run(run_step, args=(data,))
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 860, in run_step
# >>>     outputs = model.train_step(data)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\training.py", line 808, in train_step
# >>>     y_pred = self(x, training=True)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\sequential.py", line 373, in call
# >>>     return super(Sequential, self).call(inputs, training=training, mask=mask)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\functional.py", line 451, in call
# >>>     return self._run_internal_graph(
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\functional.py", line 589, in _run_internal_graph
# >>>     outputs = node.layer(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py", line 64, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\engine\base_layer.py", line 1083, in __call__
# >>>     outputs = call_fn(inputs, *args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\utils\traceback_utils.py", line 92, in error_handler
# >>>     return fn(*args, **kwargs)
# >>>
# >>>   File "C:\Users\bruna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\keras\layers\embeddings.py", line 191, in call
# >>>     out = tf.nn.embedding_lookup(self.embeddings, inputs)
# >>>
