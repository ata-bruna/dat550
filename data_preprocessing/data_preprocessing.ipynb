# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
import re

# %% [markdown]
# # Loading and merging the data

# %%
file1 = pd.read_csv("../data/crowdsourced.csv", encoding='utf-8')
file2 = pd.read_csv("../data/groundtruth.csv", encoding='utf-8')
df = pd.concat([file1, file2])


df["date"] = df["File_id"].str.strip(to_strip=".txt")

df["date"] = pd.to_datetime(df["date"])
df.sort_values("date", inplace= True)
df["mos_before_election"] = 11 - df["date"].dt.month

df['index'] = pd.RangeIndex(len(df))
df.set_index('index', inplace=True)
df
# Out:
#        Sentence_id                                               Text  \
# index
# 0             8211                   Now, this is not standing still.
# 1             8515  So these are three programs which are quite mo...
# 2             8514  The proposal advanced by you and by Mr. Javits...
# 3             8513         It does not put a deficit on the Treasury.
# 4             8512  The third is medical care for the aged which i...
# ...            ...                                                ...
# 23528        34028  First of all, the media is so dishonest and so...
# 23529        34027        What I've seen -- what I've seen is so bad.
# 23530        34026                       I'll look at it at the time.
# 23531        34039                 So I talk about the corrupt media.
# 23532        33341  They work hard, they do everything they can to...
#
#                 Speaker       Speaker_title Speaker_party         File_id  \
# index
# 0      Richard M. Nixon      Vice President    REPUBLICAN  1960-09-26.txt
# 1       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 2       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 3       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# 4       John F. Kennedy             Senator      DEMOCRAT  1960-09-26.txt
# ...                 ...                 ...           ...             ...
# 23528      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23529      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23530      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23531      Donald Trump         Businessman    REPUBLICAN  2016-10-19.txt
# 23532   Hillary Clinton  Secretary of State      DEMOCRAT  2016-10-19.txt
#
#        Length  Line_number  Sentiment  Verdict       date  mos_before_election
# index
# 0           6          114  -0.417840       -1 1960-09-26                    2
# 1           9          418   0.249581       -1 1960-09-26                    2
# 2          42          417  -0.626563        1 1960-09-26                    2
# 3           9          416  -0.629486        1 1960-09-26                    2
# 4          22          415   0.000000       -1 1960-09-26                    2
# ...       ...          ...        ...      ...        ...                  ...
# 23528      17          907   0.032300       -1 2016-10-19                    1
# 23529       9          906  -0.669600       -1 2016-10-19                    1
# 23530       7          905   0.000000       -1 2016-10-19                    1
# 23531       7          918   0.000000       -1 2016-10-19                    1
# 23532      14          220   0.361200       -1 2016-10-19                    1
#
# [23533 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23533 entries, 0 to 23532
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sentence_id          23533 non-null  int64
#  1   Text                 23533 non-null  object
#  2   Speaker              23533 non-null  object
#  3   Speaker_title        23533 non-null  object
#  4   Speaker_party        23533 non-null  object
#  5   File_id              23533 non-null  object
#  6   Length               23533 non-null  int64
#  7   Line_number          23533 non-null  int64
#  8   Sentiment            23530 non-null  float64
#  9   Verdict              23533 non-null  int64
#  10  date                 23533 non-null  datetime64[ns]
#  11  mos_before_election  23533 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# # Data preprocessing

# %%
def remove_punctuation(text):
    tokens = re.sub('[^a-zA-Z]', ' ', text).lower()
    return tokens

# %%
def remove_stop_words(text):
    stop_words = stopwords.words('english')
    word_list = [word for word in text.split() if word not in stop_words]
    return word_list

# %%
def get_word_stemm(word_list):
    """Stemmers remove morphological affixes from words, leaving only the word stem."""
    stemmer = SnowballStemmer('english')
    singles = [stemmer.stem(word) for word in word_list] 
    return singles

# %%
def preprocess_data(docs, stemming=False):

    text_list = [] 
    for doc in docs:  
        # 1. Remove punctuation and set as lower case
        text = remove_punctuation(doc)

        # 2. Remove stop words and extra spaces
        word_list = remove_stop_words(text)

        if stemming:
            # 3. Stemming
            word_list = get_word_stemm(word_list)

        joined_text = " ".join(word_list)
        text_list.append(joined_text)
        
    return text_list

# %%
data = preprocess_data(df.Text.values)

# %%
data
# Out:
# ['standing still',
#  'three programs quite moderate',
#  'proposal advanced mr javits would cost six hundred millions dollars mr rockefeller rejected new york said agree financing said ought social security',
#  'put deficit treasury',
#  'third medical care aged tied social security financed social security funds',
#  'say majority republicans opposed',
#  'say majority',
#  'say democrats united support program',
#  'extreme bill yet could get one republican join least think four eight democrats voted send floor house one republican joined democrats opposed',
#  'fact matter bill less recommended mr nixon morning proposal',
#  'uh defeat teacher salaries bill uh met opinion need',
#  'secondly federal aid education bill',
#  'think extreme yet nearly two thirds three fourths republicans house representatives voted proposal',
#  'one bill dollar twenty five cents hour anyone works store company million dollars year business',
#  'well let look bills vice president suggests extreme',
#  'reason president eisenhower vetoes sustained reason congress send bills think vetoed people congress majority know country behind president',
#  'must always remember president stop anything unless people behind',
#  'also say far senator kennedy proposals concerned question simply one uh presidential veto stopping programs',
#  'think shows difference two parties',
#  'whether house senate next session democratic republican country voted candidate presidency proposals made believe find president republican would case would able get program congress',
#  'one party ready move programs',
#  'well think serious',
#  'test whether america moves whether federal government plus state government plus local government plus biggest segment individual enterprise moves',
#  'often appraising whether moving ahead think federal government',
#  'matter fact question brings point glad make',
#  'question one goals goals one means',
#  'connection would say senator kennedy says status quo believe uh would agree sincere believing proposals federal aid education proposals health care sincerely held',
#  'connection think uh must look future mind fact fight communism home laws deal communists uh become communists become tra fellow travelers also fight communism home moving various injustices exist society communists feed upon',
#  'uphold standards conduct would never follow',
#  'also essential alert fair fair fair uphold freedoms communists would destroy',
#  'remember cold war mr khrushchev waging colleagues waging waged world waged right united states',
#  'one continue problem years come',
#  'question communism within united states one worried us past',
#  'agree senator kennedy appraisal generally respect',
#  'major threat external continue',
#  'think united states maintaining strong society united states think meet internal threat',
#  'sustain uh department justice efforts f b continually alert',
#  'support uh laws united states passed order protect us uh would destroy us within',
#  'think matter continue uh give uh great care attention',
#  'party gives lip service',
#  'example gross national product approximately five hundred billion dollars',
#  'whenever majority people program house senate responds',
#  'would say president able lead president able get program effect support country support people',
#  'something build',
#  'building record believe secret progress know way progress',
#  'think first record proves know way',
#  'senator kennedy suggested believes knows way',
#  'respect sincerity makes suggestion',
#  'hand look various programs offers seem new',
#  'seem simply retreads programs truman administration preceded',
#  'would suggest course evening might indicate areas programs new mean progress',
#  'programs expand educational opportunities give americans equal chance education things necessary dear hearts people',
#  'programs addition see medical care aged much much better handled present time',
#  'may indicate senator kennedy disagreement aims',
#  'want help old people',
#  'want see adequate medical care',
#  'question means',
#  'could give better examples whatever whether field housing health medical care schools eh development electric power programs believe move america move forward build wonderful record made past seven half years',
#  'look programs might suggest evaluating often tendency say test program much spending',
#  'concede areas referred senator kennedy would spe federal government spend would spend',
#  'record never something stand',
#  'sometimes get opinion getting programs house senate purely question legislative finagling sort thing',
#  'good record may emphasize enough',
#  'offered amendment',
#  'cannot course control senate',
#  'uh would hope control house get majority house uh election',
#  'would say course expect pick seats house senate',
#  'convinced alternate proposals republicans field health field education field welfare extreme accomplish end uh without great cost dollars freedom could get next congress',
#  'extreme',
#  'reason particular bills various fields mentioned passed president people',
#  'majority members congress felt particular proposals good issues majority democrats pass send president get veto issue',
#  'president exercises veto power people upo behind third congress',
#  'would say blame president veto power inability senator colleagues get action special session uh misses mark',
#  'would seem difficult blame four republicans eight democrats getting something particular committee',
#  'would say senator kennedy refers action house rules committee eight democrats committee four republicans',
#  'first see possible one third body republicans house senate stop two thirds two thirds adequately led',
#  'well obviously views little different',
#  'send republican president democratic majority threat veto hangs congress judgment continue happened august session clash parties inaction',
#  'judgment vigorous democratic president supported democratic majority house senate win support programs',
#  'informed time came vote adopted president united states would veto',
#  'forty four democrats voted one republican voted',
#  'wanted tie social security',
#  'costed cost democratic platform',
#  'roughly hundred billion hundred quarter billion result government activity',
#  'growth looking growth administration supported policies stimulated',
#  'satisfied every american enjoys full constitutional rights',
#  'satisfied fifty percent steel mill capacity unused',
#  'great country think could greater country powerful country think could powerful country',
#  'means average family income went fifteen per cent eisenhower years two per cent truman years',
#  'great task successful address',
#  'think ready move',
#  'question american people decide want want country want future',
#  'want say years tide came years united states started move',
#  'want historians ten years say years tide ran united states',
#  'fail fail move ahead fail develop sufficient military economic social strength country think uh tide could begin run us',
#  'meet responsibilities think freedom conquer',
#  'said beginning question us faces republicans democrats freedom next generation conquer communists going successful',
#  'feel move sixties function president set people unfinished business society franklin roosevelt thirties agenda people must society meet needs country protect security help cause freedom',
#  'think vote mr nixon',
#  'feel everything done satisfactory relative power prestige strength united states increasing relation communists b gaining security achieving everything nation achieve achieving better life citizens greater strength agree',
#  'means question',
#  'thirdly think question american people look country look world around goals americans',
#  'obligation upon generation',
#  'august tried get time medical care received support one republican senate occasion',
#  'united states standing still',
#  'think means advocate reach goal better means advocates',
#  'kerr bill provided assistance social security',
#  'also essential allow dollar spent could better spent people',
#  'stand programs mean growth progress',
#  'think big assignment big task big function federal government',
#  'reason eisenhower administration moved reason funds example locally build schools hospitals highways make progress administration encouraged individual enterprise resulted greatest expansion private sector economy ever witnessed eight year period',
#  'test whether america moves',
#  'continue alert',
#  'every republican rules committee voted sending bill considered members house representatives',
#  'might say two thirds republicans house voted dollar twenty five cent minimum wage majority democrats sustained nearly two thirds voted dollar twenty five',
#  'objection cost dollars',
#  'senator kennedy take position',
#  'far aid school construction concerned favor senator kennedy january year said favored rather aid teacher salaries',
#  'uh say experience people consider senator kennedy people consider',
#  'course disagree senator kennedy insofar suggestions done uh farm program',
#  'judgment policy work effective supply demand balance',
#  'well vice president came congress together served labor committee',
#  'question much federal government spends question government',
#  'kind programs',
#  'four hundred billion approximately result individuals',
#  'mr landon ran repeal',
#  'think clear contrast',
#  'get uh uh economy',
#  'determined men',
#  'reason complacency',
#  'far absolute gap concerned find united states even ahead twenty years ago',
#  'percentage twenty years ago',
#  'although moving faster growth find example today total gross national product forty four per cent total gross national product',
#  'start much lower base',
#  'reason obvious',
#  'soviet union moving faster',
#  'first think well put perspective really stand regard soviet union whole matter growth',
#  'want compare adversaries year united states ahead education health building homes economic strength',
#  'enough compare might done eight years ago ten years ago fifteen years ago twenty years ago',
#  'soviet union making great gains',
#  'think however president leadership set country exactly must next decade going maintain security education economic growth development natural resources',
#  'think powerful country',
#  'secondly think rich uh country',
#  'well must say reason schools constructed local school districts willing increase property taxes tremendously high figure opinion almost point diminishing returns order sustain schools',
#  'agree senator kennedy completely score',
#  'social security act written ninety four ninety five republicans voted',
#  'disagree means would use get economy',
#  'believe examine democratic platform examine proposals discussed tonight compare proposals made proposals makes would result greater growth country would case followed programs advocated',
#  'program amendment kerr bill',
#  'secondly vice president mentioned medical care aged',
#  'want see day sixty percent seventy seventy five eighty ninety percent force power could bring bear order cause destruction',
#  'want make sure stays relationship',
#  'must say forty four percent soviet country causing us good deal trouble tonight',
#  'point made mr nixon soviet production forty four percent',
#  'essential man president country certainly stand every program mean growth',
#  'found people could least afford people retired incomes uh people fixed incomes found unable meet bills end month',
#  'point would make downgrading much things cost think many people understand better look happened truman administration government spending took found savings lifetime eaten inflation',
#  'one place think program better job',
#  'would cover several million people covered social security',
#  'program social security would require everybody social security take government health insurance whether wanted',
#  'compels nobody insurance want',
#  'provides choice either government insurance private insurance',
#  'health program one senator javits republican senators well supported one provides people sixty five want health insurance opportunity want',
#  'one field health worth mentioning',
#  'many points made would like comment upon',
#  'respectfully submit senator kennedy often would rely much federal government would solve problems stimulate growth',
#  'means issue',
#  'runs minimum thirteen two tenths billions dollars year presently spending maximum eighteen billion dollars year presently spending',
#  'cost minimum four billion dollars year maximum four nine tenths billion dollar year presently spending',
#  'secondly support federal aid education federal aid teachers salaries',
#  'think good investment',
#  'think going',
#  'think heap burden property tax already strained many communities provide make sh insure opinion many children adequately educated many teachers adequately compensated',
#  'greater return economy society educational system second none',
#  'question development natural resources would pay go sense would balanced power revenues would bring back sufficient money finance projects way tennessee valley',
#  'believe balanced budget',
#  'conditions would unbalance budget would grave national emergency serious recession',
#  'otherwise steady rate economic growth mr nixon mr rockefeller meeting said five per cent economic growth would bring ten billion dollars extra tax revenues',
#  'whatever brought think finance essential programs within balanced budget business remains orderly',
#  'think mr novins referring one senator kennedy speeches democratic platform mention cutting national debt',
#  'think pointed course possible particularly proposals senator kennedy advocated either cut national debt reduce taxes',
#  'matter fact necessary raise taxes',
#  'senator kennedy points far one proposal concerned one medical care aged would financed social security',
#  'however raising taxes pay social security',
#  'points would make pay go basis natural resources development',
#  'natural resources development also support incidentally however whenever uh uh uh appropriates money one projects pay appropriate money eh eventually pay mean government put money year',
#  'program advocated failed five votes united states senate would put medical care aged social security would paid social security system social security tax',
#  'would say proposals senator kennedy made result one two things either raise taxes unbalance budget',
#  'program javits nixon nixon javits program would cost fully used uh six hundred million dollars government per year six hundred million dollars state',
#  'medical care aged would put social security',
#  'legislative branch',
#  'would say people opportunity evaluate mine think going abide whatever people decide',
#  'well say question experience question also uh judgment future goals united states ability implement goals',
#  'abraham lincoln came presidency rather little known uh session house representatives defeated senate fifty eight distinguished president',
#  'certain road presidency',
#  'guarantees uh take uh one road another successful president',
#  'congress fourteen years',
#  'voted last uh eight years uh vice president uh presiding senate meeting responsibilities',
#  'met met uh decisions eight hundred times matters affect domestic security united states member senate foreign relations committee',
#  'question really candidate party meet problems united states going face sixties',
#  'advocate reducing federal debt believe going able reduce federal debt much nineteen sixty one two three',
#  'think heavy obligations affect security going meet',
#  'therefore never suggested uh able retire debt substantially even nineteen sixty one two',
#  'reducing interest',
#  'reducing interest rate',
#  'judgment hard money tight money policy fiscal policy administration contributed slow economy helped bring recession fifty four made recession fifty eight rather intense slowed somewhat economic activity',
#  'talked however kind programs talked judgment uh fiscally sound',
#  'vice president disagree',
#  'mine executive branch',
#  'unbalances budget means inflation course cruel blow people older people talking',
#  'awfully glad ge got question know got last question able complete argument',
#  'voted favor proposal supported strongly think provided assistance teachers salaries without chance federal control vote th mr nixon disagreed tie vote uh defeated breaking tie defeated proposal',
#  'want federal government paying teachers salaries directly',
#  'money go states states determine whether shall go school construction teachers salaries opinion protect local authority school board school committee',
#  'therefore think sound proposal supported regret pass',
#  'secondly statements made uh democratic platform would cost good deal money favor unbalancing budget',
#  'wholly wrong wholly error fact last eight years democratic congress reduced appropri requests appropriations ten billion dollars',
#  'view think ought stated clearly record',
#  'view programs carefully drawn within balanced budget economy moving ahead',
#  'well take bills',
#  'may take bills pass senate bill uh provide dollar twenty five cent minimum wage',
#  'failed house pass house failed eleven votes',
#  'threatened veto passed dollar quarter extremely difficult great power president pass bill president opposed',
#  'president needs sustain veto bill one third plus one either house senate',
#  'secondly passed federal aid education bill senate',
#  'failed came floor house representatives',
#  'killed rules committee',
#  'fact august session four members rules committee republicans joining two democrats voted sending aid education bill floor house',
#  'question vice president disagreed',
#  'favor believe best way aid schools without running risk whatever federal government telling teachers teach',
#  'state could determine whether money would spent school construction teacher salaries',
#  'uh vice president quotes january sixty believe federal government pay directly teachers salaries issue senate february',
#  'uh think reason voted federal government uh pay teachers salaries probably reason concerned senator kennedy january year kick press conference said favored aid school construction time feel aid teachers salaries least way read remarks',
#  'question federal government aiding teachers salaries',
#  'take',
#  'took take reason want higher teachers salaries',
#  'need higher teachers salaries',
#  'also want education free federal control',
#  'federal government gets power pay teachers inevitably opinion acquire power set standards tell teachers teach',
#  'think would bad country think would bad teaching profession',
#  'another point made',
#  'favor higher salaries teachers',
#  'senator kennedy said january year press conference way get higher salaries teachers support school construction means local school districts various states money freed raise standards teachers salaries',
#  'also point put responsibility federal government paying portion teachers salaries local communities states going meet responsibility much',
#  'believe words seen local communities state assuming responsibility',
#  'teachers salaries fortunately gone fifty percent last eight years thirty four percent rise salaries',
#  'enough',
#  'believe way get salaries teachers federal government get massive program',
#  'objection potential cost controls eventual freedom american people giving federal government power education greatest power government',
#  'issue senate money would given state',
#  'republican platform cost',
#  'experience different mine',
#  'far experience counts whether experience counts say',
#  'example first trip abroad abroad strongly recommended increase exchange programs particularly related exchange persons leaders labor field information field',
#  'trip south america made recommendations separate inter american lending agency set south american nations would like much better lend participate lending agencies treated countries world',
#  'uh made recommendations trips example trip abroad hungary made recommendations regard hungarian refugee situation adopted president enacted law congress',
#  'within administration chairman president committee price stability economic growth opportunity make recommendations adopted within administration think reasonably effective',
#  'know senator kennedy suggested speech cleveland yesterday committee particularly effective',
#  'would suggest take credit would presume since committee formed price line held well within united states',
#  'well would say latter found uh somewhat unsatisfactory figures uh mr nixon used previous speech talked truman administration',
#  'mr truman came office nineteen uh forty four end war uh difficulties facing united states period transition price controls lifted rather difficult use overall figure taking seven half years comparing last eight years',
#  'prefer take overall percentage record last twenty years democrats eight years republicans show overall period growth',
#  'regard uh price stability uh aware committee produce recommendations ever certainly congress point view legislation regard controlling prices',
#  'regard exchange students labor unions chairman subcommittee africa think one unfortunate phases policy towards country minute number exchanges',
#  'think true latin america also',
#  'come forward program students congo three hundred federal government africa previous year think uh moved least two areas sufficient vigor',
#  'well think federal government moved program withdrew supports uh think would complete uh economic chaos',
#  'farmer plants spring harvests fall',
#  'hundreds thousands',
#  'really able control market well',
#  'first foreign trips made recommendations adopted',
#  'bring crops livestock many time',
#  'would suggest proposals could mentioned',
#  'question us point view party want lead united states',
#  'mean program better',
#  'question administration right thing',
#  'case believe programs stimulate creative energies hundred eighty million free americans',
#  'believe programs senator kennedy advocates tendency stifle creative energies believe words program would lead stagnation motive power need country get progress',
#  'final point would like make senator kennedy suggested speeches lack compassion poor old others unfortunate',
#  'let us understand throughout campaign motives mine sincere',
#  'know means poor',
#  'know means see people unemployed',
#  'know senator kennedy feels deeply problems disagreement goals america means reach goals',
#  'fourteen years period time experience uh government comparable',
#  'secondly think question uh programs advocate party record lead',
#  'come democratic party century produced woodrow wilson franklin roosevelt harry truman supported sustained programs discussed tonight',
#  'mr nixon comes republican party',
#  'nominated',
#  'fact last twenty five years republican leadership opposed federal aid education medical care aged development tennessee valley development natural resources',
#  'think mr nixon effective leader party',
#  'hope would grant',
#  'would rather difficult cover eight two half minutes',
#  'pointed came congress year',
#  'purchasers buy milk hogs large companies many cases therefore farmer position bargain effectively market place',
#  'agricultural economy collapses economy rest united states sooner later collapse',
#  'farmer produced surpluses government asked legislation war',
#  'surpluses responsibility indemnify farmer period get rid farmer uh surpluses',
#  'get surpluses farmer back however program announced see farm income holds',
#  'would propose holding income type program senator kennedy suggested would raise prices one would indemnify farmer pay farmer kind uh products surplus',
#  'well would suggest mr vanocur uh know president probably facetious remark',
#  'uh would also suggest insofar statement concerned think would improper president united states disclose uh instances members official family made recommendations made years accepted rejected',
#  'president always maintained properly entitled get advice wants cabinet advisers without disclosing anybody including matter fact congress',
#  'say',
#  'years sat national security council',
#  'cabinet',
#  'met legislative leaders',
#  'met president made great decisions regard lebanon quemoy matsu matters',
#  'president asked advice',
#  'sometimes advice taken',
#  'say made decisions',
#  'would say president ever allow anybody else make major decisions president makes decisions',
#  'advisers give counsel asks',
#  'fundamental reason let farmer go present time',
#  'think experience twenties shown free market could agriculture',
#  'recognizes government responsibility get farmer trouble presently government got',
#  'think worked past think work future',
#  'farmers number one market automobile industry united states',
#  'automobile industry number one market steel',
#  'farmers economy continues decline sharply recent years think would recession rest country',
#  'think case government intervention good one',
#  'secondly objection present farm policy effective controls bring supply demand better balance',
#  'dropping support price order limit production work highest uh surpluses nine billion dollars worth',
#  'uh higher tax load treasury farmer last years lowest farm income many years',
#  'think farm policy failed',
#  'done governmental action',
#  'therefore suggest basic commodities supported federal government endorsement farmers commodity attempt bring supply demand balance attempt effective production controls five six per cent surplus breaks price fifteen twenty per cent',
#  'think mr benson program failed',
#  'must say reading vice president speech farmers read mine believe much different mr benson',
#  'think provides effective governmental controls',
#  'think support prices tied average market price last three years mr benson theory',
#  'therefore believe sharp enough breach past give us hope success future',
#  'made suggestion need move direction government controls suggestion would also mean raising prices uh consumers pay products im imposing upon farmers uh controls acreage even far today',
#  'think wrong direction',
#  'program advocated one departs present program respect',
#  'four democrats voted',
#  'thirdly medical care aged fight going twenty five years social security',
#  'satisfied soviet union turning twice many scientists engineers',
#  'things think country make society strong mean stands still',
#  'negro baby born true also puerto ricans mexicans cities one half much chance get high school white baby',
#  'one third much chance get college white student',
#  'third much chance professional man half much chance house',
#  'uh four times much chance work life white baby',
#  'think better',
#  'want talents american go waste',
#  'know want turn everything government',
#  'united states developed tennessee valley built grand coulee dams northwest united states present rate hydropower production hallmark industrialized society soviet union producing power',
#  'want states meet responsibilities',
#  'argument used every piece social legislation last twenty five years',
#  'people united states individually could developed tennessee valley collectively could',
#  'cotton farmer georgia peanut farmer dairy farmer wisconsin minnesota cannot protect forces supply demand market place working together effective governmental programs',
#  'seventeen million americans live sixty five average social security check seventy eight dollars month able sustain individually sustain social security system',
#  'believe big government believe effective governmental action',
#  'think way united states going maintain freedom',
#  'way going move ahead',
#  'think better job',
#  'think also national responsibility',
#  'satisfied failing develop natural resources united states fullest',
#  'satisfied see men like jimmy hoffa charge largest union united states still free',
#  'think educational system second none',
#  'election abraham lincoln said question whether nation could exist half slave half free',
#  'election world around us question whether world exist half slave half free whether move direction freedom direction road taking whether move direction slavery',
#  'think depend great measure upon united states kind society build kind strength maintain',
#  'discuss tonight domestic issues would want implication given involve directly struggle mr khrushchev survival',
#  'mr khrushchev new york maintains communist offensive throughout world productive power soviet union',
#  'chinese communists always large population',
#  'important dangerous mounting major effort within country',
#  'kind country kind society kind strength build united states defense freedom',
#  'well meet obligations moving ahead think freedom secure around world',
#  'fail freedom fails',
#  'therefore think question american people much',
#  'strong',
#  'strong must going maintain independence going maintain hold hand friendship look us assistance look us survival',
#  'make clear think enough satisfied american progress making',
#  'satisfied united states last year lowest rate economic growth major industrialized society world',
#  'economic growth means strength vitality means able sustain defenses means able meet commitments abroad',
#  'satisfied nine billion dollars worth food rotting even though hungry world even though four million americans wait every month food package government averages five cents day per individual',
#  'saw cases west virginia united states children took home part school lunch order feed families think meeting obligations toward americans',
#  'satisfied many teachers inadequately paid children go school part time shifts',
#  'think going better job going meet responsibilities time events placed upon us',
#  'cannot turn job anyone else',
#  'want individuals meet responsibilities',
#  'think depends great measure country',
#  'looking problem united states move ahead united states moving think well take advice famous campaigner let look record',
#  'true administration senator kennedy charged administration retreat defeat stagnation',
#  'true far country concerned field electric power fields mentioned moving ahead',
#  'well comparison make',
#  'record truman administration seven half years seven half years eisenhower administration',
#  'compare two records areas senator kennedy discussed tonight think find america moving ahead',
#  'built schools last seven half years built previous seven half matter previous twenty years',
#  'developed hydroelectric power seven half years developed previous administration history',
#  'united states fails whole cause freedom fails',
#  'true highways',
#  'let put terms us understand',
#  'often hear gross national product discussed respect may say compare growth administration previous administration total growth eleven percent seven years administration total growth nineteen per cent seven years',
#  'shows growth administration predecessor',
#  'let put let put terms average family',
#  'happened',
#  'find wages gone five times much eisenhower administration truman administration',
#  'prices pay',
#  'find prices pay went five times much truman administration eisenhower administration',
#  'net result',
#  'year year recovery find six nine tenths per cent one highest world today',
#  'look growth g n p',
#  'find built administration previous administration',
#  'last year course',
#  'happened recession year',
#  'reason franklin roosevelt good neighbor latin america good neighbor united states',
#  'felt american society moving',
#  'want us recapture image',
#  'want people latin america africa asia start look america see things wonder resident united states look khrushchev look chinese communists',
#  'franklin roosevelt said inaugural generation americans rendezvous destiny',
#  'question freedom maintained severe tack attack ever known',
#  'think',
#  'think final analysis depends upon',
#  'think time america started moving',
#  'think generation americans rendezvous',
#  'question cannot discuss internal affairs united states without recognizing tremendous bearing international position',
#  'question nation cannot stand still deadly competition competition men kremlin men peking',
#  'ahead competition senator kennedy think implied',
#  'race way stay ahead move ahead',
#  'subscribe completely spirit senator kennedy expressed tonight spirit united states move ahead',
#  'disagree',
#  'think disagree implication remarks tonight statements made many occasions campaign effect united states standing still',
#  'things senator kennedy said many us agree',
#  'heard tonight example statement made growth national product last year lowest industrial nation world',
#  'second wrong analogies makes',
#  'want make position absolutely clear regard getting intelligence information',
#  'cannot afford intelligence gap',
#  'lost three thousand american lives',
#  'remember pearl harbor',
#  'united states strong country',
#  'connection senator kennedy criticized president ground expressing regrets allowed flight take place summit conference immediately summit conference occurred',
#  'whenever anything wrong express regrets',
#  'knew flights going long reason broke conference',
#  'intend see united states ever position negotiating soviet union discontinue intelligence effort',
#  'seems criticism wrong part',
#  'intend ever express regrets mr khrushchev anybody else something support congress right purpose protecting security united states',
#  'circumstances',
#  'would give statutory authority committee government contracts effective way getting real progress made area since one every four jobs held allotted people government contracts',
#  'certainly think us agree anybody government contract certainly money spent contract ought disbursed equally without regard race creed color individual employed',
#  'course rejected government contracts provision special session congress mr kennedy quite active',
#  'far areas concerned think look presidential leadership',
#  'speak presidential leadership refer example attitude sit strikes',
#  'talked negro mothers',
#  'heard explain try explain tell children go store buy loaf bread go store sit counter get coca cola',
#  'wrong something',
#  'well attorney general united states direction president call owners chain stores get take action',
#  'first wrong thinking th er even suggesting mr khrushchev might continued conference expressed regrets',
#  'places executive lead let sum saying talk every time south civil rights',
#  'intentions field civil rights spelled republican platform',
#  'think kenne senator kennedy wrong three counts',
#  'therefore passed authorization aid bill first time really since inter american bank founded year ago developed really looked needs latin america associated people',
#  'believe increase strength world',
#  'preaching people south southern problem northern problem western problem problem us',
#  'also question free people cuba people want free going supported attain freedom',
#  'cuba lost think kind defeatist talk senator kennedy helps situation one bit',
#  'speech last night indicated thought cuba one day would free',
#  'critical administration policy criticized mr nixon press conference havana praised competence stability bicta bict batista dictatorship dictatorship killed twenty thousand cubans seven years',
#  'secondly criticize calling free elections',
#  'criticized failure administration use great influence persuade cuban government hold free elections particularly',
#  'thirdly arthur gardner republican ambassador earl smith republican ambassador succession indicated past six weeks reported washington castro marxist raul castro communist got effective results',
#  'instead aid continued batista ineffective never side freedom never used influence could used effectively today cuba lost freedom',
#  'hope day rise think rise continue policies toward cuba recent years fact towards latin america almost ignored needs latin america beamed single voice america program spanish latin america last eight years except three months hungarian uh revolution',
#  'mr morgan suggested united states felt could save summit conference would proper us expressed regrets',
#  'confuse words strength judgment summit useful would brought us closer peace rather lie told criticized responsible people afterwards would far better us follow common diplomatic procedure expressing regrets try move',
#  'judgment statement distorted uh mr nixon others debates around country discussions',
#  'u flights proper point view protecting security',
#  'accordance international law',
#  'said felt rather tell lie told rather indicate flights would continue fact believe mr nixon said may fifteenth flights would continue even though mr herter testified senate foreign relations committee canceled may twelfth would far better expressed regrets would saved summit summit useful believe',
#  'point always left fact expressed regrets castro winter expressed regrets eisenhower administration expressed regrets flight southern russia',
#  'expressed regrets flight eastern germany administration',
#  'soviet union expressed regrets us bering sea incident',
#  'chinese communists expressed regrets us plane incident',
#  'accepted procedure nations judgment follow advice theodore roosevelt strong maintain strong position also speak softly',
#  'believe cases international custom calls expression regret would kept summit going judgment proper action',
#  'believe stronger',
#  'believe stronger military force',
#  'mr lodge meet press month ago said ever case law side u incident',
#  'responsibility leadership solve problem together',
#  'mr khrushchev came conference determined break',
#  'pointed made clear far korean war concerned felt decision go war korea right necessary',
#  'would meet mr khrushchev unless agreements secondary level foreign ministers ambassadors would indicate meeting would hope success useful exchange ideas',
#  'going move sixty one two partly maintained strength sufficient vigor last years believe meet crisis next president united states send message congress asking revitalization military strength come spring late winter going face face serious berlin crisis since l fifty',
#  'going test strength',
#  'going test nerve',
#  'next president united states first year going confronted serious question defense berlin commitment berlin',
#  'negotiate position power balance wave moving away us extremely difficult reach successful decision berlin well questions',
#  'go summit ever meet think important united states build strength build military strength well economic strength',
#  'let say one uh point would add',
#  'view',
#  'disagreement vice president position',
#  'circumstances therefore strongly urge strongly hold opportunity urge hold position summit conference would gone careful preparation mr khrushchev disgraceful conduct paris disgraceful conduct united nations gave assurance really wanted sit talk accomplish something make propaganda',
#  'well think winter sixty one present economic conditions uh uh tax uh increase would desirable',
#  'otherwise find heads state meeting making progress find cause peace hurt rather helped',
#  'going break would knew going get way berlin key matters concerned paris conference',
#  'question defend rights',
#  'must build hopes world dash case paris',
#  'would able wou would willing meet however unless preparations conference would give us reasonable certainty reasonable certainty going success',
#  'would willing president meet mr khrushchev world leader would serve cause peace',
#  'far summit conference concerned want make position absolutely clear',
#  'president still going president next four months course one could commit country period',
#  'would appropriate',
#  'course talked prime minister macmillan',
#  'incidentally senator kennedy disagrees indicate believes policies different advocating today',
#  'say american people want go back policies',
#  'going another summit conference must negotiations diplomatic level ambassadors secretaries state others level prior time delineate issues prepare way heads state meet make progress',
#  'right time particularly khrushchev country man enslaved millions man slaughtered thousands cannot continue situation point finger united states america say denying rights citizens',
#  'fact would deflationary would cause great unemployment would cause real slowdown economy',
#  'talked every speech fact going difficult times nineteen sixties going meet responsibilities citizens',
#  'paid money paid people money',
#  'add billions dollars expenditures pay',
#  'going working way',
#  'platform suggests done economic growth done effect mirrors',
#  'think also add far senator kennedy proposals concerned intends carry platform one adopted los angeles impossible make good promises without raising taxes without rise prices',
#  'tax tax enough pay outgo pay many times higher prices inflation simply',
#  'would hesitation ask american people pay taxes even l necessary maintain sound economy also maintain sound dollar',
#  'hope economize elsewhere',
#  'think may necessary taxes',
#  'opinion going de greater',
#  'expenditures defense expenditures mutual security expenditures economic assistance technical assistance going get less',
#  'ever becomes necessary wise economically essential security would hesitancy suggesting tax increase policy would defend united states',
#  'well think illusions whatever responsibilities american people sixties',
#  'merely say elect president best carry united states difficult period would want people elect promised easy soft life',
#  'say know sixties bring except think bring hard times uh international sphere hope move ahead home united states confident far better job mobilizing economy resources united states',
#  'able consume able produce time soviet union making great economic gains',
#  'believe policies recommend came general heading strengthening united states',
#  'problem building uh military strength extending uh policies abroad job home',
#  'moving ahead providing viable economy people sufficient resources consume produce country move stronger set better example world',
#  'united states began prepare great actions world war ii post war period',
#  'would want anyone elect uh president united states vote expectation life would easier elected',
#  'know future going bring',
#  'talking willingness bear burdens order maintain freedom order meet freedom around globe',
#  'talking national mood',
#  'think going difficult confident country meet responsibilities',
#  'regard cuba let make one thing clear',
#  'believe strongly defense formosa',
#  'position united states treaty treaty organization american states prohibits us interfering internal affairs state prohibits well',
#  'democrats republicans',
#  'student history senator kennedy incidentally found history country many great presidents',
#  'way elect president country way',
#  'would never tolerate president united states hope senator kennedy change mind elected',
#  'opinion kind woolly thinking led disaster america korea',
#  'start chain reaction communists quemoy matsu formosa',
#  'uh force nationalist allies get give communists',
#  'nationalists two islands',
#  'two islands area freedom',
#  'people live important',
#  'think far quemoy matsu concerned question two little pieces real estate unimportant',
#  'go came',
#  'mean',
#  'suppose hoped made speech get war',
#  'secretary acheson made famous speech press club early year k korean war started indicating effect south korea beyond defense zone united states',
#  'remember period immediately korean war south korea supposed indefensible well',
#  'disagree completely senator kennedy point',
#  'long essential defense formosa judgment ever since time eisenhower doctrine far east line drawn sea around island',
#  'believe line case war drawn islands instead island formosa',
#  'believe strongly formosa believe meet commitments every country whose security guaranteed',
#  'believe strongly berlin',
#  'think uh protect commitments',
#  'general ridgway mr herter general collins admiral spruance many others think unwise take chance dragged war may lead world war two islands strategically defensible according testimony essential defense formosa',
#  'people way always understood particular time certain man one country needed',
#  'believe election trying determine lead free world america perhaps senator kennedy already indicated important election history label wears wear counts',
#  'stand',
#  'consequently think enough go republican audiences never say look vote republican',
#  'republicans recent years last twenty five years last eight years opposed housing opposed care aged opposed federal aid education opposed minimum wage think record tells something',
#  'importance party tells something record',
#  'stand whole different approach problems facing country home abroad',
#  'stand something',
#  'republican party produced mckinley harding coolidge dewey landon',
#  'stood strong foreign policy strong national defense result produced wilson president roosevelt president truman',
#  'stood progress stood concern people welfare',
#  'democratic party century stood something',
#  'abraham lincoln great president people selected party key time history party stood something',
#  'well let say think parties important tell something program something man',
#  'suggest however interest fairness could give benefit also believing believes',
#  'leaves hundred miles sea',
#  'sure believes deeply move way',
#  'move forward faster move surely program',
#  'say programs fields education housing defense move america forward',
#  'far running away party concerned senator kennedy said compassion poor progress enemies progress term used like',
#  'think people put america first rather party first',
#  'believe people therefore asked make minds simply basis vote way grandfather vote way mother',
#  'people make minds',
#  'people ones determine',
#  'may republican may democratic',
#  'means best leadership',
#  'involved question leadership whole free world',
#  'think enough senator kennedy go audiences democratic side say vote democrat',
#  'deeply believe',
#  'decision finally nationalists make believe consult attempt work plan line drawn island formosa',
#  'secondly would suggest withdrawal point communist gun',
#  'leave rather air defend conditions think mistake',
#  'pointing things wrong think ought emphasize america strengths',
#  'best fed best clothed better distribution world goods people people history',
#  'people go bed hungry united states far less incidentally used go bed hungry came power end truman administration',
#  'true',
#  'think helpful suggested glad corrected extent seventeen million people go bed hungry every night united states',
#  'think harmful time mr khrushchev harmful wrong',
#  'think say prestige time low',
#  'responsibility accurate misstate case',
#  'would also like point far senator kennedy comments concerned think perfect right responsibility criticize administration whenever thinks wrong',
#  'administration stopped quemoy matsu stopped indochina stopped lebanon stopped parts world',
#  'truman administration six hundred million people went behind iron curtain including satellite countries eastern europe communist china',
#  'necessary run america order build',
#  'like know defeated retreated',
#  'incidentally point senator kennedy attacked foreign policy',
#  'criticized policies made necessary go korea',
#  'well first agree senator kennedy cuba lost certainly china lost administration came power',
#  'look cuba today believe following right course course difficult course circumstance proper one see cuban people get chance realize aspirations progress freedom get cooperation organi states organization american states',
#  'points fact visited cuba mr batista power',
#  'point going judge administrations terms attitude toward dictators glad comparison previous administration',
#  'today three left including one cuba',
#  'think pretty good progress',
#  'senator kennedy also indicated regard cuba thought made mistake cuba calling free elections country',
#  'surprised senator kennedy foreign relations committee would made statement kind',
#  'matter fact book strategy peace took right position',
#  'said policy led defeat retreat',
#  'made statement would direct uh opposition treaty',
#  'get absolutely clear senator kennedy must candidate candidate fifty two criticize us wrong',
#  'hand responsibility accurate',
#  'come defense',
#  'believe defend formosa',
# ...
#  'president eisenhower moves scene january twentieth next four years critical years',
#  'believe american people make choice november eighth view whether move ahead faster whether satisfactory whether build greater strength home abroad mr nixon view',
#  'feels moving ahead uh going recession country economically feels power prestige stronger ever relative communists moving ahead',
#  'believe economy sound going move',
#  'finally regard whole problem combating recession call must use full resources government respects one must see credit expanded go recessionary period understand believe going recession',
#  'program education program case equal job opportunities one would also deal older citizens',
#  'going combat unemployment better job areas',
#  'question summit agree position mr nixon',
#  'many programs talking economic growth care aged development natural resources build strength united states',
#  'using steel capacity fifty five per cent today',
#  'thing right united states emphasized less people go bed hungry united states major country world',
#  'tell surplus food distribution five cents po per person n nearly six million americans receiving adequate',
#  'never said flatly defend quemoy matsu attacked',
#  'believe get w going get war defense formosa ought clearly defined line',
#  'primarily ideological battle battle minds hearts souls men',
#  'point would make regard economic assistance technical assistance united states must rest case alone',
#  'unless adequate funds example information cut congress adequate funds technical assistance',
#  'think many ways election important since certainly almost century',
#  'must get across world',
#  'must associate aspirations',
#  'also mind something else regard whole situation world america moves forward must think terms fighting communism must also think primarily terms interests countries',
#  'need step exchange need step technical assistance trained people newly developing countries operate economies',
#  'also tremendously important bear mind pour money without pouring technical assistance w well disastrous situation',
#  'senator kennedy put great deal stress necessity economic assistance',
#  'build economy way afford things must',
#  'believe',
#  'believe essential next ten years balance power going begin move world one direction another towards us towards communists unless begin identify anti communist fight also fight poverty hunger people going begin turn communists example',
#  'country moving ahead developing economy fullest judgment resources meet military commitments also commitments overseas',
#  'goes survival',
#  'must let know great american ideals independence right people free right progress ideals belong alone belong everybody',
#  'third believe step use surplus foods areas able get people back work',
#  'floor manager',
#  'senator kennedy made strong criticisms part alleged part happened cuba',
#  'second consider problem unemployment realize',
#  'made recommendations discussed previously spell campaign',
#  'point one highest priority must get bill depressed areas next congress',
#  'hand found bill got legislative difficulties consequently action taken',
#  'bill president submitted would provided aid areas really need areas like scranton wilkes barre areas west virginia ones senator kennedy supporting',
#  'last congress special session congress bill one president one senator kennedy members party',
#  'combat unemployment first must concentrate areas refer called depressed areas',
#  'must stand ideals',
#  'must meet communists purely field gross atheistic materialism',
#  'well mr nixon stated record inaccurately regard depressed area bill',
#  'analyzing figures find unemployment exists among older citizens exists also among inadequately trained adequate opportunity education',
#  'eleven dictators south america central america came',
#  'first place never suggested cuba lost except present',
#  'president united states something right something purpose defending security country surprise attack never express regrets apologize anybody including mr khrushchev',
#  'think make progress first field employment',
#  'second field schools believe provisions whereby federal government would give assistance districts want integrate schools',
#  'situation causes us concern causes us concern denial rights people equality think belongs everybody',
#  'goldfish bowl world',
#  'let look also',
#  'seventy votes position none',
#  'looking ought future',
#  'tried provide appropriation billion half five years long term loan basis administration opposed',
#  'question defend guantanamo attacked',
#  'also exists among minority groups',
#  'let look situation regard economic growth really',
#  'let look vote congo vote seventy nothing soviet union',
#  'stimulation incentive companies go explore oil develop',
#  'well would say first senator kennedy statement made going help gallup polls abroad going help prestige either',
#  'could look also items senator kennedy named conclude saying whole matter prestige final analysis whether stand right',
#  'well ahead stay ahead provided confidence america run order build',
#  'includes oil includes kinds minerals includes everything within range taxation',
#  'want sure fair equitable',
#  'perhaps oil abroad treated differently oil home',
#  'oil industry recently hard times',
#  'particularly smaller producers',
#  'moving eight nine days texas',
#  'assure elected president whole spectrum taxes gone carefully',
#  'getting back matter discussed outset matter quemoy matsu',
#  'inequities oil commodity would vote close loophole voted past reduce depletion allowance largest producers five million dollars maintain twenty seven half per cent',
#  'senator kennedy position mine completely different',
#  'favor present depletion allowance',
#  'favor want make lot oil men rich want make america rich',
#  'depletion allowance',
#  'depletion allowance certainly believe present amount would oil exploration cut substantially country',
#  'far position concerned exactly opposite senator',
#  'belief america going growth talks talk want thing discourage individual enterprise discourage people go discover oil minerals encourage',
#  'suggests number items whole depletion field could taken account',
#  'also said moment ago would get money finance programs revising tax laws including depletion',
#  'believe study allowances tax expense dividend expenses rest make determination stimulate growth provide revenues needed move country forward',
#  'think nothing greater blow prestige united states among free nations asia us take senator kennedy advan advice go go majority members senate democrat republican said say advance surrender area communists',
#  'words united states going maintain strength prestige must strong militarily economically must firm diplomatically',
#  'thi certainly speaking know whether retreat defeat',
#  'whole th united states treaty voted united states senate defend formosa pescadores island',
#  'treaty include two islands',
#  'believe move full time missile production particularly minuteman polaris',
#  'many wars history mankind',
#  'may succeed',
#  '',
#  'certainly going peace giving indicating advance going defend become symbol freedom',
#  'would take action necessary defend treaty formosa pescadores island',
#  'suggest support',
#  'last television debate pointed position americans must choose best man either party could produce',
#  'uh also get uh opportunity questioners question next television debate',
#  'difficulty president course quite limited',
#  'judgment program vice president put forward extension mr benson program cost billion dollars present program costs six billion dollars year expensive history',
#  'believe ought pay bills inflation phony interest rate',
#  'got grow enough maintain forces abroad wage non military battle war uh world asia africa latin america',
#  'move areas programs make adequate use resources areas',
#  'would exactly wrong thing',
#  'oppose want us oil exploration less',
#  'believe must able compete market steel basic commodities abroad must able compete always technological lead',
#  'every ca african country either abstained voted us',
#  'let remember way win retreat surrender',
#  'point far depletion allowances concerned oil depletion allowance one provides eighty percent involved depletion going get much revenue insofar depletion allowances concerned unless move area indicated',
#  'let look side coin',
#  'oppose reasons mentioned',
#  'means must continue balanced budget home every possible circumstance moment loss confidence fiscal policies home results gold flowing',
#  'significance prestige really identified cause freedom',
#  'therefore mount rising influence spreading prestige spreading uh stand razor edge decision us communist system wondering whether use system freedom develop countries system communism persuaded follow example',
#  'several indications prestige high',
#  'mr george allen head information service said result second space sputnik quote believe paraphrase accurately',
#  'said many countries equate space developments scientific productivity scientific advancement',
#  'therefore said many countries feel soviet union backward par united states',
#  'secondly economic growth soviet union greater',
#  'mr dulles suggested two three times great',
#  'great effect underdeveloped world faces problems low income high population density inadequate resources',
#  'well think many uh tests mr drummond prestige',
#  'three gallup poll taken february asked people ten countries country thought would first scientifically militarily',
#  'four votes u n particularly vote dealing red china last saturday received support position taken two african countries one liberia tied us century union south africa popular country africa',
#  'countries voted us asia issue voted us',
#  'neutralists resolution much opposed thing happened',
#  'candidate candidate president brazil took trip cuba call mr castro election order get benefit castro supporters uh within brazil',
#  'guinea ghana two independent countries within last three years guinea fifty seven ghana within last eighteen months supporting soviet foreign policy u n mr herter said',
#  'laos moving direction',
#  'would say prestige high',
#  'longer give image rise',
#  'longer give image vitality',
#  'majority every country except greece felt would soviet union l',
#  'persuade countries restrict goods coming act dollar gap third persuade assume responsibilities till maintained assist underdeveloped countries africa latin america asia make economic breakthrough',
#  'sure maintain',
#  'dollar shortage yet many countries continue move goods',
#  'secondly increase exports compared imports',
#  'strong program going forward department commerce',
#  'beyond far gold supply concerned far movement gold concerned uh bear mind must get help allies abroad great venture free men involved winning battle freedom',
#  'america carrying tremendous load respect',
#  'think right carrying',
#  'favored programs abroad economic assistance military assistance',
#  'find countries europe example aided japan aided far east countries former enemies recovered completely',
#  'got bear greater share load economic assistance abroad',
#  'advocating develop course next administration course get opportunity program enlist aid countries concerted basis programs economic development africa asia latin america',
#  'united states cannot continue carry major share burden',
#  'big share got help friends abroad three factors think helpful reversing gold flow spoke',
#  'uh correct record mr nixon said depletion record opposite mine',
#  'said matter thoroughly gone make sure loopholes',
#  'record opposite means want go',
#  'question gold',
#  'difficulty course heavy obligations abroad therefore maintain favorable balance trade also send good deal dollars overseas pay troops maintain bases sustain economies',
#  'words going continue maintain position sixties maintain sound monetary fiscal policy',
#  'control inflation also favorable balance trade',
#  'able compete world market',
#  'able sell abroad consume uh abroad going able meet obligations',
#  'addition many countries around world still keep restrictions goads going way back days dollar shortage',
#  'von fremd first thing continue keep confidence abroad american dollar',
#  'one must stepped',
#  'know weapons vice president talking',
#  'uh mr mcgee hundred four commodities kind depletion allowance different kind minerals including oil',
#  'stand',
#  'concept completely repugnant',
#  'general ridgway said chief staff go war quemoy matsu would seem unwarranted tragic course take',
#  'general twining said still',
#  'uh sent mission president mr uh robertson admiral radford',
#  'suggest chiang kai shek administration attempting since persuade chiang kai shek lessen troop commitments',
#  'talking vice president determination guarantee quemoy matsu four five miles coast red china within treaty area',
#  'completely sustained treaty',
#  'therefore treaty commit united states defend anything except formosa pescadores deal acts treaty area',
#  'done much thought deliberation',
#  'mr dulles press conference said treaty republic china excludes quemoy matsu treaty area',
#  'think possible mr nixon state record distortion facts precision',
#  'instance good intentions course desire peace',
#  'road war always paved good intentions',
#  'stand secretary state mr herter said islands indefensible',
#  'may say would trust senator kennedy would change position change long major presidential candidate continues suggest going turn islands encouraging aggressors chinese communist soviet aggressors press united states press us point war would inevitable',
#  'incidentally senator johnson among rejected position voted seventy twelve',
#  'think senate right including majority democrats majority republicans rejected senator kennedy position',
#  'learned lesson korea must learn',
#  'went tragic experience leading world war ii',
#  'point follow course action indicating going defend particular area inevitable result encourages man determined conquer world press point return',
#  'first quemoy matsu next may formosa',
#  'whenever inevitably dictator encouraged try',
#  'uh related moment ago president always indicated must make mistake dealing dictator indicating going make concession point gun',
#  'far president eisenhower concerned often heard discuss question',
#  'many infantrymen enough heavy artillery certainly think implication secretary dulles statement quemoy matsu defended event attacked attack preliminary attack formosa',
#  'well mr drummond first referring secretary dulles press conference think read know find secretary dulles also indicated press conference troops withdrawn quemoy implication certainly everything said quemoy could better defended',
#  'amendment put senate united states record majority senator party voting well majority republicans put record position senator takes surrendering indicating advance united states defend offshore islands',
#  'forgets debate formosa resolution said voted voted amendment recorded amendment particular amendment say passed senate overwhelmingly seventy twelve',
#  'comment senator kennedy last answer',
#  'senate right knew lesson history',
#  'must absolute guarantee',
#  'believe meet commitments chinese communists attack pescadores formosa know mean war',
#  'merely say treaty quite precise sustain treaty',
#  'object constant reference surrendering islands',
#  'referring question regard quemoy matsu',
#  'answer united states afford es es espionage lack uh lag say uh intelligence lag afford missile lag',
#  'answer course communist espionage goes time',
#  'noted example reading uh particular discussion senator kennedy dave garroway shortly uh statement regrets uh made statement felt particular flights uh ones occurred right time indication would mr khrushchev felt uh flight uni would felt mr khrushchev ha uh flight united states uh visiting',
#  'think president correct certainly decision continue flights conference going',
#  'think president correct ordering flights',
#  ...]

# %%
# add clean text to dataframe
df["Clean_text"] = pd.Series(data)

# %%
df.head()
# Out:
#        Sentence_id                                               Text  \
# index
# 0             8211                   Now, this is not standing still.
# 1             8515  So these are three programs which are quite mo...
# 2             8514  The proposal advanced by you and by Mr. Javits...
# 3             8513         It does not put a deficit on the Treasury.
# 4             8512  The third is medical care for the aged which i...
#
#                 Speaker   Speaker_title Speaker_party         File_id  Length  \
# index
# 0      Richard M. Nixon  Vice President    REPUBLICAN  1960-09-26.txt       6
# 1       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt       9
# 2       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt      42
# 3       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt       9
# 4       John F. Kennedy         Senator      DEMOCRAT  1960-09-26.txt      22
#
#        Line_number  Sentiment  Verdict       date  mos_before_election  \
# index
# 0              114  -0.417840       -1 1960-09-26                    2
# 1              418   0.249581       -1 1960-09-26                    2
# 2              417  -0.626563        1 1960-09-26                    2
# 3              416  -0.629486        1 1960-09-26                    2
# 4              415   0.000000       -1 1960-09-26                    2
#
#                                               Clean_text
# index
# 0                                         standing still
# 1                          three programs quite moderate
# 2      proposal advanced mr javits would cost six hun...
# 3                                   put deficit treasury
# 4      third medical care aged tied social security f...

# %%
df_new = df.loc[:, ['date', 'Text', 'Clean_text', 'Verdict']]

# %%
df_new.to_csv('data.csv',  index=False)

# %% [markdown]
# ## With stemming

# %%
data1 = preprocess_data(df.Text.values, stemming=True)

# %%
# add clean text to dataframe
df.drop(['Clean_text'], axis=1, inplace=True)
df["Clean_text"] = pd.Series(data1)
df_new = df.loc[:, ['date', 'Text', 'Clean_text', 'Verdict']]
df_new.to_csv('data_stemmed.csv')
